# %%
# session 생성시 tf.Session()대신 tf.Session(config=config)로 대체 바랍니다!

import tensorflow as tf
import os
'''
os.environ["CUDA_VISIBLE_DEVICES"]='0'
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
'''
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("./mnist/data/", one_hot=True)

X = tf.placeholder(tf.float32, [None, 784])
Y = tf.placeholder(tf.float32, [None, 10])

def dropout(x, keep_prob):
    mask = tf.floor(keep_prob * tf.ones(tf.shape(x)) + tf.random_uniform(shape=tf.shape(x)))
    return tf.divide(x, keep_prob) * mask
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# WARNING:tensorflow:From <ipython-input-1-b1aeb5afed9e>:10: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ./mnist/data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ./mnist/data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting ./mnist/data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting ./mnist/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
# setup layers
# He Initialization
keep_prob = tf.placeholder(tf.float32)
epsilon = 1e-3

'''
W1 = tf.Variable(tf.random_normal([784, 2048], stddev=0.01))
#W1 = tf.get_variable("W1", shape=[784, 1024], initializer=tf.contrib.layers.variance_scaling_initializer())
B1 = tf.Variable(tf.random_normal(shape=[2048], stddev=0.01))
L1 = tf.nn.relu(tf.matmul(X, W1)+B1)
L1 = tf.nn.dropout(L1, keep_prob)
'''

W1_BN = tf.Variable(tf.random_normal([784, 2048], stddev=0.01))
L1_BN = tf.matmul(X, W1_BN)
batch_mean1, batch_var1 = tf.nn.moments(L1_BN,[0])
scale1 = tf.Variable(tf.ones([2048]))
beta1 = tf.Variable(tf.zeros([2048]))
BN1 = tf.nn.batch_normalization(L1_BN, batch_mean1, batch_var1, beta1, scale1, epsilon)
L1_BN = tf.nn.relu(BN1)
L1_BN = tf.nn.dropout(L1_BN, keep_prob)

'''
W2 = tf.Variable(tf.random_normal([2048, 1024], stddev=0.01))
#W1 = tf.get_variable("W1", shape=[784, 1024], initializer=tf.contrib.layers.variance_scaling_initializer())
B2 = tf.Variable(tf.random_normal(shape=[1024], stddev=0.01))
L2 = tf.nn.relu(tf.matmul(L1_BN, W2))
L2 = tf.nn.dropout(L2, keep_prob)
'''

W2_BN = tf.Variable(tf.random_normal([2048, 1024], stddev=0.01))
L2_BN = tf.matmul(L1_BN, W2_BN)
batch_mean2, batch_var2 = tf.nn.moments(L2_BN,[0])
scale2 = tf.Variable(tf.ones([1024]))
beta2 = tf.Variable(tf.zeros([1024]))
BN2 = tf.nn.batch_normalization(L2_BN, batch_mean2, batch_var2, beta2, scale2, epsilon)
L2_BN = tf.nn.relu(BN2)
L2_BN = tf.nn.dropout(L2_BN, keep_prob)

'''
W3 = tf.Variable(tf.random_normal([1024, 512], stddev=0.01))
#W2 = tf.get_variable("W2", shape=[1024, 512], initializer=tf.contrib.layers.variance_scaling_initializer())
B3 = tf.Variable(tf.random_normal(shape=[512], stddev=0.01))
L3 = tf.nn.relu(tf.matmul(L2, W3)+B3)
L3 = tf.nn.dropout(L3, keep_prob)
'''

W3_BN = tf.Variable(tf.random_normal([1024, 512], stddev=0.01))
L3_BN = tf.matmul(L2_BN, W3_BN)
batch_mean3, batch_var3 = tf.nn.moments(L3_BN,[0])
scale3 = tf.Variable(tf.ones([512]))
beta3 = tf.Variable(tf.zeros([512]))
BN3 = tf.nn.batch_normalization(L3_BN, batch_mean3, batch_var3, beta3, scale3, epsilon)
L3_BN = tf.nn.relu(BN3)
L3_BN = tf.nn.dropout(L3_BN, keep_prob)

'''
W4 = tf.Variable(tf.random_normal([512, 256], stddev=0.01))
#W3 = tf.get_variable("W3", shape=[512, 256], initializer=tf.contrib.layers.variance_scaling_initializer())
B4 = tf.Variable(tf.random_normal(shape=[256], stddev=0.01))
L4 = tf.nn.relu(tf.matmul(L3, W4)+B4)
L4 = tf.nn.dropout(L4, keep_prob)
'''

W4_BN = tf.Variable(tf.random_normal([512, 256], stddev=0.01))
L4_BN = tf.matmul(L3_BN, W4_BN)
batch_mean4, batch_var4 = tf.nn.moments(L4_BN,[0])
scale4 = tf.Variable(tf.ones([256]))
beta4 = tf.Variable(tf.zeros([256]))
BN4 = tf.nn.batch_normalization(L4_BN, batch_mean4, batch_var4, beta4, scale4, epsilon)
L4_BN = tf.nn.relu(BN4)
L4_BN = tf.nn.dropout(L4_BN, keep_prob)

'''
W5 = tf.Variable(tf.random_normal([256, 10], stddev=0.01))
#W4 = tf.get_variable("W4", shape=[256, 10], initializer=tf.contrib.layers.variance_scaling_initializer())
B5 = tf.Variable(tf.random_normal(shape=[10], stddev=0.01))
model = tf.nn.softmax(tf.matmul(L4,W5)+B5)
'''

W5_BN = tf.Variable(tf.random_normal([256, 10], stddev=0.01))
L5_BN = tf.matmul(L4_BN, W5_BN)
batch_mean5, batch_var5 = tf.nn.moments(L5_BN,[0])
scale5 = tf.Variable(tf.ones([10]))
beta5 = tf.Variable(tf.zeros([10]))
BN5 = tf.nn.batch_normalization(L5_BN, batch_mean5, batch_var5, beta5, scale5, epsilon)
model = tf.nn.softmax(BN5)

#cost function and optimizer
cost = tf.reduce_mean(-tf.reduce_sum(Y * tf.log(tf.clip_by_value(model, 1e-10,1.0)), [1]))
optimizer = tf.train.AdamOptimizer(0.001).minimize(cost)

init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

#set up for minibatch
batch_size=100
total_batch= int(mnist.train.num_examples/batch_size) 

#set up for accuracy
is_correct = tf.equal(tf.argmax(model,1), tf.argmax(Y,1))
accuracy = tf.reduce_mean(tf.cast(is_correct, tf.float32))

#training
for epoch in range(30):
    total_cost = 0
    
    for i in range(total_batch):
        batch_xs, batch_ys = mnist.train.next_batch(batch_size)
        #_, cost_val = sess.run([optimizer, cost], feed_dict={X: batch_xs, Y: batch_ys})
        #total_cost += cost_val
        _, cost_val = sess.run([optimizer, cost], feed_dict={X: batch_xs, Y: batch_ys, keep_prob: 0.5})
        total_cost += cost_val
        
        #print('Epoch:', '%04d' % (epoch + 1), 'Avg. cost =', '{:.3f}'.format(total_cost / total_batch), 
              #'Train Acc. =', sess.run(accuracy, feed_dict={X: mnist.train.images, Y: mnist.train.labels}))
        print('Epoch:', '%04d' % (epoch + 1), 'Avg. cost =', '{:.3f}'.format(total_cost / total_batch), 'Train Acc. =', sess.run(accuracy, feed_dict={X: mnist.train.images, Y: mnist.train.labels, keep_prob: 1.0}))

#print("Training Done")
#print("Test Acc.=", sess.run(accuracy, feed_dict={X: mnist.test.images, Y: mnist.test.labels}))
        
print('Training Done!')
print('Test Acc. = ', sess.run(accuracy, feed_dict={X: mnist.test.images, Y: mnist.test.labels, keep_prob: 1.0}))
# Out:
# WARNING:tensorflow:From <ipython-input-2-9fb3cacc1514>:19: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch: 0001 Avg. cost = 0.004 Train Acc. = 0.5282182
# Epoch: 0001 Avg. cost = 0.008 Train Acc. = 0.6317273
# Epoch: 0001 Avg. cost = 0.012 Train Acc. = 0.6678
# Epoch: 0001 Avg. cost = 0.016 Train Acc. = 0.6816364
# Epoch: 0001 Avg. cost = 0.020 Train Acc. = 0.7006909
# Epoch: 0001 Avg. cost = 0.023 Train Acc. = 0.7132546
# Epoch: 0001 Avg. cost = 0.027 Train Acc. = 0.71885455
# Epoch: 0001 Avg. cost = 0.030 Train Acc. = 0.7237091
# Epoch: 0001 Avg. cost = 0.033 Train Acc. = 0.72803634
# Epoch: 0001 Avg. cost = 0.036 Train Acc. = 0.73292726
# Epoch: 0001 Avg. cost = 0.039 Train Acc. = 0.7405818
# Epoch: 0001 Avg. cost = 0.041 Train Acc. = 0.7441818
# Epoch: 0001 Avg. cost = 0.044 Train Acc. = 0.74832726
# Epoch: 0001 Avg. cost = 0.046 Train Acc. = 0.75363636
# Epoch: 0001 Avg. cost = 0.049 Train Acc. = 0.7638364
# Epoch: 0001 Avg. cost = 0.051 Train Acc. = 0.7759454
# Epoch: 0001 Avg. cost = 0.053 Train Acc. = 0.7902
# Epoch: 0001 Avg. cost = 0.056 Train Acc. = 0.80176365
# Epoch: 0001 Avg. cost = 0.058 Train Acc. = 0.80865455
# Epoch: 0001 Avg. cost = 0.060 Train Acc. = 0.8149091
# Epoch: 0001 Avg. cost = 0.062 Train Acc. = 0.81987274
# Epoch: 0001 Avg. cost = 0.063 Train Acc. = 0.82536364
# Epoch: 0001 Avg. cost = 0.065 Train Acc. = 0.8298
# Epoch: 0001 Avg. cost = 0.067 Train Acc. = 0.83672726
# Epoch: 0001 Avg. cost = 0.068 Train Acc. = 0.84105456
# Epoch: 0001 Avg. cost = 0.070 Train Acc. = 0.84565455
# Epoch: 0001 Avg. cost = 0.071 Train Acc. = 0.85147274
# Epoch: 0001 Avg. cost = 0.073 Train Acc. = 0.8589454
# Epoch: 0001 Avg. cost = 0.074 Train Acc. = 0.8665636
# Epoch: 0001 Avg. cost = 0.075 Train Acc. = 0.8737091
# Epoch: 0001 Avg. cost = 0.076 Train Acc. = 0.87823635
# Epoch: 0001 Avg. cost = 0.078 Train Acc. = 0.8820182
# Epoch: 0001 Avg. cost = 0.079 Train Acc. = 0.88641816
# Epoch: 0001 Avg. cost = 0.080 Train Acc. = 0.8904909
# Epoch: 0001 Avg. cost = 0.081 Train Acc. = 0.8943273
# Epoch: 0001 Avg. cost = 0.083 Train Acc. = 0.8986
# Epoch: 0001 Avg. cost = 0.084 Train Acc. = 0.90145457
# Epoch: 0001 Avg. cost = 0.085 Train Acc. = 0.90294546
# Epoch: 0001 Avg. cost = 0.086 Train Acc. = 0.90450907
# Epoch: 0001 Avg. cost = 0.087 Train Acc. = 0.9055455
# Epoch: 0001 Avg. cost = 0.088 Train Acc. = 0.9075636
# Epoch: 0001 Avg. cost = 0.089 Train Acc. = 0.9100182
# Epoch: 0001 Avg. cost = 0.090 Train Acc. = 0.9134909
# Epoch: 0001 Avg. cost = 0.091 Train Acc. = 0.9166
# Epoch: 0001 Avg. cost = 0.092 Train Acc. = 0.9194
# Epoch: 0001 Avg. cost = 0.093 Train Acc. = 0.92021817
# Epoch: 0001 Avg. cost = 0.094 Train Acc. = 0.91867274
# Epoch: 0001 Avg. cost = 0.094 Train Acc. = 0.9163455
# Epoch: 0001 Avg. cost = 0.095 Train Acc. = 0.9144
# Epoch: 0001 Avg. cost = 0.096 Train Acc. = 0.9143818
# Epoch: 0001 Avg. cost = 0.097 Train Acc. = 0.9146909
# Epoch: 0001 Avg. cost = 0.098 Train Acc. = 0.9169273
# Epoch: 0001 Avg. cost = 0.099 Train Acc. = 0.9186
# Epoch: 0001 Avg. cost = 0.099 Train Acc. = 0.92063636
# Epoch: 0001 Avg. cost = 0.100 Train Acc. = 0.92254543
# Epoch: 0001 Avg. cost = 0.101 Train Acc. = 0.9232909
# Epoch: 0001 Avg. cost = 0.101 Train Acc. = 0.92392725
# Epoch: 0001 Avg. cost = 0.102 Train Acc. = 0.9238909
# Epoch: 0001 Avg. cost = 0.103 Train Acc. = 0.92414546
# Epoch: 0001 Avg. cost = 0.104 Train Acc. = 0.92496365
# Epoch: 0001 Avg. cost = 0.104 Train Acc. = 0.9252727
# Epoch: 0001 Avg. cost = 0.105 Train Acc. = 0.9252545
# Epoch: 0001 Avg. cost = 0.106 Train Acc. = 0.9260909
# Epoch: 0001 Avg. cost = 0.107 Train Acc. = 0.9272909
# Epoch: 0001 Avg. cost = 0.107 Train Acc. = 0.92767274
# Epoch: 0001 Avg. cost = 0.108 Train Acc. = 0.9282182
# Epoch: 0001 Avg. cost = 0.109 Train Acc. = 0.92841816
# Epoch: 0001 Avg. cost = 0.109 Train Acc. = 0.9282182
# Epoch: 0001 Avg. cost = 0.110 Train Acc. = 0.9270727
# Epoch: 0001 Avg. cost = 0.111 Train Acc. = 0.9256727
# Epoch: 0001 Avg. cost = 0.112 Train Acc. = 0.92385453
# Epoch: 0001 Avg. cost = 0.112 Train Acc. = 0.92234546
# Epoch: 0001 Avg. cost = 0.113 Train Acc. = 0.92185456
# Epoch: 0001 Avg. cost = 0.114 Train Acc. = 0.92274547
# Epoch: 0001 Avg. cost = 0.115 Train Acc. = 0.92216367
# Epoch: 0001 Avg. cost = 0.115 Train Acc. = 0.9204
# Epoch: 0001 Avg. cost = 0.116 Train Acc. = 0.9169091
# Epoch: 0001 Avg. cost = 0.117 Train Acc. = 0.91285455
# Epoch: 0001 Avg. cost = 0.118 Train Acc. = 0.9129818
# Epoch: 0001 Avg. cost = 0.119 Train Acc. = 0.9150182
# Epoch: 0001 Avg. cost = 0.119 Train Acc. = 0.9168909
# Epoch: 0001 Avg. cost = 0.120 Train Acc. = 0.91916364
# Epoch: 0001 Avg. cost = 0.121 Train Acc. = 0.9217273
# Epoch: 0001 Avg. cost = 0.121 Train Acc. = 0.92343634
# Epoch: 0001 Avg. cost = 0.122 Train Acc. = 0.92596364
# Epoch: 0001 Avg. cost = 0.123 Train Acc. = 0.9261091
# Epoch: 0001 Avg. cost = 0.123 Train Acc. = 0.9266
# Epoch: 0001 Avg. cost = 0.124 Train Acc. = 0.9265636
# Epoch: 0001 Avg. cost = 0.125 Train Acc. = 0.9285091
# Epoch: 0001 Avg. cost = 0.126 Train Acc. = 0.93072724
# Epoch: 0001 Avg. cost = 0.126 Train Acc. = 0.9322
# Epoch: 0001 Avg. cost = 0.127 Train Acc. = 0.93343633
# Epoch: 0001 Avg. cost = 0.128 Train Acc. = 0.9344182
# Epoch: 0001 Avg. cost = 0.128 Train Acc. = 0.9346
# Epoch: 0001 Avg. cost = 0.129 Train Acc. = 0.9339455
# Epoch: 0001 Avg. cost = 0.129 Train Acc. = 0.9339455
# Epoch: 0001 Avg. cost = 0.130 Train Acc. = 0.93274546
# Epoch: 0001 Avg. cost = 0.130 Train Acc. = 0.9312364
# Epoch: 0001 Avg. cost = 0.130 Train Acc. = 0.9299818
# Epoch: 0001 Avg. cost = 0.131 Train Acc. = 0.9304182
# Epoch: 0001 Avg. cost = 0.132 Train Acc. = 0.9313818
# Epoch: 0001 Avg. cost = 0.132 Train Acc. = 0.9327091
# Epoch: 0001 Avg. cost = 0.133 Train Acc. = 0.9331818
# Epoch: 0001 Avg. cost = 0.133 Train Acc. = 0.9327273
# Epoch: 0001 Avg. cost = 0.134 Train Acc. = 0.93256366
# Epoch: 0001 Avg. cost = 0.135 Train Acc. = 0.9329818
# Epoch: 0001 Avg. cost = 0.135 Train Acc. = 0.9337818
# Epoch: 0001 Avg. cost = 0.136 Train Acc. = 0.9349091
# Epoch: 0001 Avg. cost = 0.137 Train Acc. = 0.9367091
# Epoch: 0001 Avg. cost = 0.137 Train Acc. = 0.9374909
# Epoch: 0001 Avg. cost = 0.138 Train Acc. = 0.93781817
# Epoch: 0001 Avg. cost = 0.139 Train Acc. = 0.93774545
# Epoch: 0001 Avg. cost = 0.139 Train Acc. = 0.9377818
# Epoch: 0001 Avg. cost = 0.140 Train Acc. = 0.93807274
# Epoch: 0001 Avg. cost = 0.140 Train Acc. = 0.9383091
# Epoch: 0001 Avg. cost = 0.141 Train Acc. = 0.93847275
# Epoch: 0001 Avg. cost = 0.142 Train Acc. = 0.9385273
# Epoch: 0001 Avg. cost = 0.142 Train Acc. = 0.9385091
# Epoch: 0001 Avg. cost = 0.143 Train Acc. = 0.9392727
# Epoch: 0001 Avg. cost = 0.143 Train Acc. = 0.93896365
# Epoch: 0001 Avg. cost = 0.143 Train Acc. = 0.9392909
# Epoch: 0001 Avg. cost = 0.144 Train Acc. = 0.9394
# Epoch: 0001 Avg. cost = 0.145 Train Acc. = 0.9398364
# Epoch: 0001 Avg. cost = 0.145 Train Acc. = 0.93972725
# Epoch: 0001 Avg. cost = 0.146 Train Acc. = 0.9396909
# Epoch: 0001 Avg. cost = 0.147 Train Acc. = 0.9392909
# Epoch: 0001 Avg. cost = 0.148 Train Acc. = 0.9392727
# Epoch: 0001 Avg. cost = 0.148 Train Acc. = 0.94027275
# Epoch: 0001 Avg. cost = 0.149 Train Acc. = 0.9409091
# Epoch: 0001 Avg. cost = 0.150 Train Acc. = 0.9421273
# Epoch: 0001 Avg. cost = 0.150 Train Acc. = 0.9439273
# Epoch: 0001 Avg. cost = 0.151 Train Acc. = 0.9445091
# Epoch: 0001 Avg. cost = 0.151 Train Acc. = 0.94463634
# Epoch: 0001 Avg. cost = 0.152 Train Acc. = 0.9458
# Epoch: 0001 Avg. cost = 0.153 Train Acc. = 0.9457091
# Epoch: 0001 Avg. cost = 0.153 Train Acc. = 0.94485456
# Epoch: 0001 Avg. cost = 0.154 Train Acc. = 0.9451454
# Epoch: 0001 Avg. cost = 0.155 Train Acc. = 0.94552726
# Epoch: 0001 Avg. cost = 0.155 Train Acc. = 0.94583637
# Epoch: 0001 Avg. cost = 0.156 Train Acc. = 0.9458182
# Epoch: 0001 Avg. cost = 0.156 Train Acc. = 0.9448
# Epoch: 0001 Avg. cost = 0.157 Train Acc. = 0.9442545
# Epoch: 0001 Avg. cost = 0.157 Train Acc. = 0.9439818
# Epoch: 0001 Avg. cost = 0.158 Train Acc. = 0.94354546
# Epoch: 0001 Avg. cost = 0.158 Train Acc. = 0.9426909
# Epoch: 0001 Avg. cost = 0.159 Train Acc. = 0.94143635
# Epoch: 0001 Avg. cost = 0.159 Train Acc. = 0.9396182
# Epoch: 0001 Avg. cost = 0.160 Train Acc. = 0.9390182
# Epoch: 0001 Avg. cost = 0.161 Train Acc. = 0.93816364
# Epoch: 0001 Avg. cost = 0.161 Train Acc. = 0.9382
# Epoch: 0001 Avg. cost = 0.162 Train Acc. = 0.9386727
# Epoch: 0001 Avg. cost = 0.162 Train Acc. = 0.9392545
# Epoch: 0001 Avg. cost = 0.163 Train Acc. = 0.93994546
# Epoch: 0001 Avg. cost = 0.164 Train Acc. = 0.9407455
# Epoch: 0001 Avg. cost = 0.164 Train Acc. = 0.94165456
# Epoch: 0001 Avg. cost = 0.165 Train Acc. = 0.9430182
# Epoch: 0001 Avg. cost = 0.166 Train Acc. = 0.94461817
# Epoch: 0001 Avg. cost = 0.166 Train Acc. = 0.94609094
# Epoch: 0001 Avg. cost = 0.167 Train Acc. = 0.9472909
# Epoch: 0001 Avg. cost = 0.167 Train Acc. = 0.94798183
# Epoch: 0001 Avg. cost = 0.168 Train Acc. = 0.9487091
# Epoch: 0001 Avg. cost = 0.168 Train Acc. = 0.9488
# Epoch: 0001 Avg. cost = 0.169 Train Acc. = 0.9489273
# Epoch: 0001 Avg. cost = 0.169 Train Acc. = 0.94796365
# Epoch: 0001 Avg. cost = 0.170 Train Acc. = 0.9478545
# Epoch: 0001 Avg. cost = 0.171 Train Acc. = 0.94789094
# Epoch: 0001 Avg. cost = 0.171 Train Acc. = 0.9473818
# Epoch: 0001 Avg. cost = 0.172 Train Acc. = 0.9474
# Epoch: 0001 Avg. cost = 0.173 Train Acc. = 0.94723636
# Epoch: 0001 Avg. cost = 0.173 Train Acc. = 0.9470909
# Epoch: 0001 Avg. cost = 0.173 Train Acc. = 0.9471818
# Epoch: 0001 Avg. cost = 0.174 Train Acc. = 0.947
# Epoch: 0001 Avg. cost = 0.175 Train Acc. = 0.94749093
# Epoch: 0001 Avg. cost = 0.175 Train Acc. = 0.9476909
# Epoch: 0001 Avg. cost = 0.175 Train Acc. = 0.94903636
# Epoch: 0001 Avg. cost = 0.176 Train Acc. = 0.94943637
# Epoch: 0001 Avg. cost = 0.176 Train Acc. = 0.9500727
# Epoch: 0001 Avg. cost = 0.177 Train Acc. = 0.95025456
# Epoch: 0001 Avg. cost = 0.177 Train Acc. = 0.9500545
# Epoch: 0001 Avg. cost = 0.177 Train Acc. = 0.9499636
# Epoch: 0001 Avg. cost = 0.178 Train Acc. = 0.9498364
# Epoch: 0001 Avg. cost = 0.178 Train Acc. = 0.9498182
# Epoch: 0001 Avg. cost = 0.178 Train Acc. = 0.9494182
# Epoch: 0001 Avg. cost = 0.179 Train Acc. = 0.94934547
# Epoch: 0001 Avg. cost = 0.180 Train Acc. = 0.94954544
# Epoch: 0001 Avg. cost = 0.180 Train Acc. = 0.9500545
# Epoch: 0001 Avg. cost = 0.181 Train Acc. = 0.9507818
# Epoch: 0001 Avg. cost = 0.181 Train Acc. = 0.9517273
# Epoch: 0001 Avg. cost = 0.182 Train Acc. = 0.9519455
# Epoch: 0001 Avg. cost = 0.182 Train Acc. = 0.9519455
# Epoch: 0001 Avg. cost = 0.183 Train Acc. = 0.9522
# Epoch: 0001 Avg. cost = 0.183 Train Acc. = 0.9515455
# Epoch: 0001 Avg. cost = 0.183 Train Acc. = 0.9512727
# Epoch: 0001 Avg. cost = 0.184 Train Acc. = 0.95065457
# Epoch: 0001 Avg. cost = 0.184 Train Acc. = 0.94912726
# Epoch: 0001 Avg. cost = 0.185 Train Acc. = 0.9487454
# Epoch: 0001 Avg. cost = 0.185 Train Acc. = 0.9480909
# Epoch: 0001 Avg. cost = 0.186 Train Acc. = 0.9474
# Epoch: 0001 Avg. cost = 0.186 Train Acc. = 0.94832724
# Epoch: 0001 Avg. cost = 0.187 Train Acc. = 0.9490727
# Epoch: 0001 Avg. cost = 0.187 Train Acc. = 0.9502364
# Epoch: 0001 Avg. cost = 0.188 Train Acc. = 0.9515273
# Epoch: 0001 Avg. cost = 0.189 Train Acc. = 0.95283633
# Epoch: 0001 Avg. cost = 0.189 Train Acc. = 0.95272726
# Epoch: 0001 Avg. cost = 0.190 Train Acc. = 0.9525818
# Epoch: 0001 Avg. cost = 0.190 Train Acc. = 0.9530182
# Epoch: 0001 Avg. cost = 0.191 Train Acc. = 0.95283633
# Epoch: 0001 Avg. cost = 0.191 Train Acc. = 0.9532909
# Epoch: 0001 Avg. cost = 0.191 Train Acc. = 0.95338184
# Epoch: 0001 Avg. cost = 0.192 Train Acc. = 0.95336366
# Epoch: 0001 Avg. cost = 0.192 Train Acc. = 0.95287275
# Epoch: 0001 Avg. cost = 0.193 Train Acc. = 0.9530182
# Epoch: 0001 Avg. cost = 0.194 Train Acc. = 0.953
# Epoch: 0001 Avg. cost = 0.194 Train Acc. = 0.9526909
# Epoch: 0001 Avg. cost = 0.194 Train Acc. = 0.95232725
# Epoch: 0001 Avg. cost = 0.195 Train Acc. = 0.9525818
# Epoch: 0001 Avg. cost = 0.196 Train Acc. = 0.9526
# Epoch: 0001 Avg. cost = 0.196 Train Acc. = 0.95263636
# Epoch: 0001 Avg. cost = 0.196 Train Acc. = 0.95289093
# Epoch: 0001 Avg. cost = 0.197 Train Acc. = 0.95296365
# Epoch: 0001 Avg. cost = 0.197 Train Acc. = 0.95234543
# Epoch: 0001 Avg. cost = 0.198 Train Acc. = 0.9515273
# Epoch: 0001 Avg. cost = 0.198 Train Acc. = 0.9518727
# Epoch: 0001 Avg. cost = 0.199 Train Acc. = 0.95196366
# Epoch: 0001 Avg. cost = 0.199 Train Acc. = 0.9521273
# Epoch: 0001 Avg. cost = 0.200 Train Acc. = 0.9526727
# Epoch: 0001 Avg. cost = 0.200 Train Acc. = 0.95272726
# Epoch: 0001 Avg. cost = 0.201 Train Acc. = 0.9533091
# Epoch: 0001 Avg. cost = 0.201 Train Acc. = 0.95347273
# Epoch: 0001 Avg. cost = 0.201 Train Acc. = 0.9529273
# Epoch: 0001 Avg. cost = 0.202 Train Acc. = 0.95338184
# Epoch: 0001 Avg. cost = 0.203 Train Acc. = 0.9532727
# Epoch: 0001 Avg. cost = 0.203 Train Acc. = 0.9529091
# Epoch: 0001 Avg. cost = 0.204 Train Acc. = 0.9530182
# Epoch: 0001 Avg. cost = 0.205 Train Acc. = 0.95347273
# Epoch: 0001 Avg. cost = 0.205 Train Acc. = 0.9535091
# Epoch: 0001 Avg. cost = 0.205 Train Acc. = 0.95361817
# Epoch: 0001 Avg. cost = 0.206 Train Acc. = 0.9539091
# Epoch: 0001 Avg. cost = 0.206 Train Acc. = 0.95385456
# Epoch: 0001 Avg. cost = 0.206 Train Acc. = 0.9536727
# Epoch: 0001 Avg. cost = 0.207 Train Acc. = 0.9532545
# Epoch: 0001 Avg. cost = 0.207 Train Acc. = 0.95345455
# Epoch: 0001 Avg. cost = 0.208 Train Acc. = 0.9531818
# Epoch: 0001 Avg. cost = 0.208 Train Acc. = 0.9536545
# Epoch: 0001 Avg. cost = 0.209 Train Acc. = 0.9541818
# Epoch: 0001 Avg. cost = 0.209 Train Acc. = 0.9543818
# Epoch: 0001 Avg. cost = 0.210 Train Acc. = 0.9546546
# Epoch: 0001 Avg. cost = 0.210 Train Acc. = 0.955
# Epoch: 0001 Avg. cost = 0.211 Train Acc. = 0.95485455
# Epoch: 0001 Avg. cost = 0.211 Train Acc. = 0.9549091
# Epoch: 0001 Avg. cost = 0.212 Train Acc. = 0.9549818
# Epoch: 0001 Avg. cost = 0.212 Train Acc. = 0.9548727
# Epoch: 0001 Avg. cost = 0.213 Train Acc. = 0.9553273
# Epoch: 0001 Avg. cost = 0.213 Train Acc. = 0.9556
# Epoch: 0001 Avg. cost = 0.213 Train Acc. = 0.9561818
# Epoch: 0001 Avg. cost = 0.214 Train Acc. = 0.95641816
# Epoch: 0001 Avg. cost = 0.214 Train Acc. = 0.9564
# Epoch: 0001 Avg. cost = 0.215 Train Acc. = 0.9562909
# Epoch: 0001 Avg. cost = 0.215 Train Acc. = 0.9564546
# Epoch: 0001 Avg. cost = 0.216 Train Acc. = 0.9563636
# Epoch: 0001 Avg. cost = 0.216 Train Acc. = 0.956
# Epoch: 0001 Avg. cost = 0.217 Train Acc. = 0.9560364
# Epoch: 0001 Avg. cost = 0.217 Train Acc. = 0.95634544
# Epoch: 0001 Avg. cost = 0.218 Train Acc. = 0.9566182
# Epoch: 0001 Avg. cost = 0.218 Train Acc. = 0.95707273
# Epoch: 0001 Avg. cost = 0.219 Train Acc. = 0.95707273
# Epoch: 0001 Avg. cost = 0.220 Train Acc. = 0.95585454
# Epoch: 0001 Avg. cost = 0.220 Train Acc. = 0.9544727
# Epoch: 0001 Avg. cost = 0.221 Train Acc. = 0.95356363
# Epoch: 0001 Avg. cost = 0.221 Train Acc. = 0.95232725
# Epoch: 0001 Avg. cost = 0.221 Train Acc. = 0.95156366
# Epoch: 0001 Avg. cost = 0.222 Train Acc. = 0.9505636
# Epoch: 0001 Avg. cost = 0.222 Train Acc. = 0.9500909
# Epoch: 0001 Avg. cost = 0.222 Train Acc. = 0.9497273
# Epoch: 0001 Avg. cost = 0.223 Train Acc. = 0.9492364
# Epoch: 0001 Avg. cost = 0.223 Train Acc. = 0.94978184
# Epoch: 0001 Avg. cost = 0.224 Train Acc. = 0.9508
# Epoch: 0001 Avg. cost = 0.224 Train Acc. = 0.9514
# Epoch: 0001 Avg. cost = 0.225 Train Acc. = 0.9523818
# Epoch: 0001 Avg. cost = 0.225 Train Acc. = 0.9534364
# Epoch: 0001 Avg. cost = 0.226 Train Acc. = 0.95443636
# Epoch: 0001 Avg. cost = 0.226 Train Acc. = 0.9559636
# Epoch: 0001 Avg. cost = 0.227 Train Acc. = 0.95716363
# Epoch: 0001 Avg. cost = 0.227 Train Acc. = 0.95747274
# Epoch: 0001 Avg. cost = 0.228 Train Acc. = 0.958
# Epoch: 0001 Avg. cost = 0.228 Train Acc. = 0.95754546
# Epoch: 0001 Avg. cost = 0.228 Train Acc. = 0.9571091
# Epoch: 0001 Avg. cost = 0.229 Train Acc. = 0.9568545
# Epoch: 0001 Avg. cost = 0.230 Train Acc. = 0.95663637
# Epoch: 0001 Avg. cost = 0.230 Train Acc. = 0.95736367
# Epoch: 0001 Avg. cost = 0.230 Train Acc. = 0.9580909
# Epoch: 0001 Avg. cost = 0.231 Train Acc. = 0.95870906
# Epoch: 0001 Avg. cost = 0.231 Train Acc. = 0.9592182
# Epoch: 0001 Avg. cost = 0.232 Train Acc. = 0.95983636
# Epoch: 0001 Avg. cost = 0.232 Train Acc. = 0.9602
# Epoch: 0001 Avg. cost = 0.233 Train Acc. = 0.9607091
# Epoch: 0001 Avg. cost = 0.233 Train Acc. = 0.9608909
# Epoch: 0001 Avg. cost = 0.234 Train Acc. = 0.9612
# Epoch: 0001 Avg. cost = 0.234 Train Acc. = 0.96085453
# Epoch: 0001 Avg. cost = 0.234 Train Acc. = 0.96050906
# Epoch: 0001 Avg. cost = 0.235 Train Acc. = 0.96018183
# Epoch: 0001 Avg. cost = 0.235 Train Acc. = 0.9601455
# Epoch: 0001 Avg. cost = 0.236 Train Acc. = 0.9597818
# Epoch: 0001 Avg. cost = 0.236 Train Acc. = 0.95943636
# Epoch: 0001 Avg. cost = 0.237 Train Acc. = 0.9593818
# Epoch: 0001 Avg. cost = 0.237 Train Acc. = 0.95974547
# Epoch: 0001 Avg. cost = 0.237 Train Acc. = 0.96050906
# Epoch: 0001 Avg. cost = 0.238 Train Acc. = 0.9607273
# Epoch: 0001 Avg. cost = 0.238 Train Acc. = 0.96025455
# Epoch: 0001 Avg. cost = 0.239 Train Acc. = 0.96009094
# Epoch: 0001 Avg. cost = 0.239 Train Acc. = 0.95976365
# Epoch: 0001 Avg. cost = 0.240 Train Acc. = 0.95943636
# Epoch: 0001 Avg. cost = 0.240 Train Acc. = 0.95912725
# Epoch: 0001 Avg. cost = 0.241 Train Acc. = 0.9589091
# Epoch: 0001 Avg. cost = 0.241 Train Acc. = 0.9583455
# Epoch: 0001 Avg. cost = 0.241 Train Acc. = 0.9584182
# Epoch: 0001 Avg. cost = 0.242 Train Acc. = 0.95876366
# Epoch: 0001 Avg. cost = 0.242 Train Acc. = 0.9584727
# Epoch: 0001 Avg. cost = 0.242 Train Acc. = 0.95814544
# Epoch: 0001 Avg. cost = 0.243 Train Acc. = 0.95805454
# Epoch: 0001 Avg. cost = 0.243 Train Acc. = 0.9579818
# Epoch: 0001 Avg. cost = 0.244 Train Acc. = 0.9581636
# Epoch: 0001 Avg. cost = 0.244 Train Acc. = 0.95821816
# Epoch: 0001 Avg. cost = 0.245 Train Acc. = 0.9583273
# Epoch: 0001 Avg. cost = 0.245 Train Acc. = 0.9585091
# Epoch: 0001 Avg. cost = 0.246 Train Acc. = 0.95821816
# Epoch: 0001 Avg. cost = 0.246 Train Acc. = 0.95785457
# Epoch: 0001 Avg. cost = 0.246 Train Acc. = 0.95765454
# Epoch: 0001 Avg. cost = 0.247 Train Acc. = 0.95774543
# Epoch: 0001 Avg. cost = 0.247 Train Acc. = 0.95821816
# Epoch: 0001 Avg. cost = 0.247 Train Acc. = 0.95885456
# Epoch: 0001 Avg. cost = 0.248 Train Acc. = 0.9592
# Epoch: 0001 Avg. cost = 0.248 Train Acc. = 0.9599818
# Epoch: 0001 Avg. cost = 0.249 Train Acc. = 0.9599636
# Epoch: 0001 Avg. cost = 0.249 Train Acc. = 0.96085453
# Epoch: 0001 Avg. cost = 0.250 Train Acc. = 0.96098185
# Epoch: 0001 Avg. cost = 0.250 Train Acc. = 0.96090907
# Epoch: 0001 Avg. cost = 0.250 Train Acc. = 0.96056366
# Epoch: 0001 Avg. cost = 0.251 Train Acc. = 0.96018183
# Epoch: 0001 Avg. cost = 0.251 Train Acc. = 0.9596909
# Epoch: 0001 Avg. cost = 0.251 Train Acc. = 0.9597818
# Epoch: 0001 Avg. cost = 0.252 Train Acc. = 0.9602364
# Epoch: 0001 Avg. cost = 0.252 Train Acc. = 0.9605455
# Epoch: 0001 Avg. cost = 0.252 Train Acc. = 0.9607273
# Epoch: 0001 Avg. cost = 0.253 Train Acc. = 0.9608182
# Epoch: 0001 Avg. cost = 0.253 Train Acc. = 0.96114546
# Epoch: 0001 Avg. cost = 0.254 Train Acc. = 0.9612182
# Epoch: 0001 Avg. cost = 0.254 Train Acc. = 0.96212727
# Epoch: 0001 Avg. cost = 0.255 Train Acc. = 0.96265453
# Epoch: 0001 Avg. cost = 0.255 Train Acc. = 0.9630182
# Epoch: 0001 Avg. cost = 0.256 Train Acc. = 0.9634727
# Epoch: 0001 Avg. cost = 0.256 Train Acc. = 0.96363634
# Epoch: 0001 Avg. cost = 0.257 Train Acc. = 0.9637091
# Epoch: 0001 Avg. cost = 0.257 Train Acc. = 0.96369094
# Epoch: 0001 Avg. cost = 0.258 Train Acc. = 0.96363634
# Epoch: 0001 Avg. cost = 0.258 Train Acc. = 0.96354544
# Epoch: 0001 Avg. cost = 0.258 Train Acc. = 0.9633273
# Epoch: 0001 Avg. cost = 0.259 Train Acc. = 0.9636
# Epoch: 0001 Avg. cost = 0.259 Train Acc. = 0.9634727
# Epoch: 0001 Avg. cost = 0.259 Train Acc. = 0.96336365
# Epoch: 0001 Avg. cost = 0.260 Train Acc. = 0.96343637
# Epoch: 0001 Avg. cost = 0.260 Train Acc. = 0.96314543
# Epoch: 0001 Avg. cost = 0.261 Train Acc. = 0.96336365
# Epoch: 0001 Avg. cost = 0.261 Train Acc. = 0.96352726
# Epoch: 0001 Avg. cost = 0.261 Train Acc. = 0.9640727
# Epoch: 0001 Avg. cost = 0.262 Train Acc. = 0.964
# Epoch: 0001 Avg. cost = 0.262 Train Acc. = 0.96392727
# Epoch: 0001 Avg. cost = 0.263 Train Acc. = 0.9638909
# Epoch: 0001 Avg. cost = 0.263 Train Acc. = 0.96392727
# Epoch: 0001 Avg. cost = 0.263 Train Acc. = 0.9636727
# Epoch: 0001 Avg. cost = 0.264 Train Acc. = 0.9631636
# Epoch: 0001 Avg. cost = 0.264 Train Acc. = 0.96296364
# Epoch: 0001 Avg. cost = 0.265 Train Acc. = 0.9626909
# Epoch: 0001 Avg. cost = 0.265 Train Acc. = 0.96198183
# Epoch: 0001 Avg. cost = 0.265 Train Acc. = 0.9616182
# Epoch: 0001 Avg. cost = 0.266 Train Acc. = 0.9619273
# Epoch: 0001 Avg. cost = 0.266 Train Acc. = 0.96212727
# Epoch: 0001 Avg. cost = 0.266 Train Acc. = 0.9625273
# Epoch: 0001 Avg. cost = 0.267 Train Acc. = 0.9629273
# Epoch: 0001 Avg. cost = 0.267 Train Acc. = 0.9639091
# Epoch: 0001 Avg. cost = 0.268 Train Acc. = 0.96450907
# Epoch: 0001 Avg. cost = 0.268 Train Acc. = 0.9648182
# Epoch: 0001 Avg. cost = 0.269 Train Acc. = 0.9651091
# Epoch: 0001 Avg. cost = 0.269 Train Acc. = 0.96532726
# Epoch: 0001 Avg. cost = 0.270 Train Acc. = 0.9653818
# Epoch: 0001 Avg. cost = 0.270 Train Acc. = 0.9655273
# Epoch: 0001 Avg. cost = 0.270 Train Acc. = 0.96507275
# Epoch: 0001 Avg. cost = 0.270 Train Acc. = 0.96494544
# Epoch: 0001 Avg. cost = 0.271 Train Acc. = 0.9651091
# Epoch: 0001 Avg. cost = 0.271 Train Acc. = 0.9647273
# Epoch: 0001 Avg. cost = 0.272 Train Acc. = 0.9641455
# Epoch: 0001 Avg. cost = 0.272 Train Acc. = 0.96476364
# Epoch: 0001 Avg. cost = 0.273 Train Acc. = 0.9649818
# Epoch: 0001 Avg. cost = 0.273 Train Acc. = 0.9651273
# Epoch: 0001 Avg. cost = 0.273 Train Acc. = 0.96549094
# Epoch: 0001 Avg. cost = 0.274 Train Acc. = 0.96592724
# Epoch: 0001 Avg. cost = 0.275 Train Acc. = 0.9656909
# Epoch: 0001 Avg. cost = 0.275 Train Acc. = 0.9653091
# Epoch: 0001 Avg. cost = 0.275 Train Acc. = 0.9645454
# Epoch: 0001 Avg. cost = 0.276 Train Acc. = 0.96427274
# Epoch: 0001 Avg. cost = 0.276 Train Acc. = 0.9634
# Epoch: 0001 Avg. cost = 0.276 Train Acc. = 0.9628
# Epoch: 0001 Avg. cost = 0.277 Train Acc. = 0.9625818
# Epoch: 0001 Avg. cost = 0.277 Train Acc. = 0.9624909
# Epoch: 0001 Avg. cost = 0.278 Train Acc. = 0.96256363
# Epoch: 0001 Avg. cost = 0.278 Train Acc. = 0.9631636
# Epoch: 0001 Avg. cost = 0.278 Train Acc. = 0.96392727
# Epoch: 0001 Avg. cost = 0.279 Train Acc. = 0.96452725
# Epoch: 0001 Avg. cost = 0.279 Train Acc. = 0.96474546
# Epoch: 0001 Avg. cost = 0.279 Train Acc. = 0.9648182
# Epoch: 0001 Avg. cost = 0.279 Train Acc. = 0.9648
# Epoch: 0001 Avg. cost = 0.280 Train Acc. = 0.9649818
# Epoch: 0001 Avg. cost = 0.280 Train Acc. = 0.96592724
# Epoch: 0001 Avg. cost = 0.281 Train Acc. = 0.9660364
# Epoch: 0001 Avg. cost = 0.281 Train Acc. = 0.9661091
# Epoch: 0001 Avg. cost = 0.281 Train Acc. = 0.96592724
# Epoch: 0001 Avg. cost = 0.282 Train Acc. = 0.96583635
# Epoch: 0001 Avg. cost = 0.282 Train Acc. = 0.9657091
# Epoch: 0001 Avg. cost = 0.283 Train Acc. = 0.9658
# Epoch: 0001 Avg. cost = 0.283 Train Acc. = 0.96541816
# Epoch: 0001 Avg. cost = 0.284 Train Acc. = 0.96516365
# Epoch: 0001 Avg. cost = 0.284 Train Acc. = 0.96476364
# Epoch: 0001 Avg. cost = 0.284 Train Acc. = 0.9644182
# Epoch: 0001 Avg. cost = 0.285 Train Acc. = 0.96494544
# Epoch: 0001 Avg. cost = 0.285 Train Acc. = 0.9655091
# Epoch: 0001 Avg. cost = 0.285 Train Acc. = 0.96558183
# Epoch: 0001 Avg. cost = 0.286 Train Acc. = 0.96572727
# Epoch: 0001 Avg. cost = 0.287 Train Acc. = 0.9660182
# Epoch: 0001 Avg. cost = 0.287 Train Acc. = 0.96558183
# Epoch: 0001 Avg. cost = 0.287 Train Acc. = 0.96572727
# Epoch: 0001 Avg. cost = 0.288 Train Acc. = 0.96583635
# Epoch: 0001 Avg. cost = 0.288 Train Acc. = 0.9660909
# Epoch: 0001 Avg. cost = 0.288 Train Acc. = 0.9658909
# Epoch: 0001 Avg. cost = 0.289 Train Acc. = 0.9659455
# Epoch: 0001 Avg. cost = 0.289 Train Acc. = 0.9660909
# Epoch: 0001 Avg. cost = 0.290 Train Acc. = 0.96581817
# Epoch: 0001 Avg. cost = 0.290 Train Acc. = 0.9661091
# Epoch: 0001 Avg. cost = 0.290 Train Acc. = 0.9664182
# Epoch: 0001 Avg. cost = 0.291 Train Acc. = 0.9662909
# Epoch: 0001 Avg. cost = 0.291 Train Acc. = 0.96623635
# Epoch: 0001 Avg. cost = 0.291 Train Acc. = 0.96605456
# Epoch: 0001 Avg. cost = 0.291 Train Acc. = 0.96596366
# Epoch: 0001 Avg. cost = 0.292 Train Acc. = 0.9658545
# Epoch: 0001 Avg. cost = 0.292 Train Acc. = 0.9660182
# Epoch: 0001 Avg. cost = 0.292 Train Acc. = 0.96616364
# Epoch: 0001 Avg. cost = 0.293 Train Acc. = 0.9660364
# Epoch: 0001 Avg. cost = 0.293 Train Acc. = 0.9662182
# Epoch: 0001 Avg. cost = 0.293 Train Acc. = 0.96614546
# Epoch: 0001 Avg. cost = 0.293 Train Acc. = 0.96605456
# Epoch: 0001 Avg. cost = 0.294 Train Acc. = 0.966
# Epoch: 0001 Avg. cost = 0.294 Train Acc. = 0.9664182
# Epoch: 0001 Avg. cost = 0.295 Train Acc. = 0.9669273
# Epoch: 0001 Avg. cost = 0.295 Train Acc. = 0.9674909
# Epoch: 0001 Avg. cost = 0.295 Train Acc. = 0.96787274
# Epoch: 0001 Avg. cost = 0.296 Train Acc. = 0.96805453
# Epoch: 0001 Avg. cost = 0.296 Train Acc. = 0.96803635
# Epoch: 0001 Avg. cost = 0.297 Train Acc. = 0.9678364
# Epoch: 0001 Avg. cost = 0.297 Train Acc. = 0.9674
# Epoch: 0001 Avg. cost = 0.298 Train Acc. = 0.96745455
# Epoch: 0001 Avg. cost = 0.298 Train Acc. = 0.9669273
# Epoch: 0001 Avg. cost = 0.299 Train Acc. = 0.96723634
# Epoch: 0001 Avg. cost = 0.299 Train Acc. = 0.967
# Epoch: 0001 Avg. cost = 0.299 Train Acc. = 0.96674544
# Epoch: 0001 Avg. cost = 0.300 Train Acc. = 0.9665818
# Epoch: 0001 Avg. cost = 0.300 Train Acc. = 0.9662909
# Epoch: 0001 Avg. cost = 0.300 Train Acc. = 0.96645457
# Epoch: 0001 Avg. cost = 0.301 Train Acc. = 0.9663091
# Epoch: 0001 Avg. cost = 0.301 Train Acc. = 0.9660182
# Epoch: 0001 Avg. cost = 0.301 Train Acc. = 0.96616364
# Epoch: 0001 Avg. cost = 0.302 Train Acc. = 0.96647274
# Epoch: 0001 Avg. cost = 0.302 Train Acc. = 0.9666
# Epoch: 0001 Avg. cost = 0.302 Train Acc. = 0.9664182
# Epoch: 0001 Avg. cost = 0.303 Train Acc. = 0.9667636
# Epoch: 0001 Avg. cost = 0.304 Train Acc. = 0.9669818
# Epoch: 0001 Avg. cost = 0.304 Train Acc. = 0.96687275
# Epoch: 0001 Avg. cost = 0.304 Train Acc. = 0.9671091
# Epoch: 0001 Avg. cost = 0.305 Train Acc. = 0.9667818
# Epoch: 0001 Avg. cost = 0.305 Train Acc. = 0.967
# Epoch: 0001 Avg. cost = 0.305 Train Acc. = 0.96687275
# Epoch: 0001 Avg. cost = 0.306 Train Acc. = 0.9663454
# Epoch: 0001 Avg. cost = 0.306 Train Acc. = 0.9662
# Epoch: 0001 Avg. cost = 0.307 Train Acc. = 0.96556365
# Epoch: 0001 Avg. cost = 0.307 Train Acc. = 0.96507275
# Epoch: 0001 Avg. cost = 0.307 Train Acc. = 0.9644727
# Epoch: 0001 Avg. cost = 0.308 Train Acc. = 0.9634
# Epoch: 0001 Avg. cost = 0.308 Train Acc. = 0.9629818
# Epoch: 0001 Avg. cost = 0.309 Train Acc. = 0.96336365
# Epoch: 0001 Avg. cost = 0.309 Train Acc. = 0.9642182
# Epoch: 0001 Avg. cost = 0.310 Train Acc. = 0.96492726
# Epoch: 0001 Avg. cost = 0.310 Train Acc. = 0.9653818
# Epoch: 0001 Avg. cost = 0.310 Train Acc. = 0.9657818
# Epoch: 0001 Avg. cost = 0.311 Train Acc. = 0.96623635
# Epoch: 0001 Avg. cost = 0.311 Train Acc. = 0.96632725
# Epoch: 0001 Avg. cost = 0.311 Train Acc. = 0.9662727
# Epoch: 0001 Avg. cost = 0.312 Train Acc. = 0.9666909
# Epoch: 0001 Avg. cost = 0.312 Train Acc. = 0.9669091
# Epoch: 0001 Avg. cost = 0.312 Train Acc. = 0.96721816
# Epoch: 0001 Avg. cost = 0.313 Train Acc. = 0.96721816
# Epoch: 0001 Avg. cost = 0.313 Train Acc. = 0.96714544
# Epoch: 0001 Avg. cost = 0.314 Train Acc. = 0.9672
# Epoch: 0001 Avg. cost = 0.314 Train Acc. = 0.96714544
# Epoch: 0001 Avg. cost = 0.314 Train Acc. = 0.9673455
# Epoch: 0001 Avg. cost = 0.315 Train Acc. = 0.9672
# Epoch: 0001 Avg. cost = 0.315 Train Acc. = 0.9671091
# Epoch: 0001 Avg. cost = 0.316 Train Acc. = 0.9670727
# Epoch: 0001 Avg. cost = 0.316 Train Acc. = 0.9675273
# Epoch: 0001 Avg. cost = 0.316 Train Acc. = 0.9673091
# Epoch: 0001 Avg. cost = 0.317 Train Acc. = 0.96712726
# Epoch: 0001 Avg. cost = 0.317 Train Acc. = 0.96694547
# Epoch: 0001 Avg. cost = 0.318 Train Acc. = 0.9666182
# Epoch: 0001 Avg. cost = 0.318 Train Acc. = 0.9665091
# Epoch: 0001 Avg. cost = 0.319 Train Acc. = 0.9661273
# Epoch: 0001 Avg. cost = 0.319 Train Acc. = 0.96565455
# Epoch: 0001 Avg. cost = 0.320 Train Acc. = 0.96572727
# Epoch: 0001 Avg. cost = 0.320 Train Acc. = 0.96556365
# Epoch: 0001 Avg. cost = 0.320 Train Acc. = 0.96525455
# Epoch: 0001 Avg. cost = 0.321 Train Acc. = 0.9651273
# Epoch: 0001 Avg. cost = 0.321 Train Acc. = 0.9651091
# Epoch: 0001 Avg. cost = 0.322 Train Acc. = 0.96543634
# Epoch: 0001 Avg. cost = 0.322 Train Acc. = 0.9657636
# Epoch: 0001 Avg. cost = 0.322 Train Acc. = 0.96592724
# Epoch: 0001 Avg. cost = 0.323 Train Acc. = 0.9662909
# Epoch: 0001 Avg. cost = 0.323 Train Acc. = 0.9664364
# Epoch: 0001 Avg. cost = 0.323 Train Acc. = 0.9668546
# Epoch: 0001 Avg. cost = 0.324 Train Acc. = 0.9672727
# Epoch: 0001 Avg. cost = 0.324 Train Acc. = 0.9675636
# Epoch: 0001 Avg. cost = 0.324 Train Acc. = 0.96763635
# Epoch: 0001 Avg. cost = 0.325 Train Acc. = 0.9676545
# Epoch: 0001 Avg. cost = 0.325 Train Acc. = 0.9676
# Epoch: 0001 Avg. cost = 0.325 Train Acc. = 0.9678364
# Epoch: 0001 Avg. cost = 0.325 Train Acc. = 0.9682
# Epoch: 0001 Avg. cost = 0.326 Train Acc. = 0.9685818
# Epoch: 0001 Avg. cost = 0.326 Train Acc. = 0.96892726
# Epoch: 0001 Avg. cost = 0.326 Train Acc. = 0.9689636
# Epoch: 0001 Avg. cost = 0.327 Train Acc. = 0.9694545
# Epoch: 0001 Avg. cost = 0.327 Train Acc. = 0.96976364
# Epoch: 0001 Avg. cost = 0.328 Train Acc. = 0.96985453
# Epoch: 0001 Avg. cost = 0.328 Train Acc. = 0.9697818
# Epoch: 0001 Avg. cost = 0.328 Train Acc. = 0.96956366
# Epoch: 0001 Avg. cost = 0.328 Train Acc. = 0.9697091
# Epoch: 0001 Avg. cost = 0.329 Train Acc. = 0.9700182
# Epoch: 0001 Avg. cost = 0.330 Train Acc. = 0.9702909
# Epoch: 0001 Avg. cost = 0.330 Train Acc. = 0.9706
# Epoch: 0001 Avg. cost = 0.330 Train Acc. = 0.9706
# Epoch: 0001 Avg. cost = 0.331 Train Acc. = 0.9703818
# Epoch: 0001 Avg. cost = 0.331 Train Acc. = 0.97032726
# Epoch: 0001 Avg. cost = 0.331 Train Acc. = 0.97032726
# Epoch: 0001 Avg. cost = 0.331 Train Acc. = 0.9699818
# Epoch: 0001 Avg. cost = 0.332 Train Acc. = 0.9697273
# Epoch: 0001 Avg. cost = 0.332 Train Acc. = 0.96976364
# Epoch: 0002 Avg. cost = 0.000 Train Acc. = 0.9697091
# Epoch: 0002 Avg. cost = 0.001 Train Acc. = 0.9693273
# Epoch: 0002 Avg. cost = 0.001 Train Acc. = 0.9692364
# Epoch: 0002 Avg. cost = 0.001 Train Acc. = 0.96916366
# Epoch: 0002 Avg. cost = 0.001 Train Acc. = 0.96901816
# Epoch: 0002 Avg. cost = 0.002 Train Acc. = 0.9689818
# Epoch: 0002 Avg. cost = 0.002 Train Acc. = 0.9690545
# Epoch: 0002 Avg. cost = 0.002 Train Acc. = 0.9693273
# Epoch: 0002 Avg. cost = 0.003 Train Acc. = 0.96976364
# Epoch: 0002 Avg. cost = 0.003 Train Acc. = 0.96994543
# Epoch: 0002 Avg. cost = 0.004 Train Acc. = 0.9700364
# Epoch: 0002 Avg. cost = 0.004 Train Acc. = 0.9700364
# Epoch: 0002 Avg. cost = 0.004 Train Acc. = 0.97016364
# Epoch: 0002 Avg. cost = 0.005 Train Acc. = 0.9701273
# Epoch: 0002 Avg. cost = 0.005 Train Acc. = 0.9706182
# Epoch: 0002 Avg. cost = 0.005 Train Acc. = 0.97105455
# Epoch: 0002 Avg. cost = 0.006 Train Acc. = 0.9709091
# Epoch: 0002 Avg. cost = 0.006 Train Acc. = 0.97074544
# Epoch: 0002 Avg. cost = 0.006 Train Acc. = 0.9708909
# Epoch: 0002 Avg. cost = 0.007 Train Acc. = 0.9708909
# Epoch: 0002 Avg. cost = 0.007 Train Acc. = 0.9706727
# Epoch: 0002 Avg. cost = 0.008 Train Acc. = 0.9705818
# Epoch: 0002 Avg. cost = 0.008 Train Acc. = 0.96985453
# Epoch: 0002 Avg. cost = 0.008 Train Acc. = 0.9694
# Epoch: 0002 Avg. cost = 0.008 Train Acc. = 0.96925455
# Epoch: 0002 Avg. cost = 0.009 Train Acc. = 0.96901816
# Epoch: 0002 Avg. cost = 0.009 Train Acc. = 0.96909094
# Epoch: 0002 Avg. cost = 0.010 Train Acc. = 0.9686546
# Epoch: 0002 Avg. cost = 0.010 Train Acc. = 0.96892726
# Epoch: 0002 Avg. cost = 0.010 Train Acc. = 0.96925455
# Epoch: 0002 Avg. cost = 0.011 Train Acc. = 0.96941817
# Epoch: 0002 Avg. cost = 0.011 Train Acc. = 0.96936363
# Epoch: 0002 Avg. cost = 0.011 Train Acc. = 0.96936363
# Epoch: 0002 Avg. cost = 0.012 Train Acc. = 0.9691091
# Epoch: 0002 Avg. cost = 0.012 Train Acc. = 0.9691091
# Epoch: 0002 Avg. cost = 0.012 Train Acc. = 0.96909094
# Epoch: 0002 Avg. cost = 0.012 Train Acc. = 0.9693091
# Epoch: 0002 Avg. cost = 0.013 Train Acc. = 0.9698909
# Epoch: 0002 Avg. cost = 0.013 Train Acc. = 0.9702909
# Epoch: 0002 Avg. cost = 0.013 Train Acc. = 0.9703091
# Epoch: 0002 Avg. cost = 0.014 Train Acc. = 0.97072726
# Epoch: 0002 Avg. cost = 0.014 Train Acc. = 0.9714182
# Epoch: 0002 Avg. cost = 0.014 Train Acc. = 0.9716182
# Epoch: 0002 Avg. cost = 0.015 Train Acc. = 0.97185457
# Epoch: 0002 Avg. cost = 0.015 Train Acc. = 0.97203636
# Epoch: 0002 Avg. cost = 0.015 Train Acc. = 0.9720909
# Epoch: 0002 Avg. cost = 0.016 Train Acc. = 0.97212726
# Epoch: 0002 Avg. cost = 0.016 Train Acc. = 0.97214544
# Epoch: 0002 Avg. cost = 0.017 Train Acc. = 0.97227275
# Epoch: 0002 Avg. cost = 0.017 Train Acc. = 0.97221816
# Epoch: 0002 Avg. cost = 0.017 Train Acc. = 0.97196364
# Epoch: 0002 Avg. cost = 0.017 Train Acc. = 0.9718364
# Epoch: 0002 Avg. cost = 0.018 Train Acc. = 0.9715273
# Epoch: 0002 Avg. cost = 0.018 Train Acc. = 0.97138184
# Epoch: 0002 Avg. cost = 0.018 Train Acc. = 0.9715273
# Epoch: 0002 Avg. cost = 0.019 Train Acc. = 0.9712
# Epoch: 0002 Avg. cost = 0.019 Train Acc. = 0.9714182
# Epoch: 0002 Avg. cost = 0.019 Train Acc. = 0.97145456
# Epoch: 0002 Avg. cost = 0.019 Train Acc. = 0.9711818
# Epoch: 0002 Avg. cost = 0.020 Train Acc. = 0.9709091
# Epoch: 0002 Avg. cost = 0.020 Train Acc. = 0.9709273
# Epoch: 0002 Avg. cost = 0.020 Train Acc. = 0.9712
# Epoch: 0002 Avg. cost = 0.020 Train Acc. = 0.97114545
# Epoch: 0002 Avg. cost = 0.021 Train Acc. = 0.97132725
# Epoch: 0002 Avg. cost = 0.021 Train Acc. = 0.97147274
# Epoch: 0002 Avg. cost = 0.021 Train Acc. = 0.9716
# Epoch: 0002 Avg. cost = 0.022 Train Acc. = 0.9716182
# Epoch: 0002 Avg. cost = 0.022 Train Acc. = 0.97165453
# Epoch: 0002 Avg. cost = 0.022 Train Acc. = 0.97221816
# Epoch: 0002 Avg. cost = 0.023 Train Acc. = 0.97263634
# Epoch: 0002 Avg. cost = 0.023 Train Acc. = 0.9723091
# Epoch: 0002 Avg. cost = 0.024 Train Acc. = 0.9722546
# Epoch: 0002 Avg. cost = 0.024 Train Acc. = 0.97223634
# Epoch: 0002 Avg. cost = 0.025 Train Acc. = 0.972
# Epoch: 0002 Avg. cost = 0.025 Train Acc. = 0.9718364
# Epoch: 0002 Avg. cost = 0.026 Train Acc. = 0.9716727
# Epoch: 0002 Avg. cost = 0.026 Train Acc. = 0.9714182
# Epoch: 0002 Avg. cost = 0.026 Train Acc. = 0.97156364
# Epoch: 0002 Avg. cost = 0.027 Train Acc. = 0.9712727
# Epoch: 0002 Avg. cost = 0.027 Train Acc. = 0.97114545
# Epoch: 0002 Avg. cost = 0.027 Train Acc. = 0.97098184
# Epoch: 0002 Avg. cost = 0.027 Train Acc. = 0.9706727
# Epoch: 0002 Avg. cost = 0.028 Train Acc. = 0.97047275
# Epoch: 0002 Avg. cost = 0.028 Train Acc. = 0.9704
# Epoch: 0002 Avg. cost = 0.028 Train Acc. = 0.9704
# Epoch: 0002 Avg. cost = 0.028 Train Acc. = 0.9700909
# Epoch: 0002 Avg. cost = 0.029 Train Acc. = 0.9698727
# Epoch: 0002 Avg. cost = 0.029 Train Acc. = 0.96983635
# Epoch: 0002 Avg. cost = 0.029 Train Acc. = 0.96976364
# Epoch: 0002 Avg. cost = 0.030 Train Acc. = 0.9699636
# Epoch: 0002 Avg. cost = 0.030 Train Acc. = 0.9701818
# Epoch: 0002 Avg. cost = 0.030 Train Acc. = 0.97014546
# Epoch: 0002 Avg. cost = 0.031 Train Acc. = 0.9702727
# Epoch: 0002 Avg. cost = 0.031 Train Acc. = 0.97065455
# Epoch: 0002 Avg. cost = 0.031 Train Acc. = 0.9712545
# Epoch: 0002 Avg. cost = 0.031 Train Acc. = 0.97174543
# Epoch: 0002 Avg. cost = 0.032 Train Acc. = 0.972
# Epoch: 0002 Avg. cost = 0.032 Train Acc. = 0.97196364
# Epoch: 0002 Avg. cost = 0.032 Train Acc. = 0.97187275
# Epoch: 0002 Avg. cost = 0.033 Train Acc. = 0.9719091
# Epoch: 0002 Avg. cost = 0.033 Train Acc. = 0.97196364
# Epoch: 0002 Avg. cost = 0.033 Train Acc. = 0.9719818
# Epoch: 0002 Avg. cost = 0.034 Train Acc. = 0.97185457
# Epoch: 0002 Avg. cost = 0.034 Train Acc. = 0.9717636
# Epoch: 0002 Avg. cost = 0.034 Train Acc. = 0.97130907
# Epoch: 0002 Avg. cost = 0.034 Train Acc. = 0.97116363
# Epoch: 0002 Avg. cost = 0.035 Train Acc. = 0.9706909
# Epoch: 0002 Avg. cost = 0.035 Train Acc. = 0.9708909
# Epoch: 0002 Avg. cost = 0.035 Train Acc. = 0.9715273
# Epoch: 0002 Avg. cost = 0.035 Train Acc. = 0.97185457
# Epoch: 0002 Avg. cost = 0.035 Train Acc. = 0.97245455
# Epoch: 0002 Avg. cost = 0.036 Train Acc. = 0.9729091
# Epoch: 0002 Avg. cost = 0.036 Train Acc. = 0.9732364
# Epoch: 0002 Avg. cost = 0.036 Train Acc. = 0.9733818
# Epoch: 0002 Avg. cost = 0.036 Train Acc. = 0.9734
# Epoch: 0002 Avg. cost = 0.037 Train Acc. = 0.97301817
# Epoch: 0002 Avg. cost = 0.037 Train Acc. = 0.9727273
# Epoch: 0002 Avg. cost = 0.037 Train Acc. = 0.9726
# Epoch: 0002 Avg. cost = 0.038 Train Acc. = 0.9722546
# Epoch: 0002 Avg. cost = 0.038 Train Acc. = 0.97214544
# Epoch: 0002 Avg. cost = 0.038 Train Acc. = 0.9726
# Epoch: 0002 Avg. cost = 0.039 Train Acc. = 0.9727273
# Epoch: 0002 Avg. cost = 0.039 Train Acc. = 0.97243637
# Epoch: 0002 Avg. cost = 0.039 Train Acc. = 0.9727455
# Epoch: 0002 Avg. cost = 0.040 Train Acc. = 0.9729818
# Epoch: 0002 Avg. cost = 0.040 Train Acc. = 0.973
# Epoch: 0002 Avg. cost = 0.040 Train Acc. = 0.973
# Epoch: 0002 Avg. cost = 0.040 Train Acc. = 0.9728909
# Epoch: 0002 Avg. cost = 0.041 Train Acc. = 0.97312725
# Epoch: 0002 Avg. cost = 0.041 Train Acc. = 0.97285455
# Epoch: 0002 Avg. cost = 0.041 Train Acc. = 0.9727273
# Epoch: 0002 Avg. cost = 0.041 Train Acc. = 0.9724909
# Epoch: 0002 Avg. cost = 0.042 Train Acc. = 0.9724909
# Epoch: 0002 Avg. cost = 0.042 Train Acc. = 0.9718182
# Epoch: 0002 Avg. cost = 0.043 Train Acc. = 0.9716727
# Epoch: 0002 Avg. cost = 0.043 Train Acc. = 0.97132725
# Epoch: 0002 Avg. cost = 0.043 Train Acc. = 0.9712909
# Epoch: 0002 Avg. cost = 0.044 Train Acc. = 0.9716909
# Epoch: 0002 Avg. cost = 0.044 Train Acc. = 0.97229093
# Epoch: 0002 Avg. cost = 0.044 Train Acc. = 0.9726
# Epoch: 0002 Avg. cost = 0.045 Train Acc. = 0.9728
# Epoch: 0002 Avg. cost = 0.045 Train Acc. = 0.9733273
# Epoch: 0002 Avg. cost = 0.046 Train Acc. = 0.9736182
# Epoch: 0002 Avg. cost = 0.046 Train Acc. = 0.97376364
# Epoch: 0002 Avg. cost = 0.046 Train Acc. = 0.9738727
# Epoch: 0002 Avg. cost = 0.047 Train Acc. = 0.97376364
# Epoch: 0002 Avg. cost = 0.047 Train Acc. = 0.97401816
# Epoch: 0002 Avg. cost = 0.047 Train Acc. = 0.97409093
# Epoch: 0002 Avg. cost = 0.048 Train Acc. = 0.974
# Epoch: 0002 Avg. cost = 0.048 Train Acc. = 0.9739091
# Epoch: 0002 Avg. cost = 0.049 Train Acc. = 0.9738
# Epoch: 0002 Avg. cost = 0.049 Train Acc. = 0.9734182
# Epoch: 0002 Avg. cost = 0.049 Train Acc. = 0.9732182
# Epoch: 0002 Avg. cost = 0.050 Train Acc. = 0.97312725
# Epoch: 0002 Avg. cost = 0.050 Train Acc. = 0.9726909
# Epoch: 0002 Avg. cost = 0.050 Train Acc. = 0.97276366
# Epoch: 0002 Avg. cost = 0.051 Train Acc. = 0.9724182
# Epoch: 0002 Avg. cost = 0.051 Train Acc. = 0.9721636
# Epoch: 0002 Avg. cost = 0.052 Train Acc. = 0.9725091
# Epoch: 0002 Avg. cost = 0.052 Train Acc. = 0.9723273
# Epoch: 0002 Avg. cost = 0.052 Train Acc. = 0.9723273
# Epoch: 0002 Avg. cost = 0.052 Train Acc. = 0.9726545
# Epoch: 0002 Avg. cost = 0.053 Train Acc. = 0.97261816
# Epoch: 0002 Avg. cost = 0.053 Train Acc. = 0.97261816
# Epoch: 0002 Avg. cost = 0.053 Train Acc. = 0.97296363
# Epoch: 0002 Avg. cost = 0.053 Train Acc. = 0.9728364
# Epoch: 0002 Avg. cost = 0.054 Train Acc. = 0.97245455
# Epoch: 0002 Avg. cost = 0.054 Train Acc. = 0.97245455
# Epoch: 0002 Avg. cost = 0.055 Train Acc. = 0.9724727
# Epoch: 0002 Avg. cost = 0.055 Train Acc. = 0.9723455
# Epoch: 0002 Avg. cost = 0.056 Train Acc. = 0.97203636
# Epoch: 0002 Avg. cost = 0.056 Train Acc. = 0.97172725
# Epoch: 0002 Avg. cost = 0.056 Train Acc. = 0.9717091
# Epoch: 0002 Avg. cost = 0.056 Train Acc. = 0.97187275
# Epoch: 0002 Avg. cost = 0.057 Train Acc. = 0.9721818
# Epoch: 0002 Avg. cost = 0.057 Train Acc. = 0.97212726
# Epoch: 0002 Avg. cost = 0.057 Train Acc. = 0.97276366
# Epoch: 0002 Avg. cost = 0.057 Train Acc. = 0.9729091
# Epoch: 0002 Avg. cost = 0.058 Train Acc. = 0.9733091
# Epoch: 0002 Avg. cost = 0.058 Train Acc. = 0.97376364
# Epoch: 0002 Avg. cost = 0.058 Train Acc. = 0.9736909
# Epoch: 0002 Avg. cost = 0.059 Train Acc. = 0.97407275
# Epoch: 0002 Avg. cost = 0.059 Train Acc. = 0.9742182
# Epoch: 0002 Avg. cost = 0.059 Train Acc. = 0.97418183
# Epoch: 0002 Avg. cost = 0.060 Train Acc. = 0.97403634
# Epoch: 0002 Avg. cost = 0.060 Train Acc. = 0.9739636
# Epoch: 0002 Avg. cost = 0.060 Train Acc. = 0.9736182
# Epoch: 0002 Avg. cost = 0.060 Train Acc. = 0.9738
# Epoch: 0002 Avg. cost = 0.061 Train Acc. = 0.97385454
# Epoch: 0002 Avg. cost = 0.061 Train Acc. = 0.9736364
# Epoch: 0002 Avg. cost = 0.061 Train Acc. = 0.9735636
# Epoch: 0002 Avg. cost = 0.061 Train Acc. = 0.9735818
# Epoch: 0002 Avg. cost = 0.062 Train Acc. = 0.9736909
# Epoch: 0002 Avg. cost = 0.062 Train Acc. = 0.97401816
# Epoch: 0002 Avg. cost = 0.063 Train Acc. = 0.9743818
# Epoch: 0002 Avg. cost = 0.063 Train Acc. = 0.9746
# Epoch: 0002 Avg. cost = 0.063 Train Acc. = 0.97467273
# Epoch: 0002 Avg. cost = 0.063 Train Acc. = 0.9748727
# Epoch: 0002 Avg. cost = 0.063 Train Acc. = 0.97525454
# Epoch: 0002 Avg. cost = 0.064 Train Acc. = 0.9754
# Epoch: 0002 Avg. cost = 0.064 Train Acc. = 0.9756909
# Epoch: 0002 Avg. cost = 0.064 Train Acc. = 0.97574544
# Epoch: 0002 Avg. cost = 0.065 Train Acc. = 0.97581816
# Epoch: 0002 Avg. cost = 0.065 Train Acc. = 0.97605455
# Epoch: 0002 Avg. cost = 0.065 Train Acc. = 0.9759273
# Epoch: 0002 Avg. cost = 0.066 Train Acc. = 0.9757818
# Epoch: 0002 Avg. cost = 0.066 Train Acc. = 0.9756182
# Epoch: 0002 Avg. cost = 0.066 Train Acc. = 0.97532725
# Epoch: 0002 Avg. cost = 0.066 Train Acc. = 0.97514546
# Epoch: 0002 Avg. cost = 0.067 Train Acc. = 0.9750909
# Epoch: 0002 Avg. cost = 0.067 Train Acc. = 0.97476363
# Epoch: 0002 Avg. cost = 0.068 Train Acc. = 0.97483635
# Epoch: 0002 Avg. cost = 0.068 Train Acc. = 0.97474545
# Epoch: 0002 Avg. cost = 0.068 Train Acc. = 0.97476363
# Epoch: 0002 Avg. cost = 0.069 Train Acc. = 0.97443634
# Epoch: 0002 Avg. cost = 0.069 Train Acc. = 0.9742909
# Epoch: 0002 Avg. cost = 0.069 Train Acc. = 0.9742727
# Epoch: 0002 Avg. cost = 0.070 Train Acc. = 0.97423637
# Epoch: 0002 Avg. cost = 0.070 Train Acc. = 0.9743818
# Epoch: 0002 Avg. cost = 0.070 Train Acc. = 0.9747091
# Epoch: 0002 Avg. cost = 0.071 Train Acc. = 0.97481817
# Epoch: 0002 Avg. cost = 0.071 Train Acc. = 0.97476363
# Epoch: 0002 Avg. cost = 0.071 Train Acc. = 0.97467273
# Epoch: 0002 Avg. cost = 0.071 Train Acc. = 0.9744545
# Epoch: 0002 Avg. cost = 0.072 Train Acc. = 0.97443634
# Epoch: 0002 Avg. cost = 0.072 Train Acc. = 0.9742
# Epoch: 0002 Avg. cost = 0.072 Train Acc. = 0.97432727
# Epoch: 0002 Avg. cost = 0.073 Train Acc. = 0.9742
# Epoch: 0002 Avg. cost = 0.073 Train Acc. = 0.97418183
# Epoch: 0002 Avg. cost = 0.073 Train Acc. = 0.97392726
# Epoch: 0002 Avg. cost = 0.074 Train Acc. = 0.97409093
# Epoch: 0002 Avg. cost = 0.074 Train Acc. = 0.9742
# Epoch: 0002 Avg. cost = 0.074 Train Acc. = 0.97409093
# Epoch: 0002 Avg. cost = 0.075 Train Acc. = 0.9742182
# Epoch: 0002 Avg. cost = 0.075 Train Acc. = 0.9743636
# Epoch: 0002 Avg. cost = 0.075 Train Acc. = 0.9745091
# Epoch: 0002 Avg. cost = 0.075 Train Acc. = 0.9744727
# Epoch: 0002 Avg. cost = 0.075 Train Acc. = 0.9747091
# Epoch: 0002 Avg. cost = 0.076 Train Acc. = 0.9746909
# Epoch: 0002 Avg. cost = 0.076 Train Acc. = 0.9746
# Epoch: 0002 Avg. cost = 0.076 Train Acc. = 0.9746909
# Epoch: 0002 Avg. cost = 0.076 Train Acc. = 0.9746364
# Epoch: 0002 Avg. cost = 0.077 Train Acc. = 0.9745273
# Epoch: 0002 Avg. cost = 0.077 Train Acc. = 0.9745273
# Epoch: 0002 Avg. cost = 0.077 Train Acc. = 0.97492725
# Epoch: 0002 Avg. cost = 0.077 Train Acc. = 0.9749454
# Epoch: 0002 Avg. cost = 0.078 Train Acc. = 0.9751091
# Epoch: 0002 Avg. cost = 0.078 Train Acc. = 0.9750909
# Epoch: 0002 Avg. cost = 0.078 Train Acc. = 0.97507274
# Epoch: 0002 Avg. cost = 0.079 Train Acc. = 0.9752
# Epoch: 0002 Avg. cost = 0.079 Train Acc. = 0.9752909
# Epoch: 0002 Avg. cost = 0.079 Train Acc. = 0.9751273
# Epoch: 0002 Avg. cost = 0.079 Train Acc. = 0.975
# Epoch: 0002 Avg. cost = 0.079 Train Acc. = 0.9751091
# Epoch: 0002 Avg. cost = 0.080 Train Acc. = 0.9752
# Epoch: 0002 Avg. cost = 0.080 Train Acc. = 0.9755273
# Epoch: 0002 Avg. cost = 0.080 Train Acc. = 0.9751273
# Epoch: 0002 Avg. cost = 0.081 Train Acc. = 0.9750182
# Epoch: 0002 Avg. cost = 0.081 Train Acc. = 0.97507274
# Epoch: 0002 Avg. cost = 0.081 Train Acc. = 0.97496367
# Epoch: 0002 Avg. cost = 0.081 Train Acc. = 0.97498184
# Epoch: 0002 Avg. cost = 0.081 Train Acc. = 0.9751091
# Epoch: 0002 Avg. cost = 0.082 Train Acc. = 0.97496367
# Epoch: 0002 Avg. cost = 0.082 Train Acc. = 0.9751091
# Epoch: 0002 Avg. cost = 0.082 Train Acc. = 0.9753636
# Epoch: 0002 Avg. cost = 0.082 Train Acc. = 0.97565454
# Epoch: 0002 Avg. cost = 0.083 Train Acc. = 0.97596365
# Epoch: 0002 Avg. cost = 0.084 Train Acc. = 0.97596365
# Epoch: 0002 Avg. cost = 0.084 Train Acc. = 0.9756182
# Epoch: 0002 Avg. cost = 0.084 Train Acc. = 0.9754909
# Epoch: 0002 Avg. cost = 0.084 Train Acc. = 0.9751818
# Epoch: 0002 Avg. cost = 0.085 Train Acc. = 0.9754
# Epoch: 0002 Avg. cost = 0.085 Train Acc. = 0.9754364
# Epoch: 0002 Avg. cost = 0.085 Train Acc. = 0.9755091
# Epoch: 0002 Avg. cost = 0.086 Train Acc. = 0.97534543
# Epoch: 0002 Avg. cost = 0.086 Train Acc. = 0.9753636
# Epoch: 0002 Avg. cost = 0.086 Train Acc. = 0.97507274
# Epoch: 0002 Avg. cost = 0.087 Train Acc. = 0.9752
# Epoch: 0002 Avg. cost = 0.087 Train Acc. = 0.97481817
# Epoch: 0002 Avg. cost = 0.087 Train Acc. = 0.9746909
# Epoch: 0002 Avg. cost = 0.087 Train Acc. = 0.9745091
# Epoch: 0002 Avg. cost = 0.088 Train Acc. = 0.9746182
# Epoch: 0002 Avg. cost = 0.088 Train Acc. = 0.9746
# Epoch: 0002 Avg. cost = 0.088 Train Acc. = 0.9748727
# Epoch: 0002 Avg. cost = 0.089 Train Acc. = 0.97505456
# Epoch: 0002 Avg. cost = 0.089 Train Acc. = 0.9751273
# Epoch: 0002 Avg. cost = 0.089 Train Acc. = 0.9754182
# Epoch: 0002 Avg. cost = 0.089 Train Acc. = 0.97572726
# Epoch: 0002 Avg. cost = 0.090 Train Acc. = 0.9756182
# Epoch: 0002 Avg. cost = 0.090 Train Acc. = 0.97554547
# Epoch: 0002 Avg. cost = 0.090 Train Acc. = 0.9754182
# Epoch: 0002 Avg. cost = 0.091 Train Acc. = 0.9755273
# Epoch: 0002 Avg. cost = 0.091 Train Acc. = 0.9754182
# Epoch: 0002 Avg. cost = 0.091 Train Acc. = 0.9753091
# Epoch: 0002 Avg. cost = 0.092 Train Acc. = 0.97556365
# Epoch: 0002 Avg. cost = 0.092 Train Acc. = 0.9750909
# Epoch: 0002 Avg. cost = 0.092 Train Acc. = 0.9748727
# Epoch: 0002 Avg. cost = 0.093 Train Acc. = 0.9747273
# Epoch: 0002 Avg. cost = 0.093 Train Acc. = 0.9746
# Epoch: 0002 Avg. cost = 0.093 Train Acc. = 0.97434545
# Epoch: 0002 Avg. cost = 0.094 Train Acc. = 0.97418183
# Epoch: 0002 Avg. cost = 0.094 Train Acc. = 0.9744545
# Epoch: 0002 Avg. cost = 0.094 Train Acc. = 0.9747273
# Epoch: 0002 Avg. cost = 0.095 Train Acc. = 0.97496367
# Epoch: 0002 Avg. cost = 0.095 Train Acc. = 0.97505456
# Epoch: 0002 Avg. cost = 0.095 Train Acc. = 0.97523636
# Epoch: 0002 Avg. cost = 0.096 Train Acc. = 0.9753818
# Epoch: 0002 Avg. cost = 0.096 Train Acc. = 0.97545457
# Epoch: 0002 Avg. cost = 0.096 Train Acc. = 0.9751818
# Epoch: 0002 Avg. cost = 0.097 Train Acc. = 0.9748545
# Epoch: 0002 Avg. cost = 0.097 Train Acc. = 0.97476363
# Epoch: 0002 Avg. cost = 0.098 Train Acc. = 0.97465456
# Epoch: 0002 Avg. cost = 0.098 Train Acc. = 0.9742182
# Epoch: 0002 Avg. cost = 0.098 Train Acc. = 0.97392726
# Epoch: 0002 Avg. cost = 0.099 Train Acc. = 0.9738909
# Epoch: 0002 Avg. cost = 0.099 Train Acc. = 0.97409093
# Epoch: 0002 Avg. cost = 0.099 Train Acc. = 0.97409093
# Epoch: 0002 Avg. cost = 0.100 Train Acc. = 0.974
# Epoch: 0002 Avg. cost = 0.100 Train Acc. = 0.9740546
# Epoch: 0002 Avg. cost = 0.100 Train Acc. = 0.9739091
# Epoch: 0002 Avg. cost = 0.100 Train Acc. = 0.9738
# Epoch: 0002 Avg. cost = 0.101 Train Acc. = 0.9737273
# Epoch: 0002 Avg. cost = 0.101 Train Acc. = 0.9739636
# Epoch: 0002 Avg. cost = 0.101 Train Acc. = 0.9738182
# Epoch: 0002 Avg. cost = 0.102 Train Acc. = 0.97403634
# Epoch: 0002 Avg. cost = 0.102 Train Acc. = 0.97394544
# Epoch: 0002 Avg. cost = 0.102 Train Acc. = 0.9742727
# Epoch: 0002 Avg. cost = 0.103 Train Acc. = 0.97467273
# Epoch: 0002 Avg. cost = 0.103 Train Acc. = 0.97456366
# Epoch: 0002 Avg. cost = 0.103 Train Acc. = 0.9746182
# Epoch: 0002 Avg. cost = 0.104 Train Acc. = 0.97456366
# Epoch: 0002 Avg. cost = 0.104 Train Acc. = 0.9745273
# Epoch: 0002 Avg. cost = 0.104 Train Acc. = 0.9743818
# Epoch: 0002 Avg. cost = 0.104 Train Acc. = 0.9743091
# Epoch: 0002 Avg. cost = 0.104 Train Acc. = 0.9745455
# Epoch: 0002 Avg. cost = 0.105 Train Acc. = 0.97456366
# Epoch: 0002 Avg. cost = 0.105 Train Acc. = 0.97483635
# Epoch: 0002 Avg. cost = 0.105 Train Acc. = 0.9748727
# Epoch: 0002 Avg. cost = 0.105 Train Acc. = 0.97523636
# Epoch: 0002 Avg. cost = 0.106 Train Acc. = 0.9751273
# Epoch: 0002 Avg. cost = 0.106 Train Acc. = 0.97523636
# Epoch: 0002 Avg. cost = 0.107 Train Acc. = 0.97545457
# ...
# Epoch: 0030 Avg. cost = 0.012 Train Acc. = 0.9990364
# Epoch: 0030 Avg. cost = 0.012 Train Acc. = 0.9990364
# Epoch: 0030 Avg. cost = 0.012 Train Acc. = 0.9990364
# Epoch: 0030 Avg. cost = 0.012 Train Acc. = 0.9990182
# Epoch: 0030 Avg. cost = 0.012 Train Acc. = 0.9990364
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.9990364
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.9990182
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.9990364
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.9990182
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.9990182
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.9990364
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.99905455
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.9991091
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.9990909
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.9990909
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.9990909
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.99912727
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.9991091
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.99912727
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.99912727
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.9991091
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.99912727
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.99914545
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.9991636
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.9991636
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.9991818
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.99921817
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.99921817
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.99923635
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.99923635
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.99921817
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.99921817
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.99921817
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.99921817
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.99930906
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.99930906
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.9992909
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.9992909
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.99930906
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.9993273
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.9993273
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.9993273
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.99938184
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.9994
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.9994
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.9994182
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.9994182
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.9994182
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.9994182
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.9994182
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.9994182
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.99945456
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.99945456
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.9994182
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.99945456
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.9994364
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.99945456
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.99945456
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.99945456
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.99945456
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.99945456
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.99938184
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.9993273
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.9993273
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.9993273
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.9993273
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.9994182
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.9994364
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.9994364
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.9994364
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.99947274
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.99945456
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.99945456
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.99947274
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.9994182
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.9994
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.9993273
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.99930906
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.99923635
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.99921817
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.9992
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.9992
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.9991818
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.9991636
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.9991818
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.9991636
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.9991636
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.9991818
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.9991818
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.9992
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.9992
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.99921817
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.9992727
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.9993273
# Epoch: 0030 Avg. cost = 0.018 Train Acc. = 0.99930906
# Epoch: 0030 Avg. cost = 0.018 Train Acc. = 0.9992909
# Epoch: 0030 Avg. cost = 0.018 Train Acc. = 0.9992727
# Epoch: 0030 Avg. cost = 0.018 Train Acc. = 0.9992909
# Epoch: 0030 Avg. cost = 0.018 Train Acc. = 0.9992909
# Epoch: 0030 Avg. cost = 0.018 Train Acc. = 0.9992909
# Epoch: 0030 Avg. cost = 0.018 Train Acc. = 0.9992909
# Epoch: 0030 Avg. cost = 0.018 Train Acc. = 0.9992909
# Epoch: 0030 Avg. cost = 0.018 Train Acc. = 0.9992727
# Epoch: 0030 Avg. cost = 0.018 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.018 Train Acc. = 0.99923635
# Epoch: 0030 Avg. cost = 0.018 Train Acc. = 0.99921817
# Epoch: 0030 Avg. cost = 0.018 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.018 Train Acc. = 0.99921817
# Epoch: 0030 Avg. cost = 0.018 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.018 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.018 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.9992909
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.99930906
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.9993273
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.9993273
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.9994182
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.9994182
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.9994182
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.9994182
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.9994182
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.9994364
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.99947274
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.99945456
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.99945456
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.99945456
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.9994909
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.9994909
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.99947274
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.99945456
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.9994182
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.9994364
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.9994
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.9994
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.9993273
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.9993273
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.9993273
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.9993273
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.99938184
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.99938184
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.99938184
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.99938184
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.99938184
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.99938184
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.9994
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.99938184
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.99938184
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.9994
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.9994
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.99938184
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.9994182
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.9994
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.99938184
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.99938184
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.99938184
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.9994
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.99938184
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.99938184
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.99938184
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.99938184
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.99938184
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.9993273
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.9993273
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.99930906
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.9993273
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.9994
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.99938184
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.9994
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.9994182
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.99938184
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.9993273
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.99930906
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.9992727
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.9992727
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.99921817
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.9992
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.9992
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.9992
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.9991818
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.99914545
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.9990909
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.99907273
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.9990909
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.9990909
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.9990909
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.9989455
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.99883634
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.9988545
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.99881816
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.9988
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.9987818
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.9987636
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.99881816
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.99881816
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.99887276
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.9989091
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.99898183
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.999
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.99907273
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.99914545
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.9991636
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.9991818
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.99914545
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.9991636
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.99914545
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.99914545
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.99912727
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.9991636
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.9991818
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.9992
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.99914545
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.9991636
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.99914545
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.9991636
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.9991818
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.9992
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.9992
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.9992
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.9992
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.99912727
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.99914545
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.9991091
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.99905455
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.999
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.99896365
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.99889094
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.9989455
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.99896365
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.999
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.9990364
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9990364
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9990364
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9991091
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.99912727
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.99914545
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.99914545
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.99912727
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.99914545
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9991636
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9992909
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9992909
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.99930906
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.99930906
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9992909
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9992727
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9992727
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9992727
# Epoch: 0030 Avg. cost = 0.028 Train Acc. = 0.9992909
# Epoch: 0030 Avg. cost = 0.028 Train Acc. = 0.9993273
# Epoch: 0030 Avg. cost = 0.028 Train Acc. = 0.9992909
# Training Done!
# Test Acc. =  0.9859
