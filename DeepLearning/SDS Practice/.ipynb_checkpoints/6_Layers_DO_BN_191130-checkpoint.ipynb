# %%
# session 생성시 tf.Session()대신 tf.Session(config=config)로 대체 바랍니다!

import tensorflow as tf
import os

os.environ["CUDA_VISIBLE_DEVICES"]='0'
config = tf.ConfigProto()
config.gpu_options.allow_growth = True

from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("./mnist/data/", one_hot=True)

X = tf.placeholder(tf.float32, [None, 784])
Y = tf.placeholder(tf.float32, [None, 10])
# Out:
# Extracting ./mnist/data/train-images-idx3-ubyte.gz
# Extracting ./mnist/data/train-labels-idx1-ubyte.gz
# Extracting ./mnist/data/t10k-images-idx3-ubyte.gz
# Extracting ./mnist/data/t10k-labels-idx1-ubyte.gz

# %%
def dropout(x, keep_prob):
    mask = tf.floor(keep_prob * tf.ones(tf.shape(x)) + tf.random_uniform(shape=tf.shape(x)))
    return tf.divide(x, keep_prob) * mask

# %%
# setup layers
# He Initialization
keep_prob = tf.placeholder(tf.float32)
epsilon = 1e-3

'''
W1 = tf.Variable(tf.random_normal([784, 2048], stddev=0.01))
#W1 = tf.get_variable("W1", shape=[784, 1024], initializer=tf.contrib.layers.variance_scaling_initializer())
B1 = tf.Variable(tf.random_normal(shape=[2048], stddev=0.01))
L1 = tf.nn.relu(tf.matmul(X, W1)+B1)
L1 = tf.nn.dropout(L1, keep_prob)
'''

W1_BN = tf.Variable(tf.random_normal([784, 2048], stddev=0.01))
L1_BN = tf.matmul(X, W1_BN)
batch_mean1, batch_var1 = tf.nn.moments(L1_BN,[0])
scale1 = tf.Variable(tf.ones([2048]))
beta1 = tf.Variable(tf.zeros([2048]))
BN1 = tf.nn.batch_normalization(L1_BN, batch_mean1, batch_var1, beta1, scale1, epsilon)
L1_BN = tf.nn.relu(BN1)
L1_BN = tf.nn.dropout(L1_BN, keep_prob)

'''
W2 = tf.Variable(tf.random_normal([2048, 1024], stddev=0.01))
#W1 = tf.get_variable("W1", shape=[784, 1024], initializer=tf.contrib.layers.variance_scaling_initializer())
B2 = tf.Variable(tf.random_normal(shape=[1024], stddev=0.01))
L2 = tf.nn.relu(tf.matmul(L1_BN, W2))
L2 = tf.nn.dropout(L2, keep_prob)
'''

W2_BN = tf.Variable(tf.random_normal([2048, 1024], stddev=0.01))
L2_BN = tf.matmul(L1_BN, W2_BN)
batch_mean2, batch_var2 = tf.nn.moments(L2_BN,[0])
scale2 = tf.Variable(tf.ones([1024]))
beta2 = tf.Variable(tf.zeros([1024]))
BN2 = tf.nn.batch_normalization(L2_BN, batch_mean2, batch_var2, beta2, scale2, epsilon)
L2_BN = tf.nn.relu(BN2)
L2_BN = tf.nn.dropout(L2_BN, keep_prob)

'''
W3 = tf.Variable(tf.random_normal([1024, 512], stddev=0.01))
#W2 = tf.get_variable("W2", shape=[1024, 512], initializer=tf.contrib.layers.variance_scaling_initializer())
B3 = tf.Variable(tf.random_normal(shape=[512], stddev=0.01))
L3 = tf.nn.relu(tf.matmul(L2, W3)+B3)
L3 = tf.nn.dropout(L3, keep_prob)
'''

W3_BN = tf.Variable(tf.random_normal([1024, 512], stddev=0.01))
L3_BN = tf.matmul(L2_BN, W3_BN)
batch_mean3, batch_var3 = tf.nn.moments(L3_BN,[0])
scale3 = tf.Variable(tf.ones([512]))
beta3 = tf.Variable(tf.zeros([512]))
BN3 = tf.nn.batch_normalization(L3_BN, batch_mean3, batch_var3, beta3, scale3, epsilon)
L3_BN = tf.nn.relu(BN3)
L3_BN = tf.nn.dropout(L3_BN, keep_prob)

'''
W4 = tf.Variable(tf.random_normal([512, 256], stddev=0.01))
#W3 = tf.get_variable("W3", shape=[512, 256], initializer=tf.contrib.layers.variance_scaling_initializer())
B4 = tf.Variable(tf.random_normal(shape=[256], stddev=0.01))
L4 = tf.nn.relu(tf.matmul(L3, W4)+B4)
L4 = tf.nn.dropout(L4, keep_prob)
'''

W4_BN = tf.Variable(tf.random_normal([512, 256], stddev=0.01))
L4_BN = tf.matmul(L3_BN, W4_BN)
batch_mean4, batch_var4 = tf.nn.moments(L4_BN,[0])
scale4 = tf.Variable(tf.ones([256]))
beta4 = tf.Variable(tf.zeros([256]))
BN4 = tf.nn.batch_normalization(L4_BN, batch_mean4, batch_var4, beta4, scale4, epsilon)
L4_BN = tf.nn.relu(BN4)
L4_BN = tf.nn.dropout(L4_BN, keep_prob)

'''
W5 = tf.Variable(tf.random_normal([256, 10], stddev=0.01))
#W4 = tf.get_variable("W4", shape=[256, 10], initializer=tf.contrib.layers.variance_scaling_initializer())
B5 = tf.Variable(tf.random_normal(shape=[10], stddev=0.01))
model = tf.nn.softmax(tf.matmul(L4,W5)+B5)
'''

W5_BN = tf.Variable(tf.random_normal([256, 10], stddev=0.01))
L5_BN = tf.matmul(L4_BN, W5_BN)
batch_mean5, batch_var5 = tf.nn.moments(L5_BN,[0])
scale5 = tf.Variable(tf.ones([10]))
beta5 = tf.Variable(tf.zeros([10]))
BN5 = tf.nn.batch_normalization(L5_BN, batch_mean5, batch_var5, beta5, scale5, epsilon)
model = tf.nn.softmax(tf.matmul(L4_BN,W5_BN))

#cost function and optimizer
cost = tf.reduce_mean(-tf.reduce_sum(Y * tf.log(tf.clip_by_value(model, 1e-10,1.0)), [1]))
optimizer = tf.train.AdamOptimizer(0.001).minimize(cost)

init = tf.global_variables_initializer()
sess = tf.Session(config=config)
sess.run(init)

#set up for minibatch
batch_size=100
total_batch= int(mnist.train.num_examples/batch_size) 

#set up for accuracy
is_correct = tf.equal(tf.argmax(model,1), tf.argmax(Y,1))
accuracy = tf.reduce_mean(tf.cast(is_correct, tf.float32))

#training
for epoch in range(15):
    total_cost = 0
    
    for i in range(total_batch):
        batch_xs, batch_ys = mnist.train.next_batch(batch_size)
        #_, cost_val = sess.run([optimizer, cost], feed_dict={X: batch_xs, Y: batch_ys})
        #total_cost += cost_val
        _, cost_val = sess.run([optimizer, cost], feed_dict={X: batch_xs, Y: batch_ys, keep_prob: 0.5})
        total_cost += cost_val
        
        #print('Epoch:', '%04d' % (epoch + 1), 'Avg. cost =', '{:.3f}'.format(total_cost / total_batch), 
              #'Train Acc. =', sess.run(accuracy, feed_dict={X: mnist.train.images, Y: mnist.train.labels}))
        print('Epoch:', '%04d' % (epoch + 1), 'Avg. cost =', '{:.3f}'.format(total_cost / total_batch), 'Train Acc. =', sess.run(accuracy, feed_dict={X: mnist.train.images, Y: mnist.train.labels, keep_prob: 1.0}))

#print("Training Done")
#print("Test Acc.=", sess.run(accuracy, feed_dict={X: mnist.test.images, Y: mnist.test.labels}))
        
print('Training Done!')
print('Test Acc. = ', sess.run(accuracy, feed_dict={X: mnist.test.images, Y: mnist.test.labels, keep_prob: 1.0}))
# Out:
# Epoch: 0001 Avg. cost = 0.004 Train Acc. = 0.50012726
# Epoch: 0001 Avg. cost = 0.008 Train Acc. = 0.6380727
# Epoch: 0001 Avg. cost = 0.012 Train Acc. = 0.6538909
# Epoch: 0001 Avg. cost = 0.016 Train Acc. = 0.65834546
# Epoch: 0001 Avg. cost = 0.020 Train Acc. = 0.66269094
# Epoch: 0001 Avg. cost = 0.023 Train Acc. = 0.6732
# Epoch: 0001 Avg. cost = 0.027 Train Acc. = 0.68612725
# Epoch: 0001 Avg. cost = 0.030 Train Acc. = 0.69256365
# Epoch: 0001 Avg. cost = 0.033 Train Acc. = 0.7049091
# Epoch: 0001 Avg. cost = 0.037 Train Acc. = 0.7164364
# Epoch: 0001 Avg. cost = 0.039 Train Acc. = 0.7278909
# Epoch: 0001 Avg. cost = 0.042 Train Acc. = 0.7412182
# Epoch: 0001 Avg. cost = 0.045 Train Acc. = 0.75463635
# Epoch: 0001 Avg. cost = 0.048 Train Acc. = 0.7694182
# Epoch: 0001 Avg. cost = 0.050 Train Acc. = 0.7843091
# Epoch: 0001 Avg. cost = 0.052 Train Acc. = 0.7940364
# Epoch: 0001 Avg. cost = 0.054 Train Acc. = 0.7998545
# Epoch: 0001 Avg. cost = 0.056 Train Acc. = 0.8038
# Epoch: 0001 Avg. cost = 0.058 Train Acc. = 0.8077273
# Epoch: 0001 Avg. cost = 0.060 Train Acc. = 0.8117818
# Epoch: 0001 Avg. cost = 0.062 Train Acc. = 0.8166909
# Epoch: 0001 Avg. cost = 0.064 Train Acc. = 0.8242546
# Epoch: 0001 Avg. cost = 0.066 Train Acc. = 0.8335818
# Epoch: 0001 Avg. cost = 0.067 Train Acc. = 0.8402
# Epoch: 0001 Avg. cost = 0.069 Train Acc. = 0.8468182
# Epoch: 0001 Avg. cost = 0.071 Train Acc. = 0.85252726
# Epoch: 0001 Avg. cost = 0.072 Train Acc. = 0.8569091
# Epoch: 0001 Avg. cost = 0.074 Train Acc. = 0.8623091
# Epoch: 0001 Avg. cost = 0.075 Train Acc. = 0.86767274
# Epoch: 0001 Avg. cost = 0.076 Train Acc. = 0.8747454
# Epoch: 0001 Avg. cost = 0.077 Train Acc. = 0.88012725
# Epoch: 0001 Avg. cost = 0.079 Train Acc. = 0.8873818
# Epoch: 0001 Avg. cost = 0.080 Train Acc. = 0.8947273
# Epoch: 0001 Avg. cost = 0.082 Train Acc. = 0.9002727
# Epoch: 0001 Avg. cost = 0.083 Train Acc. = 0.9038727
# Epoch: 0001 Avg. cost = 0.084 Train Acc. = 0.9064364
# Epoch: 0001 Avg. cost = 0.085 Train Acc. = 0.90685457
# Epoch: 0001 Avg. cost = 0.086 Train Acc. = 0.90696365
# Epoch: 0001 Avg. cost = 0.087 Train Acc. = 0.9052727
# Epoch: 0001 Avg. cost = 0.088 Train Acc. = 0.9035091
# Epoch: 0001 Avg. cost = 0.089 Train Acc. = 0.9046909
# Epoch: 0001 Avg. cost = 0.090 Train Acc. = 0.9078182
# Epoch: 0001 Avg. cost = 0.091 Train Acc. = 0.9100909
# Epoch: 0001 Avg. cost = 0.092 Train Acc. = 0.91163635
# Epoch: 0001 Avg. cost = 0.092 Train Acc. = 0.9128
# Epoch: 0001 Avg. cost = 0.093 Train Acc. = 0.9122364
# Epoch: 0001 Avg. cost = 0.094 Train Acc. = 0.91172725
# Epoch: 0001 Avg. cost = 0.095 Train Acc. = 0.91276366
# Epoch: 0001 Avg. cost = 0.096 Train Acc. = 0.914
# Epoch: 0001 Avg. cost = 0.096 Train Acc. = 0.915
# Epoch: 0001 Avg. cost = 0.097 Train Acc. = 0.9160909
# Epoch: 0001 Avg. cost = 0.098 Train Acc. = 0.91712725
# Epoch: 0001 Avg. cost = 0.099 Train Acc. = 0.91834545
# Epoch: 0001 Avg. cost = 0.100 Train Acc. = 0.9207091
# Epoch: 0001 Avg. cost = 0.100 Train Acc. = 0.9226182
# Epoch: 0001 Avg. cost = 0.101 Train Acc. = 0.92309093
# Epoch: 0001 Avg. cost = 0.102 Train Acc. = 0.92316365
# Epoch: 0001 Avg. cost = 0.103 Train Acc. = 0.92301816
# Epoch: 0001 Avg. cost = 0.104 Train Acc. = 0.9214909
# Epoch: 0001 Avg. cost = 0.104 Train Acc. = 0.91932726
# Epoch: 0001 Avg. cost = 0.105 Train Acc. = 0.9175091
# Epoch: 0001 Avg. cost = 0.106 Train Acc. = 0.91614544
# Epoch: 0001 Avg. cost = 0.106 Train Acc. = 0.9160909
# Epoch: 0001 Avg. cost = 0.107 Train Acc. = 0.9173273
# Epoch: 0001 Avg. cost = 0.108 Train Acc. = 0.9206
# Epoch: 0001 Avg. cost = 0.108 Train Acc. = 0.92252725
# Epoch: 0001 Avg. cost = 0.109 Train Acc. = 0.92496365
# Epoch: 0001 Avg. cost = 0.110 Train Acc. = 0.92596364
# Epoch: 0001 Avg. cost = 0.110 Train Acc. = 0.9254364
# Epoch: 0001 Avg. cost = 0.111 Train Acc. = 0.92374545
# Epoch: 0001 Avg. cost = 0.112 Train Acc. = 0.9224182
# Epoch: 0001 Avg. cost = 0.113 Train Acc. = 0.9220545
# Epoch: 0001 Avg. cost = 0.113 Train Acc. = 0.9215636
# Epoch: 0001 Avg. cost = 0.114 Train Acc. = 0.9216727
# Epoch: 0001 Avg. cost = 0.114 Train Acc. = 0.9214182
# Epoch: 0001 Avg. cost = 0.115 Train Acc. = 0.9226
# Epoch: 0001 Avg. cost = 0.116 Train Acc. = 0.9241273
# Epoch: 0001 Avg. cost = 0.117 Train Acc. = 0.92596364
# Epoch: 0001 Avg. cost = 0.118 Train Acc. = 0.92776364
# Epoch: 0001 Avg. cost = 0.118 Train Acc. = 0.9282182
# Epoch: 0001 Avg. cost = 0.119 Train Acc. = 0.92734545
# Epoch: 0001 Avg. cost = 0.120 Train Acc. = 0.9255818
# Epoch: 0001 Avg. cost = 0.120 Train Acc. = 0.9227091
# Epoch: 0001 Avg. cost = 0.121 Train Acc. = 0.9213455
# Epoch: 0001 Avg. cost = 0.122 Train Acc. = 0.92185456
# Epoch: 0001 Avg. cost = 0.122 Train Acc. = 0.9228727
# Epoch: 0001 Avg. cost = 0.123 Train Acc. = 0.92358184
# Epoch: 0001 Avg. cost = 0.124 Train Acc. = 0.92463636
# Epoch: 0001 Avg. cost = 0.124 Train Acc. = 0.92596364
# Epoch: 0001 Avg. cost = 0.125 Train Acc. = 0.9268364
# Epoch: 0001 Avg. cost = 0.125 Train Acc. = 0.92703635
# Epoch: 0001 Avg. cost = 0.126 Train Acc. = 0.92667276
# Epoch: 0001 Avg. cost = 0.126 Train Acc. = 0.9268
# Epoch: 0001 Avg. cost = 0.127 Train Acc. = 0.92694545
# Epoch: 0001 Avg. cost = 0.127 Train Acc. = 0.92627275
# Epoch: 0001 Avg. cost = 0.128 Train Acc. = 0.92514545
# Epoch: 0001 Avg. cost = 0.129 Train Acc. = 0.9244909
# Epoch: 0001 Avg. cost = 0.129 Train Acc. = 0.92481816
# Epoch: 0001 Avg. cost = 0.130 Train Acc. = 0.9267273
# Epoch: 0001 Avg. cost = 0.131 Train Acc. = 0.92896366
# Epoch: 0001 Avg. cost = 0.131 Train Acc. = 0.9315818
# Epoch: 0001 Avg. cost = 0.132 Train Acc. = 0.93414545
# Epoch: 0001 Avg. cost = 0.133 Train Acc. = 0.9360909
# Epoch: 0001 Avg. cost = 0.134 Train Acc. = 0.93725455
# Epoch: 0001 Avg. cost = 0.134 Train Acc. = 0.93756366
# Epoch: 0001 Avg. cost = 0.135 Train Acc. = 0.9369091
# Epoch: 0001 Avg. cost = 0.136 Train Acc. = 0.9373818
# Epoch: 0001 Avg. cost = 0.137 Train Acc. = 0.93741816
# Epoch: 0001 Avg. cost = 0.137 Train Acc. = 0.9372909
# Epoch: 0001 Avg. cost = 0.138 Train Acc. = 0.9372909
# Epoch: 0001 Avg. cost = 0.139 Train Acc. = 0.9377818
# Epoch: 0001 Avg. cost = 0.140 Train Acc. = 0.93790907
# Epoch: 0001 Avg. cost = 0.140 Train Acc. = 0.9374
# Epoch: 0001 Avg. cost = 0.141 Train Acc. = 0.9362
# Epoch: 0001 Avg. cost = 0.142 Train Acc. = 0.93587273
# Epoch: 0001 Avg. cost = 0.142 Train Acc. = 0.9349818
# Epoch: 0001 Avg. cost = 0.143 Train Acc. = 0.9346727
# Epoch: 0001 Avg. cost = 0.144 Train Acc. = 0.9362182
# Epoch: 0001 Avg. cost = 0.144 Train Acc. = 0.93585455
# Epoch: 0001 Avg. cost = 0.145 Train Acc. = 0.9352
# Epoch: 0001 Avg. cost = 0.145 Train Acc. = 0.9350727
# Epoch: 0001 Avg. cost = 0.146 Train Acc. = 0.93563634
# Epoch: 0001 Avg. cost = 0.146 Train Acc. = 0.936
# Epoch: 0001 Avg. cost = 0.147 Train Acc. = 0.93627274
# Epoch: 0001 Avg. cost = 0.147 Train Acc. = 0.9359091
# Epoch: 0001 Avg. cost = 0.148 Train Acc. = 0.9355818
# Epoch: 0001 Avg. cost = 0.148 Train Acc. = 0.9363091
# Epoch: 0001 Avg. cost = 0.149 Train Acc. = 0.93732727
# Epoch: 0001 Avg. cost = 0.149 Train Acc. = 0.9373636
# Epoch: 0001 Avg. cost = 0.150 Train Acc. = 0.93872726
# Epoch: 0001 Avg. cost = 0.150 Train Acc. = 0.9407455
# Epoch: 0001 Avg. cost = 0.151 Train Acc. = 0.94143635
# Epoch: 0001 Avg. cost = 0.152 Train Acc. = 0.9421273
# Epoch: 0001 Avg. cost = 0.152 Train Acc. = 0.9424
# Epoch: 0001 Avg. cost = 0.153 Train Acc. = 0.9421091
# Epoch: 0001 Avg. cost = 0.153 Train Acc. = 0.94158185
# Epoch: 0001 Avg. cost = 0.154 Train Acc. = 0.9416909
# Epoch: 0001 Avg. cost = 0.154 Train Acc. = 0.9419091
# Epoch: 0001 Avg. cost = 0.155 Train Acc. = 0.9420364
# Epoch: 0001 Avg. cost = 0.156 Train Acc. = 0.9425273
# Epoch: 0001 Avg. cost = 0.156 Train Acc. = 0.9431818
# Epoch: 0001 Avg. cost = 0.157 Train Acc. = 0.94452727
# Epoch: 0001 Avg. cost = 0.157 Train Acc. = 0.9451636
# Epoch: 0001 Avg. cost = 0.158 Train Acc. = 0.9458727
# Epoch: 0001 Avg. cost = 0.159 Train Acc. = 0.94543636
# Epoch: 0001 Avg. cost = 0.160 Train Acc. = 0.9460545
# Epoch: 0001 Avg. cost = 0.160 Train Acc. = 0.9460727
# Epoch: 0001 Avg. cost = 0.161 Train Acc. = 0.94536364
# Epoch: 0001 Avg. cost = 0.161 Train Acc. = 0.9455636
# Epoch: 0001 Avg. cost = 0.162 Train Acc. = 0.94569093
# Epoch: 0001 Avg. cost = 0.162 Train Acc. = 0.9456546
# Epoch: 0001 Avg. cost = 0.163 Train Acc. = 0.9454182
# Epoch: 0001 Avg. cost = 0.163 Train Acc. = 0.9453091
# Epoch: 0001 Avg. cost = 0.164 Train Acc. = 0.94576365
# Epoch: 0001 Avg. cost = 0.164 Train Acc. = 0.9454
# Epoch: 0001 Avg. cost = 0.165 Train Acc. = 0.9455636
# Epoch: 0001 Avg. cost = 0.165 Train Acc. = 0.94476366
# Epoch: 0001 Avg. cost = 0.166 Train Acc. = 0.9439091
# Epoch: 0001 Avg. cost = 0.166 Train Acc. = 0.9434909
# Epoch: 0001 Avg. cost = 0.167 Train Acc. = 0.9432182
# Epoch: 0001 Avg. cost = 0.168 Train Acc. = 0.9430909
# Epoch: 0001 Avg. cost = 0.168 Train Acc. = 0.9428545
# Epoch: 0001 Avg. cost = 0.168 Train Acc. = 0.9435091
# Epoch: 0001 Avg. cost = 0.169 Train Acc. = 0.9442545
# Epoch: 0001 Avg. cost = 0.169 Train Acc. = 0.9452
# Epoch: 0001 Avg. cost = 0.170 Train Acc. = 0.9457818
# Epoch: 0001 Avg. cost = 0.171 Train Acc. = 0.9464909
# Epoch: 0001 Avg. cost = 0.171 Train Acc. = 0.9471091
# Epoch: 0001 Avg. cost = 0.172 Train Acc. = 0.9472727
# Epoch: 0001 Avg. cost = 0.173 Train Acc. = 0.9478727
# Epoch: 0001 Avg. cost = 0.173 Train Acc. = 0.9477636
# Epoch: 0001 Avg. cost = 0.174 Train Acc. = 0.94749093
# Epoch: 0001 Avg. cost = 0.174 Train Acc. = 0.9466182
# Epoch: 0001 Avg. cost = 0.175 Train Acc. = 0.9464727
# Epoch: 0001 Avg. cost = 0.175 Train Acc. = 0.94552726
# Epoch: 0001 Avg. cost = 0.176 Train Acc. = 0.94463634
# Epoch: 0001 Avg. cost = 0.176 Train Acc. = 0.94452727
# Epoch: 0001 Avg. cost = 0.177 Train Acc. = 0.94421816
# Epoch: 0001 Avg. cost = 0.177 Train Acc. = 0.94394547
# Epoch: 0001 Avg. cost = 0.178 Train Acc. = 0.9444
# Epoch: 0001 Avg. cost = 0.179 Train Acc. = 0.9450909
# Epoch: 0001 Avg. cost = 0.179 Train Acc. = 0.9462182
# Epoch: 0001 Avg. cost = 0.180 Train Acc. = 0.9467091
# Epoch: 0001 Avg. cost = 0.180 Train Acc. = 0.94789094
# Epoch: 0001 Avg. cost = 0.181 Train Acc. = 0.94836366
# Epoch: 0001 Avg. cost = 0.181 Train Acc. = 0.94905454
# Epoch: 0001 Avg. cost = 0.182 Train Acc. = 0.9490909
# Epoch: 0001 Avg. cost = 0.182 Train Acc. = 0.9495636
# Epoch: 0001 Avg. cost = 0.183 Train Acc. = 0.9497455
# Epoch: 0001 Avg. cost = 0.183 Train Acc. = 0.94963634
# Epoch: 0001 Avg. cost = 0.184 Train Acc. = 0.9498182
# Epoch: 0001 Avg. cost = 0.184 Train Acc. = 0.9503091
# Epoch: 0001 Avg. cost = 0.185 Train Acc. = 0.9504182
# Epoch: 0001 Avg. cost = 0.185 Train Acc. = 0.9508909
# Epoch: 0001 Avg. cost = 0.186 Train Acc. = 0.9509818
# Epoch: 0001 Avg. cost = 0.187 Train Acc. = 0.95109093
# Epoch: 0001 Avg. cost = 0.188 Train Acc. = 0.95034546
# Epoch: 0001 Avg. cost = 0.188 Train Acc. = 0.9498364
# Epoch: 0001 Avg. cost = 0.189 Train Acc. = 0.9490727
# Epoch: 0001 Avg. cost = 0.189 Train Acc. = 0.9486909
# Epoch: 0001 Avg. cost = 0.189 Train Acc. = 0.9481636
# Epoch: 0001 Avg. cost = 0.189 Train Acc. = 0.94756365
# Epoch: 0001 Avg. cost = 0.190 Train Acc. = 0.9485091
# Epoch: 0001 Avg. cost = 0.191 Train Acc. = 0.9485818
# Epoch: 0001 Avg. cost = 0.192 Train Acc. = 0.9501455
# Epoch: 0001 Avg. cost = 0.192 Train Acc. = 0.9507273
# Epoch: 0001 Avg. cost = 0.193 Train Acc. = 0.9514545
# Epoch: 0001 Avg. cost = 0.193 Train Acc. = 0.9517818
# Epoch: 0001 Avg. cost = 0.194 Train Acc. = 0.95192724
# Epoch: 0001 Avg. cost = 0.194 Train Acc. = 0.9523818
# Epoch: 0001 Avg. cost = 0.194 Train Acc. = 0.95283633
# Epoch: 0001 Avg. cost = 0.195 Train Acc. = 0.9526727
# Epoch: 0001 Avg. cost = 0.195 Train Acc. = 0.95256364
# Epoch: 0001 Avg. cost = 0.196 Train Acc. = 0.95216364
# Epoch: 0001 Avg. cost = 0.196 Train Acc. = 0.9516
# Epoch: 0001 Avg. cost = 0.197 Train Acc. = 0.95132726
# Epoch: 0001 Avg. cost = 0.197 Train Acc. = 0.9512
# Epoch: 0001 Avg. cost = 0.198 Train Acc. = 0.95092726
# Epoch: 0001 Avg. cost = 0.198 Train Acc. = 0.9507273
# Epoch: 0001 Avg. cost = 0.199 Train Acc. = 0.95085454
# Epoch: 0001 Avg. cost = 0.199 Train Acc. = 0.9509818
# Epoch: 0001 Avg. cost = 0.200 Train Acc. = 0.9518545
# Epoch: 0001 Avg. cost = 0.201 Train Acc. = 0.95245457
# Epoch: 0001 Avg. cost = 0.201 Train Acc. = 0.9530909
# Epoch: 0001 Avg. cost = 0.202 Train Acc. = 0.9524364
# Epoch: 0001 Avg. cost = 0.202 Train Acc. = 0.9522727
# Epoch: 0001 Avg. cost = 0.203 Train Acc. = 0.9516
# Epoch: 0001 Avg. cost = 0.203 Train Acc. = 0.9521091
# Epoch: 0001 Avg. cost = 0.204 Train Acc. = 0.9520909
# Epoch: 0001 Avg. cost = 0.204 Train Acc. = 0.95223635
# Epoch: 0001 Avg. cost = 0.205 Train Acc. = 0.9522182
# Epoch: 0001 Avg. cost = 0.205 Train Acc. = 0.95263636
# Epoch: 0001 Avg. cost = 0.205 Train Acc. = 0.9524
# Epoch: 0001 Avg. cost = 0.206 Train Acc. = 0.95256364
# Epoch: 0001 Avg. cost = 0.206 Train Acc. = 0.9524909
# Epoch: 0001 Avg. cost = 0.207 Train Acc. = 0.95289093
# Epoch: 0001 Avg. cost = 0.207 Train Acc. = 0.9533091
# Epoch: 0001 Avg. cost = 0.208 Train Acc. = 0.95361817
# Epoch: 0001 Avg. cost = 0.208 Train Acc. = 0.95372725
# Epoch: 0001 Avg. cost = 0.209 Train Acc. = 0.95372725
# Epoch: 0001 Avg. cost = 0.209 Train Acc. = 0.95312726
# Epoch: 0001 Avg. cost = 0.210 Train Acc. = 0.9528546
# Epoch: 0001 Avg. cost = 0.210 Train Acc. = 0.9534
# Epoch: 0001 Avg. cost = 0.210 Train Acc. = 0.95378184
# Epoch: 0001 Avg. cost = 0.211 Train Acc. = 0.9540727
# Epoch: 0001 Avg. cost = 0.211 Train Acc. = 0.9543273
# Epoch: 0001 Avg. cost = 0.212 Train Acc. = 0.95403636
# Epoch: 0001 Avg. cost = 0.212 Train Acc. = 0.9538909
# Epoch: 0001 Avg. cost = 0.213 Train Acc. = 0.9545091
# Epoch: 0001 Avg. cost = 0.214 Train Acc. = 0.955
# Epoch: 0001 Avg. cost = 0.214 Train Acc. = 0.9552182
# Epoch: 0001 Avg. cost = 0.214 Train Acc. = 0.95541817
# Epoch: 0001 Avg. cost = 0.215 Train Acc. = 0.95503634
# Epoch: 0001 Avg. cost = 0.215 Train Acc. = 0.9545091
# Epoch: 0001 Avg. cost = 0.215 Train Acc. = 0.9534182
# Epoch: 0001 Avg. cost = 0.216 Train Acc. = 0.95245457
# Epoch: 0001 Avg. cost = 0.216 Train Acc. = 0.95149094
# Epoch: 0001 Avg. cost = 0.217 Train Acc. = 0.9514
# Epoch: 0001 Avg. cost = 0.217 Train Acc. = 0.95192724
# Epoch: 0001 Avg. cost = 0.217 Train Acc. = 0.9526
# Epoch: 0001 Avg. cost = 0.218 Train Acc. = 0.9533273
# Epoch: 0001 Avg. cost = 0.218 Train Acc. = 0.9547273
# Epoch: 0001 Avg. cost = 0.219 Train Acc. = 0.9561091
# Epoch: 0001 Avg. cost = 0.219 Train Acc. = 0.9571091
# Epoch: 0001 Avg. cost = 0.220 Train Acc. = 0.9585091
# Epoch: 0001 Avg. cost = 0.220 Train Acc. = 0.95912725
# Epoch: 0001 Avg. cost = 0.221 Train Acc. = 0.95952725
# Epoch: 0001 Avg. cost = 0.221 Train Acc. = 0.95936364
# Epoch: 0001 Avg. cost = 0.221 Train Acc. = 0.9586727
# Epoch: 0001 Avg. cost = 0.221 Train Acc. = 0.95774543
# Epoch: 0001 Avg. cost = 0.222 Train Acc. = 0.9572545
# Epoch: 0001 Avg. cost = 0.222 Train Acc. = 0.95625454
# Epoch: 0001 Avg. cost = 0.223 Train Acc. = 0.9551273
# Epoch: 0001 Avg. cost = 0.223 Train Acc. = 0.95387274
# Epoch: 0001 Avg. cost = 0.224 Train Acc. = 0.95314544
# Epoch: 0001 Avg. cost = 0.224 Train Acc. = 0.95263636
# Epoch: 0001 Avg. cost = 0.225 Train Acc. = 0.95225453
# Epoch: 0001 Avg. cost = 0.225 Train Acc. = 0.953
# Epoch: 0001 Avg. cost = 0.226 Train Acc. = 0.9536909
# Epoch: 0001 Avg. cost = 0.226 Train Acc. = 0.9544182
# Epoch: 0001 Avg. cost = 0.226 Train Acc. = 0.95503634
# Epoch: 0001 Avg. cost = 0.227 Train Acc. = 0.95594543
# Epoch: 0001 Avg. cost = 0.228 Train Acc. = 0.95672727
# Epoch: 0001 Avg. cost = 0.228 Train Acc. = 0.9572727
# Epoch: 0001 Avg. cost = 0.229 Train Acc. = 0.95787275
# Epoch: 0001 Avg. cost = 0.229 Train Acc. = 0.9583273
# Epoch: 0001 Avg. cost = 0.229 Train Acc. = 0.95887274
# Epoch: 0001 Avg. cost = 0.230 Train Acc. = 0.95894545
# Epoch: 0001 Avg. cost = 0.230 Train Acc. = 0.9590545
# Epoch: 0001 Avg. cost = 0.231 Train Acc. = 0.9586545
# Epoch: 0001 Avg. cost = 0.231 Train Acc. = 0.95863634
# Epoch: 0001 Avg. cost = 0.232 Train Acc. = 0.9585636
# Epoch: 0001 Avg. cost = 0.232 Train Acc. = 0.9580909
# Epoch: 0001 Avg. cost = 0.233 Train Acc. = 0.95765454
# Epoch: 0001 Avg. cost = 0.233 Train Acc. = 0.95738184
# Epoch: 0001 Avg. cost = 0.234 Train Acc. = 0.9575273
# Epoch: 0001 Avg. cost = 0.234 Train Acc. = 0.9571091
# Epoch: 0001 Avg. cost = 0.234 Train Acc. = 0.95649093
# Epoch: 0001 Avg. cost = 0.235 Train Acc. = 0.9565273
# Epoch: 0001 Avg. cost = 0.236 Train Acc. = 0.9564546
# Epoch: 0001 Avg. cost = 0.236 Train Acc. = 0.9566727
# Epoch: 0001 Avg. cost = 0.237 Train Acc. = 0.95738184
# Epoch: 0001 Avg. cost = 0.237 Train Acc. = 0.95814544
# Epoch: 0001 Avg. cost = 0.238 Train Acc. = 0.9591454
# Epoch: 0001 Avg. cost = 0.238 Train Acc. = 0.95927274
# Epoch: 0001 Avg. cost = 0.239 Train Acc. = 0.95903635
# Epoch: 0001 Avg. cost = 0.239 Train Acc. = 0.95936364
# Epoch: 0001 Avg. cost = 0.239 Train Acc. = 0.9592909
# Epoch: 0001 Avg. cost = 0.240 Train Acc. = 0.9594727
# Epoch: 0001 Avg. cost = 0.240 Train Acc. = 0.95936364
# Epoch: 0001 Avg. cost = 0.241 Train Acc. = 0.95916367
# Epoch: 0001 Avg. cost = 0.241 Train Acc. = 0.9593273
# Epoch: 0001 Avg. cost = 0.242 Train Acc. = 0.9595818
# Epoch: 0001 Avg. cost = 0.242 Train Acc. = 0.9595636
# Epoch: 0001 Avg. cost = 0.242 Train Acc. = 0.9594909
# Epoch: 0001 Avg. cost = 0.243 Train Acc. = 0.9594182
# Epoch: 0001 Avg. cost = 0.243 Train Acc. = 0.95954543
# Epoch: 0001 Avg. cost = 0.244 Train Acc. = 0.96007276
# Epoch: 0001 Avg. cost = 0.244 Train Acc. = 0.9601091
# Epoch: 0001 Avg. cost = 0.244 Train Acc. = 0.9601273
# Epoch: 0001 Avg. cost = 0.245 Train Acc. = 0.9601273
# Epoch: 0001 Avg. cost = 0.245 Train Acc. = 0.9600545
# Epoch: 0001 Avg. cost = 0.246 Train Acc. = 0.95983636
# Epoch: 0001 Avg. cost = 0.246 Train Acc. = 0.96009094
# Epoch: 0001 Avg. cost = 0.247 Train Acc. = 0.96009094
# Epoch: 0001 Avg. cost = 0.247 Train Acc. = 0.9599818
# Epoch: 0001 Avg. cost = 0.248 Train Acc. = 0.95994544
# Epoch: 0001 Avg. cost = 0.248 Train Acc. = 0.9601091
# Epoch: 0001 Avg. cost = 0.248 Train Acc. = 0.96009094
# Epoch: 0001 Avg. cost = 0.249 Train Acc. = 0.9604
# Epoch: 0001 Avg. cost = 0.249 Train Acc. = 0.9603636
# Epoch: 0001 Avg. cost = 0.250 Train Acc. = 0.9602727
# Epoch: 0001 Avg. cost = 0.250 Train Acc. = 0.96043634
# Epoch: 0001 Avg. cost = 0.250 Train Acc. = 0.9600545
# Epoch: 0001 Avg. cost = 0.250 Train Acc. = 0.95936364
# Epoch: 0001 Avg. cost = 0.251 Train Acc. = 0.9583273
# Epoch: 0001 Avg. cost = 0.251 Train Acc. = 0.9574182
# Epoch: 0001 Avg. cost = 0.251 Train Acc. = 0.95649093
# Epoch: 0001 Avg. cost = 0.252 Train Acc. = 0.9569273
# Epoch: 0001 Avg. cost = 0.253 Train Acc. = 0.95663637
# Epoch: 0001 Avg. cost = 0.253 Train Acc. = 0.95683634
# Epoch: 0001 Avg. cost = 0.254 Train Acc. = 0.9580727
# Epoch: 0001 Avg. cost = 0.254 Train Acc. = 0.95878184
# Epoch: 0001 Avg. cost = 0.254 Train Acc. = 0.9597273
# Epoch: 0001 Avg. cost = 0.255 Train Acc. = 0.9602364
# Epoch: 0001 Avg. cost = 0.255 Train Acc. = 0.96056366
# Epoch: 0001 Avg. cost = 0.256 Train Acc. = 0.9607818
# Epoch: 0001 Avg. cost = 0.256 Train Acc. = 0.96107274
# Epoch: 0001 Avg. cost = 0.257 Train Acc. = 0.96156365
# Epoch: 0001 Avg. cost = 0.257 Train Acc. = 0.96147275
# Epoch: 0001 Avg. cost = 0.258 Train Acc. = 0.9614
# Epoch: 0001 Avg. cost = 0.258 Train Acc. = 0.9612182
# Epoch: 0001 Avg. cost = 0.259 Train Acc. = 0.9611818
# Epoch: 0001 Avg. cost = 0.259 Train Acc. = 0.9611273
# Epoch: 0001 Avg. cost = 0.259 Train Acc. = 0.9610182
# Epoch: 0001 Avg. cost = 0.260 Train Acc. = 0.9608182
# Epoch: 0001 Avg. cost = 0.261 Train Acc. = 0.9608727
# Epoch: 0001 Avg. cost = 0.261 Train Acc. = 0.96114546
# Epoch: 0001 Avg. cost = 0.262 Train Acc. = 0.9614182
# Epoch: 0001 Avg. cost = 0.262 Train Acc. = 0.96172726
# Epoch: 0001 Avg. cost = 0.262 Train Acc. = 0.96198183
# Epoch: 0001 Avg. cost = 0.263 Train Acc. = 0.9618
# Epoch: 0001 Avg. cost = 0.263 Train Acc. = 0.96183634
# Epoch: 0001 Avg. cost = 0.263 Train Acc. = 0.9619273
# Epoch: 0001 Avg. cost = 0.263 Train Acc. = 0.96198183
# Epoch: 0001 Avg. cost = 0.264 Train Acc. = 0.9618
# Epoch: 0001 Avg. cost = 0.264 Train Acc. = 0.96187276
# Epoch: 0001 Avg. cost = 0.264 Train Acc. = 0.9615091
# Epoch: 0001 Avg. cost = 0.265 Train Acc. = 0.962
# Epoch: 0001 Avg. cost = 0.265 Train Acc. = 0.9618545
# Epoch: 0001 Avg. cost = 0.266 Train Acc. = 0.96214545
# Epoch: 0001 Avg. cost = 0.266 Train Acc. = 0.9621091
# Epoch: 0001 Avg. cost = 0.267 Train Acc. = 0.9618545
# Epoch: 0001 Avg. cost = 0.267 Train Acc. = 0.96154547
# Epoch: 0001 Avg. cost = 0.268 Train Acc. = 0.96165454
# Epoch: 0001 Avg. cost = 0.268 Train Acc. = 0.9617091
# Epoch: 0001 Avg. cost = 0.269 Train Acc. = 0.96212727
# Epoch: 0001 Avg. cost = 0.269 Train Acc. = 0.9620364
# Epoch: 0001 Avg. cost = 0.269 Train Acc. = 0.96230906
# Epoch: 0001 Avg. cost = 0.270 Train Acc. = 0.962
# Epoch: 0001 Avg. cost = 0.270 Train Acc. = 0.9617636
# Epoch: 0001 Avg. cost = 0.270 Train Acc. = 0.9619273
# Epoch: 0001 Avg. cost = 0.271 Train Acc. = 0.96207273
# Epoch: 0001 Avg. cost = 0.271 Train Acc. = 0.96183634
# Epoch: 0001 Avg. cost = 0.272 Train Acc. = 0.9613636
# Epoch: 0001 Avg. cost = 0.272 Train Acc. = 0.96076363
# Epoch: 0001 Avg. cost = 0.273 Train Acc. = 0.96083635
# Epoch: 0001 Avg. cost = 0.273 Train Acc. = 0.9610364
# Epoch: 0001 Avg. cost = 0.274 Train Acc. = 0.96076363
# Epoch: 0001 Avg. cost = 0.274 Train Acc. = 0.9606182
# Epoch: 0001 Avg. cost = 0.274 Train Acc. = 0.96065456
# Epoch: 0001 Avg. cost = 0.275 Train Acc. = 0.96116364
# Epoch: 0001 Avg. cost = 0.275 Train Acc. = 0.96198183
# Epoch: 0001 Avg. cost = 0.276 Train Acc. = 0.9625091
# Epoch: 0001 Avg. cost = 0.276 Train Acc. = 0.9628
# Epoch: 0001 Avg. cost = 0.276 Train Acc. = 0.96327275
# Epoch: 0001 Avg. cost = 0.277 Train Acc. = 0.9635091
# Epoch: 0001 Avg. cost = 0.277 Train Acc. = 0.9638182
# Epoch: 0001 Avg. cost = 0.278 Train Acc. = 0.9638364
# Epoch: 0001 Avg. cost = 0.278 Train Acc. = 0.9642364
# Epoch: 0001 Avg. cost = 0.278 Train Acc. = 0.96443635
# Epoch: 0001 Avg. cost = 0.279 Train Acc. = 0.96443635
# Epoch: 0001 Avg. cost = 0.279 Train Acc. = 0.9648727
# Epoch: 0001 Avg. cost = 0.279 Train Acc. = 0.96534544
# Epoch: 0001 Avg. cost = 0.280 Train Acc. = 0.9647818
# Epoch: 0001 Avg. cost = 0.280 Train Acc. = 0.96436363
# Epoch: 0001 Avg. cost = 0.281 Train Acc. = 0.9641455
# Epoch: 0001 Avg. cost = 0.281 Train Acc. = 0.96392727
# Epoch: 0001 Avg. cost = 0.281 Train Acc. = 0.9637455
# Epoch: 0001 Avg. cost = 0.281 Train Acc. = 0.96387273
# Epoch: 0001 Avg. cost = 0.282 Train Acc. = 0.9634727
# Epoch: 0001 Avg. cost = 0.282 Train Acc. = 0.9637091
# Epoch: 0001 Avg. cost = 0.283 Train Acc. = 0.9636727
# Epoch: 0001 Avg. cost = 0.283 Train Acc. = 0.9641273
# Epoch: 0001 Avg. cost = 0.284 Train Acc. = 0.9642182
# Epoch: 0001 Avg. cost = 0.284 Train Acc. = 0.9643273
# Epoch: 0001 Avg. cost = 0.284 Train Acc. = 0.9647091
# Epoch: 0001 Avg. cost = 0.285 Train Acc. = 0.96532726
# Epoch: 0001 Avg. cost = 0.285 Train Acc. = 0.9655091
# Epoch: 0001 Avg. cost = 0.286 Train Acc. = 0.96543634
# Epoch: 0001 Avg. cost = 0.286 Train Acc. = 0.9651818
# Epoch: 0001 Avg. cost = 0.286 Train Acc. = 0.96507275
# Epoch: 0001 Avg. cost = 0.287 Train Acc. = 0.9654
# Epoch: 0001 Avg. cost = 0.287 Train Acc. = 0.96507275
# Epoch: 0001 Avg. cost = 0.287 Train Acc. = 0.96450907
# Epoch: 0001 Avg. cost = 0.288 Train Acc. = 0.9640909
# Epoch: 0001 Avg. cost = 0.288 Train Acc. = 0.9640727
# Epoch: 0001 Avg. cost = 0.289 Train Acc. = 0.9643273
# Epoch: 0001 Avg. cost = 0.289 Train Acc. = 0.9644
# Epoch: 0001 Avg. cost = 0.289 Train Acc. = 0.9646364
# Epoch: 0001 Avg. cost = 0.290 Train Acc. = 0.96509093
# Epoch: 0001 Avg. cost = 0.290 Train Acc. = 0.96581817
# Epoch: 0001 Avg. cost = 0.290 Train Acc. = 0.9661091
# Epoch: 0001 Avg. cost = 0.291 Train Acc. = 0.96681815
# Epoch: 0001 Avg. cost = 0.291 Train Acc. = 0.9668
# Epoch: 0001 Avg. cost = 0.291 Train Acc. = 0.96665454
# Epoch: 0001 Avg. cost = 0.291 Train Acc. = 0.96647274
# Epoch: 0001 Avg. cost = 0.292 Train Acc. = 0.96654546
# Epoch: 0001 Avg. cost = 0.292 Train Acc. = 0.96672726
# Epoch: 0001 Avg. cost = 0.292 Train Acc. = 0.9668364
# Epoch: 0001 Avg. cost = 0.293 Train Acc. = 0.96665454
# Epoch: 0001 Avg. cost = 0.293 Train Acc. = 0.9665091
# Epoch: 0001 Avg. cost = 0.294 Train Acc. = 0.96696365
# Epoch: 0001 Avg. cost = 0.294 Train Acc. = 0.96681815
# Epoch: 0001 Avg. cost = 0.294 Train Acc. = 0.96714544
# Epoch: 0001 Avg. cost = 0.295 Train Acc. = 0.96745455
# Epoch: 0001 Avg. cost = 0.295 Train Acc. = 0.9674
# Epoch: 0001 Avg. cost = 0.295 Train Acc. = 0.9674909
# Epoch: 0001 Avg. cost = 0.296 Train Acc. = 0.9672727
# Epoch: 0001 Avg. cost = 0.296 Train Acc. = 0.96723634
# Epoch: 0001 Avg. cost = 0.296 Train Acc. = 0.9671818
# Epoch: 0001 Avg. cost = 0.297 Train Acc. = 0.9675091
# Epoch: 0001 Avg. cost = 0.297 Train Acc. = 0.9670909
# Epoch: 0001 Avg. cost = 0.297 Train Acc. = 0.967
# Epoch: 0001 Avg. cost = 0.298 Train Acc. = 0.9668546
# Epoch: 0001 Avg. cost = 0.298 Train Acc. = 0.96656364
# Epoch: 0001 Avg. cost = 0.299 Train Acc. = 0.9670909
# Epoch: 0001 Avg. cost = 0.299 Train Acc. = 0.96703637
# Epoch: 0001 Avg. cost = 0.299 Train Acc. = 0.96689093
# Epoch: 0001 Avg. cost = 0.300 Train Acc. = 0.96681815
# Epoch: 0001 Avg. cost = 0.300 Train Acc. = 0.9666727
# Epoch: 0001 Avg. cost = 0.300 Train Acc. = 0.9670182
# Epoch: 0001 Avg. cost = 0.300 Train Acc. = 0.96694547
# Epoch: 0001 Avg. cost = 0.301 Train Acc. = 0.967
# Epoch: 0001 Avg. cost = 0.302 Train Acc. = 0.9670909
# Epoch: 0001 Avg. cost = 0.302 Train Acc. = 0.96738183
# Epoch: 0001 Avg. cost = 0.302 Train Acc. = 0.9674182
# Epoch: 0001 Avg. cost = 0.303 Train Acc. = 0.9677455
# Epoch: 0001 Avg. cost = 0.303 Train Acc. = 0.96778184
# Epoch: 0001 Avg. cost = 0.304 Train Acc. = 0.9676727
# Epoch: 0001 Avg. cost = 0.304 Train Acc. = 0.9674
# Epoch: 0001 Avg. cost = 0.304 Train Acc. = 0.967
# Epoch: 0001 Avg. cost = 0.304 Train Acc. = 0.96681815
# Epoch: 0001 Avg. cost = 0.305 Train Acc. = 0.9666182
# Epoch: 0001 Avg. cost = 0.305 Train Acc. = 0.9666182
# Epoch: 0001 Avg. cost = 0.306 Train Acc. = 0.9666
# Epoch: 0001 Avg. cost = 0.307 Train Acc. = 0.9664
# Epoch: 0001 Avg. cost = 0.307 Train Acc. = 0.9663091
# Epoch: 0001 Avg. cost = 0.308 Train Acc. = 0.96645457
# Epoch: 0001 Avg. cost = 0.308 Train Acc. = 0.9668546
# Epoch: 0001 Avg. cost = 0.308 Train Acc. = 0.96674544
# Epoch: 0001 Avg. cost = 0.309 Train Acc. = 0.96736366
# Epoch: 0001 Avg. cost = 0.309 Train Acc. = 0.9671636
# Epoch: 0001 Avg. cost = 0.309 Train Acc. = 0.96754545
# Epoch: 0001 Avg. cost = 0.310 Train Acc. = 0.9678364
# Epoch: 0001 Avg. cost = 0.310 Train Acc. = 0.96772724
# Epoch: 0001 Avg. cost = 0.310 Train Acc. = 0.96763635
# Epoch: 0001 Avg. cost = 0.311 Train Acc. = 0.96772724
# Epoch: 0001 Avg. cost = 0.311 Train Acc. = 0.9675818
# Epoch: 0001 Avg. cost = 0.311 Train Acc. = 0.9674909
# Epoch: 0001 Avg. cost = 0.312 Train Acc. = 0.96738183
# Epoch: 0001 Avg. cost = 0.312 Train Acc. = 0.9672545
# Epoch: 0001 Avg. cost = 0.313 Train Acc. = 0.9673091
# Epoch: 0001 Avg. cost = 0.313 Train Acc. = 0.9676
# Epoch: 0001 Avg. cost = 0.314 Train Acc. = 0.96814543
# Epoch: 0001 Avg. cost = 0.314 Train Acc. = 0.96852726
# Epoch: 0001 Avg. cost = 0.314 Train Acc. = 0.96867275
# Epoch: 0001 Avg. cost = 0.315 Train Acc. = 0.9688727
# Epoch: 0001 Avg. cost = 0.315 Train Acc. = 0.9689636
# Epoch: 0001 Avg. cost = 0.315 Train Acc. = 0.96894544
# Epoch: 0001 Avg. cost = 0.316 Train Acc. = 0.9688727
# Epoch: 0001 Avg. cost = 0.317 Train Acc. = 0.96943635
# Epoch: 0001 Avg. cost = 0.317 Train Acc. = 0.9694909
# Epoch: 0001 Avg. cost = 0.317 Train Acc. = 0.96976364
# Epoch: 0001 Avg. cost = 0.318 Train Acc. = 0.9699091
# Epoch: 0001 Avg. cost = 0.318 Train Acc. = 0.9701091
# Epoch: 0001 Avg. cost = 0.318 Train Acc. = 0.9696909
# Epoch: 0001 Avg. cost = 0.319 Train Acc. = 0.96952724
# Epoch: 0001 Avg. cost = 0.319 Train Acc. = 0.96941817
# Epoch: 0001 Avg. cost = 0.319 Train Acc. = 0.9691455
# Epoch: 0001 Avg. cost = 0.320 Train Acc. = 0.96941817
# Epoch: 0001 Avg. cost = 0.320 Train Acc. = 0.9693273
# Epoch: 0001 Avg. cost = 0.320 Train Acc. = 0.9691091
# Epoch: 0001 Avg. cost = 0.321 Train Acc. = 0.96934545
# Epoch: 0001 Avg. cost = 0.321 Train Acc. = 0.9694909
# Epoch: 0001 Avg. cost = 0.321 Train Acc. = 0.9696182
# Epoch: 0001 Avg. cost = 0.322 Train Acc. = 0.9698
# Epoch: 0001 Avg. cost = 0.322 Train Acc. = 0.96956366
# Epoch: 0001 Avg. cost = 0.322 Train Acc. = 0.9696909
# Epoch: 0001 Avg. cost = 0.323 Train Acc. = 0.96965456
# Epoch: 0001 Avg. cost = 0.323 Train Acc. = 0.9693818
# Epoch: 0001 Avg. cost = 0.323 Train Acc. = 0.9691455
# Epoch: 0001 Avg. cost = 0.323 Train Acc. = 0.9688909
# Epoch: 0001 Avg. cost = 0.324 Train Acc. = 0.96918184
# Epoch: 0001 Avg. cost = 0.324 Train Acc. = 0.9694545
# Epoch: 0001 Avg. cost = 0.325 Train Acc. = 0.96925455
# Epoch: 0001 Avg. cost = 0.325 Train Acc. = 0.96936363
# Epoch: 0001 Avg. cost = 0.325 Train Acc. = 0.96965456
# Epoch: 0001 Avg. cost = 0.326 Train Acc. = 0.9697273
# Epoch: 0001 Avg. cost = 0.326 Train Acc. = 0.96956366
# Epoch: 0001 Avg. cost = 0.326 Train Acc. = 0.9694545
# Epoch: 0001 Avg. cost = 0.327 Train Acc. = 0.9693273
# Epoch: 0001 Avg. cost = 0.327 Train Acc. = 0.96950907
# Epoch: 0001 Avg. cost = 0.327 Train Acc. = 0.9691273
# Epoch: 0001 Avg. cost = 0.328 Train Acc. = 0.9693091
# Epoch: 0001 Avg. cost = 0.328 Train Acc. = 0.96952724
# Epoch: 0001 Avg. cost = 0.328 Train Acc. = 0.96936363
# Epoch: 0001 Avg. cost = 0.329 Train Acc. = 0.96943635
# Epoch: 0001 Avg. cost = 0.329 Train Acc. = 0.96992725
# Epoch: 0001 Avg. cost = 0.329 Train Acc. = 0.97007275
# Epoch: 0001 Avg. cost = 0.330 Train Acc. = 0.97041816
# Epoch: 0001 Avg. cost = 0.330 Train Acc. = 0.9706909
# Epoch: 0001 Avg. cost = 0.330 Train Acc. = 0.97114545
# Epoch: 0001 Avg. cost = 0.330 Train Acc. = 0.9712545
# Epoch: 0001 Avg. cost = 0.331 Train Acc. = 0.9713455
# Epoch: 0001 Avg. cost = 0.331 Train Acc. = 0.97096366
# Epoch: 0001 Avg. cost = 0.332 Train Acc. = 0.9709091
# Epoch: 0001 Avg. cost = 0.332 Train Acc. = 0.97049093
# Epoch: 0001 Avg. cost = 0.332 Train Acc. = 0.97016364
# Epoch: 0001 Avg. cost = 0.333 Train Acc. = 0.9700364
# Epoch: 0002 Avg. cost = 0.000 Train Acc. = 0.96983635
# Epoch: 0002 Avg. cost = 0.001 Train Acc. = 0.9696909
# Epoch: 0002 Avg. cost = 0.001 Train Acc. = 0.9697091
# Epoch: 0002 Avg. cost = 0.001 Train Acc. = 0.96956366
# Epoch: 0002 Avg. cost = 0.002 Train Acc. = 0.96925455
# Epoch: 0002 Avg. cost = 0.002 Train Acc. = 0.96903634
# Epoch: 0002 Avg. cost = 0.002 Train Acc. = 0.9693818
# Epoch: 0002 Avg. cost = 0.003 Train Acc. = 0.96976364
# Epoch: 0002 Avg. cost = 0.003 Train Acc. = 0.9698909
# Epoch: 0002 Avg. cost = 0.003 Train Acc. = 0.97034544
# Epoch: 0002 Avg. cost = 0.004 Train Acc. = 0.97081816
# Epoch: 0002 Avg. cost = 0.004 Train Acc. = 0.97074544
# Epoch: 0002 Avg. cost = 0.004 Train Acc. = 0.97016364
# Epoch: 0002 Avg. cost = 0.005 Train Acc. = 0.9701273
# Epoch: 0002 Avg. cost = 0.005 Train Acc. = 0.9698727
# Epoch: 0002 Avg. cost = 0.006 Train Acc. = 0.96976364
# Epoch: 0002 Avg. cost = 0.006 Train Acc. = 0.9699636
# Epoch: 0002 Avg. cost = 0.007 Train Acc. = 0.9701091
# Epoch: 0002 Avg. cost = 0.007 Train Acc. = 0.96994543
# Epoch: 0002 Avg. cost = 0.007 Train Acc. = 0.9698909
# Epoch: 0002 Avg. cost = 0.007 Train Acc. = 0.96967274
# Epoch: 0002 Avg. cost = 0.008 Train Acc. = 0.9692364
# Epoch: 0002 Avg. cost = 0.008 Train Acc. = 0.96958184
# Epoch: 0002 Avg. cost = 0.008 Train Acc. = 0.97016364
# Epoch: 0002 Avg. cost = 0.009 Train Acc. = 0.97049093
# Epoch: 0002 Avg. cost = 0.009 Train Acc. = 0.9705455
# Epoch: 0002 Avg. cost = 0.009 Train Acc. = 0.9708909
# Epoch: 0002 Avg. cost = 0.010 Train Acc. = 0.97083634
# Epoch: 0002 Avg. cost = 0.010 Train Acc. = 0.97130907
# Epoch: 0002 Avg. cost = 0.010 Train Acc. = 0.97138184
# Epoch: 0002 Avg. cost = 0.011 Train Acc. = 0.9711818
# Epoch: 0002 Avg. cost = 0.011 Train Acc. = 0.9709091
# Epoch: 0002 Avg. cost = 0.011 Train Acc. = 0.97072726
# Epoch: 0002 Avg. cost = 0.012 Train Acc. = 0.9706727
# Epoch: 0002 Avg. cost = 0.012 Train Acc. = 0.97056365
# Epoch: 0002 Avg. cost = 0.013 Train Acc. = 0.9702727
# Epoch: 0002 Avg. cost = 0.013 Train Acc. = 0.9698909
# Epoch: 0002 Avg. cost = 0.013 Train Acc. = 0.96950907
# Epoch: 0002 Avg. cost = 0.014 Train Acc. = 0.96925455
# Epoch: 0002 Avg. cost = 0.014 Train Acc. = 0.9690545
# Epoch: 0002 Avg. cost = 0.014 Train Acc. = 0.969
# Epoch: 0002 Avg. cost = 0.014 Train Acc. = 0.9689636
# Epoch: 0002 Avg. cost = 0.015 Train Acc. = 0.9689091
# Epoch: 0002 Avg. cost = 0.015 Train Acc. = 0.96892726
# Epoch: 0002 Avg. cost = 0.016 Train Acc. = 0.96901816
# Epoch: 0002 Avg. cost = 0.016 Train Acc. = 0.9694545
# Epoch: 0002 Avg. cost = 0.016 Train Acc. = 0.96950907
# Epoch: 0002 Avg. cost = 0.016 Train Acc. = 0.96934545
# Epoch: 0002 Avg. cost = 0.017 Train Acc. = 0.96950907
# Epoch: 0002 Avg. cost = 0.017 Train Acc. = 0.96958184
# Epoch: 0002 Avg. cost = 0.017 Train Acc. = 0.9698182
# Epoch: 0002 Avg. cost = 0.017 Train Acc. = 0.9696909
# Epoch: 0002 Avg. cost = 0.018 Train Acc. = 0.9698
# Epoch: 0002 Avg. cost = 0.018 Train Acc. = 0.96992725
# Epoch: 0002 Avg. cost = 0.019 Train Acc. = 0.9700364
# Epoch: 0002 Avg. cost = 0.019 Train Acc. = 0.97025454
# Epoch: 0002 Avg. cost = 0.019 Train Acc. = 0.9705273
# Epoch: 0002 Avg. cost = 0.020 Train Acc. = 0.97049093
# Epoch: 0002 Avg. cost = 0.020 Train Acc. = 0.9707091
# Epoch: 0002 Avg. cost = 0.020 Train Acc. = 0.9709091
# Epoch: 0002 Avg. cost = 0.020 Train Acc. = 0.97121817
# Epoch: 0002 Avg. cost = 0.021 Train Acc. = 0.97163635
# Epoch: 0002 Avg. cost = 0.021 Train Acc. = 0.97147274
# Epoch: 0002 Avg. cost = 0.022 Train Acc. = 0.9714
# Epoch: 0002 Avg. cost = 0.022 Train Acc. = 0.9716909
# Epoch: 0002 Avg. cost = 0.022 Train Acc. = 0.97194546
# Epoch: 0002 Avg. cost = 0.023 Train Acc. = 0.97238183
# Epoch: 0002 Avg. cost = 0.023 Train Acc. = 0.97252727
# Epoch: 0002 Avg. cost = 0.023 Train Acc. = 0.9725818
# Epoch: 0002 Avg. cost = 0.023 Train Acc. = 0.97243637
# Epoch: 0002 Avg. cost = 0.023 Train Acc. = 0.97236365
# Epoch: 0002 Avg. cost = 0.024 Train Acc. = 0.97245455
# Epoch: 0002 Avg. cost = 0.024 Train Acc. = 0.97223634
# Epoch: 0002 Avg. cost = 0.024 Train Acc. = 0.97227275
# Epoch: 0002 Avg. cost = 0.025 Train Acc. = 0.97212726
# Epoch: 0002 Avg. cost = 0.025 Train Acc. = 0.97205454
# Epoch: 0002 Avg. cost = 0.026 Train Acc. = 0.9720909
# Epoch: 0002 Avg. cost = 0.026 Train Acc. = 0.9719818
# Epoch: 0002 Avg. cost = 0.026 Train Acc. = 0.97185457
# Epoch: 0002 Avg. cost = 0.026 Train Acc. = 0.97174543
# Epoch: 0002 Avg. cost = 0.027 Train Acc. = 0.9715091
# Epoch: 0002 Avg. cost = 0.027 Train Acc. = 0.9715091
# Epoch: 0002 Avg. cost = 0.028 Train Acc. = 0.9718
# Epoch: 0002 Avg. cost = 0.028 Train Acc. = 0.97212726
# Epoch: 0002 Avg. cost = 0.028 Train Acc. = 0.9723091
# Epoch: 0002 Avg. cost = 0.028 Train Acc. = 0.97229093
# Epoch: 0002 Avg. cost = 0.029 Train Acc. = 0.9723091
# Epoch: 0002 Avg. cost = 0.029 Train Acc. = 0.97263634
# Epoch: 0002 Avg. cost = 0.029 Train Acc. = 0.97312725
# Epoch: 0002 Avg. cost = 0.030 Train Acc. = 0.97334546
# Epoch: 0002 Avg. cost = 0.030 Train Acc. = 0.9734
# Epoch: 0002 Avg. cost = 0.030 Train Acc. = 0.97383636
# Epoch: 0002 Avg. cost = 0.031 Train Acc. = 0.9742182
# Epoch: 0002 Avg. cost = 0.031 Train Acc. = 0.9743818
# Epoch: 0002 Avg. cost = 0.031 Train Acc. = 0.9744
# Epoch: 0002 Avg. cost = 0.032 Train Acc. = 0.9745455
# Epoch: 0002 Avg. cost = 0.032 Train Acc. = 0.9745455
# Epoch: 0002 Avg. cost = 0.032 Train Acc. = 0.9744727
# Epoch: 0002 Avg. cost = 0.033 Train Acc. = 0.97465456
# Epoch: 0002 Avg. cost = 0.033 Train Acc. = 0.9746182
# Epoch: 0002 Avg. cost = 0.033 Train Acc. = 0.97434545
# Epoch: 0002 Avg. cost = 0.033 Train Acc. = 0.9742727
# Epoch: 0002 Avg. cost = 0.033 Train Acc. = 0.9741273
# Epoch: 0002 Avg. cost = 0.034 Train Acc. = 0.9741091
# Epoch: 0002 Avg. cost = 0.034 Train Acc. = 0.974
# Epoch: 0002 Avg. cost = 0.034 Train Acc. = 0.97376364
# Epoch: 0002 Avg. cost = 0.034 Train Acc. = 0.9739818
# Epoch: 0002 Avg. cost = 0.035 Train Acc. = 0.9739091
# Epoch: 0002 Avg. cost = 0.035 Train Acc. = 0.9737818
# Epoch: 0002 Avg. cost = 0.035 Train Acc. = 0.9738
# Epoch: 0002 Avg. cost = 0.036 Train Acc. = 0.9736364
# Epoch: 0002 Avg. cost = 0.036 Train Acc. = 0.9734
# Epoch: 0002 Avg. cost = 0.036 Train Acc. = 0.9732909
# Epoch: 0002 Avg. cost = 0.036 Train Acc. = 0.9734909
# Epoch: 0002 Avg. cost = 0.037 Train Acc. = 0.9736364
# Epoch: 0002 Avg. cost = 0.037 Train Acc. = 0.9736182
# Epoch: 0002 Avg. cost = 0.037 Train Acc. = 0.9736182
# Epoch: 0002 Avg. cost = 0.037 Train Acc. = 0.97327274
# Epoch: 0002 Avg. cost = 0.038 Train Acc. = 0.9734182
# Epoch: 0002 Avg. cost = 0.038 Train Acc. = 0.9733091
# Epoch: 0002 Avg. cost = 0.038 Train Acc. = 0.9733091
# Epoch: 0002 Avg. cost = 0.038 Train Acc. = 0.9729273
# Epoch: 0002 Avg. cost = 0.039 Train Acc. = 0.9726545
# Epoch: 0002 Avg. cost = 0.039 Train Acc. = 0.9726
# Epoch: 0002 Avg. cost = 0.039 Train Acc. = 0.97243637
# Epoch: 0002 Avg. cost = 0.040 Train Acc. = 0.97245455
# Epoch: 0002 Avg. cost = 0.040 Train Acc. = 0.9724727
# Epoch: 0002 Avg. cost = 0.041 Train Acc. = 0.97243637
# Epoch: 0002 Avg. cost = 0.041 Train Acc. = 0.9728909
# Epoch: 0002 Avg. cost = 0.041 Train Acc. = 0.9729273
# Epoch: 0002 Avg. cost = 0.041 Train Acc. = 0.97294545
# Epoch: 0002 Avg. cost = 0.041 Train Acc. = 0.97294545
# Epoch: 0002 Avg. cost = 0.042 Train Acc. = 0.9729091
# Epoch: 0002 Avg. cost = 0.042 Train Acc. = 0.97312725
# Epoch: 0002 Avg. cost = 0.043 Train Acc. = 0.9731454
# Epoch: 0002 Avg. cost = 0.043 Train Acc. = 0.97301817
# Epoch: 0002 Avg. cost = 0.043 Train Acc. = 0.9732
# Epoch: 0002 Avg. cost = 0.044 Train Acc. = 0.973
# Epoch: 0002 Avg. cost = 0.044 Train Acc. = 0.97287273
# Epoch: 0002 Avg. cost = 0.044 Train Acc. = 0.9726545
# Epoch: 0002 Avg. cost = 0.045 Train Acc. = 0.9723273
# Epoch: 0002 Avg. cost = 0.045 Train Acc. = 0.97212726
# Epoch: 0002 Avg. cost = 0.045 Train Acc. = 0.9717636
# Epoch: 0002 Avg. cost = 0.045 Train Acc. = 0.97147274
# Epoch: 0002 Avg. cost = 0.045 Train Acc. = 0.97138184
# Epoch: 0002 Avg. cost = 0.046 Train Acc. = 0.97116363
# Epoch: 0002 Avg. cost = 0.046 Train Acc. = 0.9710182
# Epoch: 0002 Avg. cost = 0.046 Train Acc. = 0.9709455
# Epoch: 0002 Avg. cost = 0.046 Train Acc. = 0.9708727
# Epoch: 0002 Avg. cost = 0.047 Train Acc. = 0.9706727
# Epoch: 0002 Avg. cost = 0.047 Train Acc. = 0.97063637
# Epoch: 0002 Avg. cost = 0.047 Train Acc. = 0.9710909
# Epoch: 0002 Avg. cost = 0.048 Train Acc. = 0.97156364
# Epoch: 0002 Avg. cost = 0.048 Train Acc. = 0.97214544
# Epoch: 0002 Avg. cost = 0.048 Train Acc. = 0.97221816
# Epoch: 0002 Avg. cost = 0.049 Train Acc. = 0.97227275
# Epoch: 0002 Avg. cost = 0.049 Train Acc. = 0.97221816
# Epoch: 0002 Avg. cost = 0.049 Train Acc. = 0.9724909
# Epoch: 0002 Avg. cost = 0.050 Train Acc. = 0.9725091
# Epoch: 0002 Avg. cost = 0.050 Train Acc. = 0.97263634
# Epoch: 0002 Avg. cost = 0.051 Train Acc. = 0.97278184
# Epoch: 0002 Avg. cost = 0.051 Train Acc. = 0.97254544
# Epoch: 0002 Avg. cost = 0.051 Train Acc. = 0.9723273
# Epoch: 0002 Avg. cost = 0.052 Train Acc. = 0.9721636
# Epoch: 0002 Avg. cost = 0.052 Train Acc. = 0.9719273
# Epoch: 0002 Avg. cost = 0.052 Train Acc. = 0.9722546
# Epoch: 0002 Avg. cost = 0.053 Train Acc. = 0.97203636
# Epoch: 0002 Avg. cost = 0.053 Train Acc. = 0.9720727
# Epoch: 0002 Avg. cost = 0.054 Train Acc. = 0.9718
# Epoch: 0002 Avg. cost = 0.054 Train Acc. = 0.9719818
# Epoch: 0002 Avg. cost = 0.054 Train Acc. = 0.9719091
# Epoch: 0002 Avg. cost = 0.054 Train Acc. = 0.97174543
# Epoch: 0002 Avg. cost = 0.055 Train Acc. = 0.9715818
# Epoch: 0002 Avg. cost = 0.055 Train Acc. = 0.9713455
# Epoch: 0002 Avg. cost = 0.056 Train Acc. = 0.9714182
# Epoch: 0002 Avg. cost = 0.056 Train Acc. = 0.9714182
# Epoch: 0002 Avg. cost = 0.056 Train Acc. = 0.9712727
# Epoch: 0002 Avg. cost = 0.057 Train Acc. = 0.9715273
# Epoch: 0002 Avg. cost = 0.057 Train Acc. = 0.9716182
# Epoch: 0002 Avg. cost = 0.057 Train Acc. = 0.9717818
# Epoch: 0002 Avg. cost = 0.057 Train Acc. = 0.97172725
# Epoch: 0002 Avg. cost = 0.058 Train Acc. = 0.97194546
# Epoch: 0002 Avg. cost = 0.058 Train Acc. = 0.9718909
# Epoch: 0002 Avg. cost = 0.058 Train Acc. = 0.9722546
# Epoch: 0002 Avg. cost = 0.059 Train Acc. = 0.9724
# Epoch: 0002 Avg. cost = 0.059 Train Acc. = 0.9724
# Epoch: 0002 Avg. cost = 0.059 Train Acc. = 0.9724909
# Epoch: 0002 Avg. cost = 0.059 Train Acc. = 0.9726909
# Epoch: 0002 Avg. cost = 0.060 Train Acc. = 0.9726727
# Epoch: 0002 Avg. cost = 0.060 Train Acc. = 0.9729818
# Epoch: 0002 Avg. cost = 0.060 Train Acc. = 0.97276366
# Epoch: 0002 Avg. cost = 0.060 Train Acc. = 0.97278184
# Epoch: 0002 Avg. cost = 0.061 Train Acc. = 0.97263634
# Epoch: 0002 Avg. cost = 0.061 Train Acc. = 0.9727273
# Epoch: 0002 Avg. cost = 0.061 Train Acc. = 0.9729091
# Epoch: 0002 Avg. cost = 0.062 Train Acc. = 0.97316366
# Epoch: 0002 Avg. cost = 0.062 Train Acc. = 0.9735091
# Epoch: 0002 Avg. cost = 0.062 Train Acc. = 0.97354543
# Epoch: 0002 Avg. cost = 0.062 Train Acc. = 0.9737818
# Epoch: 0002 Avg. cost = 0.063 Train Acc. = 0.9735818
# Epoch: 0002 Avg. cost = 0.063 Train Acc. = 0.9736182
# Epoch: 0002 Avg. cost = 0.063 Train Acc. = 0.9735818
# Epoch: 0002 Avg. cost = 0.063 Train Acc. = 0.97343636
# Epoch: 0002 Avg. cost = 0.064 Train Acc. = 0.9734182
# Epoch: 0002 Avg. cost = 0.064 Train Acc. = 0.97318184
# Epoch: 0002 Avg. cost = 0.064 Train Acc. = 0.9733091
# Epoch: 0002 Avg. cost = 0.064 Train Acc. = 0.9732909
# Epoch: 0002 Avg. cost = 0.065 Train Acc. = 0.97352725
# Epoch: 0002 Avg. cost = 0.065 Train Acc. = 0.97365457
# Epoch: 0002 Avg. cost = 0.066 Train Acc. = 0.9738909
# Epoch: 0002 Avg. cost = 0.066 Train Acc. = 0.97383636
# Epoch: 0002 Avg. cost = 0.066 Train Acc. = 0.9739818
# Epoch: 0002 Avg. cost = 0.067 Train Acc. = 0.97418183
# Epoch: 0002 Avg. cost = 0.067 Train Acc. = 0.9744909
# Epoch: 0002 Avg. cost = 0.067 Train Acc. = 0.9744545
# Epoch: 0002 Avg. cost = 0.067 Train Acc. = 0.97481817
# Epoch: 0002 Avg. cost = 0.067 Train Acc. = 0.9750364
# Epoch: 0002 Avg. cost = 0.067 Train Acc. = 0.97523636
# Epoch: 0002 Avg. cost = 0.068 Train Acc. = 0.9755273
# Epoch: 0002 Avg. cost = 0.068 Train Acc. = 0.9761091
# Epoch: 0002 Avg. cost = 0.069 Train Acc. = 0.97621816
# Epoch: 0002 Avg. cost = 0.069 Train Acc. = 0.9761818
# Epoch: 0002 Avg. cost = 0.069 Train Acc. = 0.97596365
# Epoch: 0002 Avg. cost = 0.069 Train Acc. = 0.9756909
# Epoch: 0002 Avg. cost = 0.070 Train Acc. = 0.97523636
# Epoch: 0002 Avg. cost = 0.070 Train Acc. = 0.97476363
# Epoch: 0002 Avg. cost = 0.070 Train Acc. = 0.9745455
# Epoch: 0002 Avg. cost = 0.070 Train Acc. = 0.9741091
# Epoch: 0002 Avg. cost = 0.071 Train Acc. = 0.97385454
# Epoch: 0002 Avg. cost = 0.071 Train Acc. = 0.97345454
# Epoch: 0002 Avg. cost = 0.071 Train Acc. = 0.974
# Epoch: 0002 Avg. cost = 0.072 Train Acc. = 0.97443634
# Epoch: 0002 Avg. cost = 0.072 Train Acc. = 0.97481817
# Epoch: 0002 Avg. cost = 0.073 Train Acc. = 0.9748909
# Epoch: 0002 Avg. cost = 0.073 Train Acc. = 0.9748
# Epoch: 0002 Avg. cost = 0.074 Train Acc. = 0.9751818
# Epoch: 0002 Avg. cost = 0.074 Train Acc. = 0.9750909
# Epoch: 0002 Avg. cost = 0.074 Train Acc. = 0.9751091
# Epoch: 0002 Avg. cost = 0.074 Train Acc. = 0.9754182
# Epoch: 0002 Avg. cost = 0.075 Train Acc. = 0.9756
# Epoch: 0002 Avg. cost = 0.075 Train Acc. = 0.9755091
# Epoch: 0002 Avg. cost = 0.075 Train Acc. = 0.97556365
# Epoch: 0002 Avg. cost = 0.076 Train Acc. = 0.9754909
# Epoch: 0002 Avg. cost = 0.076 Train Acc. = 0.9752727
# Epoch: 0002 Avg. cost = 0.076 Train Acc. = 0.9750364
# Epoch: 0002 Avg. cost = 0.077 Train Acc. = 0.9746909
# Epoch: 0002 Avg. cost = 0.077 Train Acc. = 0.9743091
# Epoch: 0002 Avg. cost = 0.077 Train Acc. = 0.97403634
# Epoch: 0002 Avg. cost = 0.078 Train Acc. = 0.97385454
# Epoch: 0002 Avg. cost = 0.078 Train Acc. = 0.97401816
# Epoch: 0002 Avg. cost = 0.078 Train Acc. = 0.97392726
# Epoch: 0002 Avg. cost = 0.079 Train Acc. = 0.97407275
# Epoch: 0002 Avg. cost = 0.079 Train Acc. = 0.9742909
# Epoch: 0002 Avg. cost = 0.080 Train Acc. = 0.97458184
# Epoch: 0002 Avg. cost = 0.080 Train Acc. = 0.97476363
# Epoch: 0002 Avg. cost = 0.080 Train Acc. = 0.9748545
# Epoch: 0002 Avg. cost = 0.080 Train Acc. = 0.9746909
# Epoch: 0002 Avg. cost = 0.081 Train Acc. = 0.9744727
# Epoch: 0002 Avg. cost = 0.081 Train Acc. = 0.9742727
# Epoch: 0002 Avg. cost = 0.081 Train Acc. = 0.97434545
# Epoch: 0002 Avg. cost = 0.082 Train Acc. = 0.97434545
# Epoch: 0002 Avg. cost = 0.082 Train Acc. = 0.9742727
# Epoch: 0002 Avg. cost = 0.082 Train Acc. = 0.9745273
# Epoch: 0002 Avg. cost = 0.083 Train Acc. = 0.9744909
# Epoch: 0002 Avg. cost = 0.083 Train Acc. = 0.9746182
# Epoch: 0002 Avg. cost = 0.083 Train Acc. = 0.97456366
# Epoch: 0002 Avg. cost = 0.083 Train Acc. = 0.9747818
# Epoch: 0002 Avg. cost = 0.083 Train Acc. = 0.97505456
# Epoch: 0002 Avg. cost = 0.084 Train Acc. = 0.9751091
# Epoch: 0002 Avg. cost = 0.084 Train Acc. = 0.97514546
# Epoch: 0002 Avg. cost = 0.084 Train Acc. = 0.9754909
# Epoch: 0002 Avg. cost = 0.084 Train Acc. = 0.9753636
# Epoch: 0002 Avg. cost = 0.085 Train Acc. = 0.9752909
# Epoch: 0002 Avg. cost = 0.085 Train Acc. = 0.97523636
# Epoch: 0002 Avg. cost = 0.085 Train Acc. = 0.97496367
# Epoch: 0002 Avg. cost = 0.086 Train Acc. = 0.9752727
# Epoch: 0002 Avg. cost = 0.086 Train Acc. = 0.97525454
# Epoch: 0002 Avg. cost = 0.086 Train Acc. = 0.97545457
# Epoch: 0002 Avg. cost = 0.087 Train Acc. = 0.97572726
# Epoch: 0002 Avg. cost = 0.087 Train Acc. = 0.97587276
# Epoch: 0002 Avg. cost = 0.087 Train Acc. = 0.9755273
# Epoch: 0002 Avg. cost = 0.088 Train Acc. = 0.9755273
# Epoch: 0002 Avg. cost = 0.088 Train Acc. = 0.9755273
# Epoch: 0002 Avg. cost = 0.088 Train Acc. = 0.9756909
# Epoch: 0002 Avg. cost = 0.089 Train Acc. = 0.9755091
# Epoch: 0002 Avg. cost = 0.089 Train Acc. = 0.9753818
# Epoch: 0002 Avg. cost = 0.090 Train Acc. = 0.97547275
# Epoch: 0002 Avg. cost = 0.090 Train Acc. = 0.9756
# Epoch: 0002 Avg. cost = 0.090 Train Acc. = 0.97547275
# Epoch: 0002 Avg. cost = 0.090 Train Acc. = 0.9753091
# Epoch: 0002 Avg. cost = 0.091 Train Acc. = 0.9754182
# Epoch: 0002 Avg. cost = 0.091 Train Acc. = 0.9753818
# Epoch: 0002 Avg. cost = 0.091 Train Acc. = 0.97554547
# Epoch: 0002 Avg. cost = 0.091 Train Acc. = 0.9756909
# Epoch: 0002 Avg. cost = 0.091 Train Acc. = 0.9755818
# Epoch: 0002 Avg. cost = 0.092 Train Acc. = 0.97565454
# Epoch: 0002 Avg. cost = 0.092 Train Acc. = 0.9755091
# Epoch: 0002 Avg. cost = 0.092 Train Acc. = 0.9753091
# Epoch: 0002 Avg. cost = 0.092 Train Acc. = 0.97490907
# Epoch: 0002 Avg. cost = 0.092 Train Acc. = 0.97507274
# Epoch: 0002 Avg. cost = 0.093 Train Acc. = 0.97523636
# Epoch: 0002 Avg. cost = 0.093 Train Acc. = 0.97507274
# Epoch: 0002 Avg. cost = 0.093 Train Acc. = 0.9750364
# Epoch: 0002 Avg. cost = 0.093 Train Acc. = 0.97490907
# Epoch: 0002 Avg. cost = 0.094 Train Acc. = 0.97467273
# Epoch: 0002 Avg. cost = 0.094 Train Acc. = 0.9747273
# Epoch: 0002 Avg. cost = 0.094 Train Acc. = 0.97525454
# Epoch: 0002 Avg. cost = 0.094 Train Acc. = 0.97523636
# Epoch: 0002 Avg. cost = 0.095 Train Acc. = 0.9752182
# Epoch: 0002 Avg. cost = 0.095 Train Acc. = 0.97545457
# Epoch: 0002 Avg. cost = 0.095 Train Acc. = 0.9754364
# Epoch: 0002 Avg. cost = 0.096 Train Acc. = 0.97545457
# Epoch: 0002 Avg. cost = 0.096 Train Acc. = 0.97532725
# Epoch: 0002 Avg. cost = 0.096 Train Acc. = 0.97532725
# Epoch: 0002 Avg. cost = 0.096 Train Acc. = 0.9753818
# Epoch: 0002 Avg. cost = 0.097 Train Acc. = 0.97532725
# Epoch: 0002 Avg. cost = 0.097 Train Acc. = 0.97532725
# Epoch: 0002 Avg. cost = 0.097 Train Acc. = 0.97547275
# Epoch: 0002 Avg. cost = 0.098 Train Acc. = 0.97556365
# Epoch: 0002 Avg. cost = 0.098 Train Acc. = 0.9753818
# Epoch: 0002 Avg. cost = 0.098 Train Acc. = 0.9754909
# Epoch: 0002 Avg. cost = 0.098 Train Acc. = 0.9755273
# Epoch: 0002 Avg. cost = 0.099 Train Acc. = 0.97563636
# Epoch: 0002 Avg. cost = 0.099 Train Acc. = 0.9759091
# Epoch: 0002 Avg. cost = 0.099 Train Acc. = 0.97574544
# Epoch: 0002 Avg. cost = 0.100 Train Acc. = 0.9761636
# Epoch: 0002 Avg. cost = 0.100 Train Acc. = 0.9762
# Epoch: 0002 Avg. cost = 0.100 Train Acc. = 0.976
# Epoch: 0002 Avg. cost = 0.101 Train Acc. = 0.9758
# Epoch: 0002 Avg. cost = 0.101 Train Acc. = 0.9755818
# Epoch: 0002 Avg. cost = 0.101 Train Acc. = 0.9754182
# Epoch: 0002 Avg. cost = 0.102 Train Acc. = 0.97505456
# Epoch: 0002 Avg. cost = 0.102 Train Acc. = 0.9748909
# Epoch: 0002 Avg. cost = 0.102 Train Acc. = 0.9746
# Epoch: 0002 Avg. cost = 0.102 Train Acc. = 0.9740546
# Epoch: 0002 Avg. cost = 0.102 Train Acc. = 0.97354543
# Epoch: 0002 Avg. cost = 0.103 Train Acc. = 0.9733091
# Epoch: 0002 Avg. cost = 0.103 Train Acc. = 0.9729273
# Epoch: 0002 Avg. cost = 0.103 Train Acc. = 0.9728182
# Epoch: 0002 Avg. cost = 0.103 Train Acc. = 0.97285455
# Epoch: 0002 Avg. cost = 0.104 Train Acc. = 0.97285455
# Epoch: 0002 Avg. cost = 0.104 Train Acc. = 0.9730727
# Epoch: 0002 Avg. cost = 0.104 Train Acc. = 0.9732364
# Epoch: 0002 Avg. cost = 0.105 Train Acc. = 0.9733818
# Epoch: 0002 Avg. cost = 0.105 Train Acc. = 0.97365457
# Epoch: 0002 Avg. cost = 0.105 Train Acc. = 0.97394544
# Epoch: 0002 Avg. cost = 0.105 Train Acc. = 0.9741455
# Epoch: 0002 Avg. cost = 0.106 Train Acc. = 0.975
# Epoch: 0002 Avg. cost = 0.106 Train Acc. = 0.97532725
# Epoch: 0002 Avg. cost = 0.106 Train Acc. = 0.9756182
# Epoch: 0002 Avg. cost = 0.107 Train Acc. = 0.97572726
# Epoch: 0002 Avg. cost = 0.107 Train Acc. = 0.9760182
# ...
# Epoch: 0015 Avg. cost = 0.022 Train Acc. = 0.99674547
# Epoch: 0015 Avg. cost = 0.022 Train Acc. = 0.99685454
# Epoch: 0015 Avg. cost = 0.022 Train Acc. = 0.99694544
# Epoch: 0015 Avg. cost = 0.022 Train Acc. = 0.9968909
# Epoch: 0015 Avg. cost = 0.022 Train Acc. = 0.9968727
# Epoch: 0015 Avg. cost = 0.022 Train Acc. = 0.99685454
# Epoch: 0015 Avg. cost = 0.022 Train Acc. = 0.9967273
# Epoch: 0015 Avg. cost = 0.022 Train Acc. = 0.9967818
# Epoch: 0015 Avg. cost = 0.023 Train Acc. = 0.9967818
# Epoch: 0015 Avg. cost = 0.023 Train Acc. = 0.9968
# Epoch: 0015 Avg. cost = 0.023 Train Acc. = 0.9967818
# Epoch: 0015 Avg. cost = 0.023 Train Acc. = 0.9968
# Epoch: 0015 Avg. cost = 0.023 Train Acc. = 0.99685454
# Epoch: 0015 Avg. cost = 0.023 Train Acc. = 0.9968909
# Epoch: 0015 Avg. cost = 0.023 Train Acc. = 0.9969091
# Epoch: 0015 Avg. cost = 0.023 Train Acc. = 0.9968
# Epoch: 0015 Avg. cost = 0.024 Train Acc. = 0.9967818
# Epoch: 0015 Avg. cost = 0.024 Train Acc. = 0.9968
# Epoch: 0015 Avg. cost = 0.024 Train Acc. = 0.9968182
# Epoch: 0015 Avg. cost = 0.024 Train Acc. = 0.99683636
# Epoch: 0015 Avg. cost = 0.024 Train Acc. = 0.99683636
# Epoch: 0015 Avg. cost = 0.024 Train Acc. = 0.9968727
# Epoch: 0015 Avg. cost = 0.024 Train Acc. = 0.9968909
# Epoch: 0015 Avg. cost = 0.024 Train Acc. = 0.9968727
# Epoch: 0015 Avg. cost = 0.024 Train Acc. = 0.9968727
# Epoch: 0015 Avg. cost = 0.025 Train Acc. = 0.9967818
# Epoch: 0015 Avg. cost = 0.025 Train Acc. = 0.9966909
# Epoch: 0015 Avg. cost = 0.025 Train Acc. = 0.99667275
# Epoch: 0015 Avg. cost = 0.025 Train Acc. = 0.9966364
# Epoch: 0015 Avg. cost = 0.025 Train Acc. = 0.9966364
# Epoch: 0015 Avg. cost = 0.025 Train Acc. = 0.99654543
# Epoch: 0015 Avg. cost = 0.025 Train Acc. = 0.99654543
# Epoch: 0015 Avg. cost = 0.025 Train Acc. = 0.9965818
# Epoch: 0015 Avg. cost = 0.025 Train Acc. = 0.9965818
# Epoch: 0015 Avg. cost = 0.025 Train Acc. = 0.9965636
# Epoch: 0015 Avg. cost = 0.025 Train Acc. = 0.9965818
# Epoch: 0015 Avg. cost = 0.025 Train Acc. = 0.9965636
# Epoch: 0015 Avg. cost = 0.025 Train Acc. = 0.9966364
# Epoch: 0015 Avg. cost = 0.025 Train Acc. = 0.9965636
# Epoch: 0015 Avg. cost = 0.025 Train Acc. = 0.99643636
# Epoch: 0015 Avg. cost = 0.025 Train Acc. = 0.9964
# Epoch: 0015 Avg. cost = 0.025 Train Acc. = 0.9963273
# Epoch: 0015 Avg. cost = 0.026 Train Acc. = 0.9963818
# Epoch: 0015 Avg. cost = 0.026 Train Acc. = 0.9963091
# Epoch: 0015 Avg. cost = 0.026 Train Acc. = 0.9964182
# Epoch: 0015 Avg. cost = 0.026 Train Acc. = 0.9964
# Epoch: 0015 Avg. cost = 0.026 Train Acc. = 0.99636364
# Epoch: 0015 Avg. cost = 0.026 Train Acc. = 0.9964
# Epoch: 0015 Avg. cost = 0.026 Train Acc. = 0.9964727
# Epoch: 0015 Avg. cost = 0.026 Train Acc. = 0.9964727
# Epoch: 0015 Avg. cost = 0.026 Train Acc. = 0.9964909
# Epoch: 0015 Avg. cost = 0.026 Train Acc. = 0.9965636
# Epoch: 0015 Avg. cost = 0.026 Train Acc. = 0.9966182
# Epoch: 0015 Avg. cost = 0.026 Train Acc. = 0.9967273
# Epoch: 0015 Avg. cost = 0.027 Train Acc. = 0.9967091
# Epoch: 0015 Avg. cost = 0.027 Train Acc. = 0.9967818
# Epoch: 0015 Avg. cost = 0.027 Train Acc. = 0.99676365
# Epoch: 0015 Avg. cost = 0.027 Train Acc. = 0.99676365
# Epoch: 0015 Avg. cost = 0.027 Train Acc. = 0.9967818
# Epoch: 0015 Avg. cost = 0.027 Train Acc. = 0.9968909
# Epoch: 0015 Avg. cost = 0.027 Train Acc. = 0.9968
# Epoch: 0015 Avg. cost = 0.027 Train Acc. = 0.99676365
# Epoch: 0015 Avg. cost = 0.028 Train Acc. = 0.99674547
# Epoch: 0015 Avg. cost = 0.028 Train Acc. = 0.9967273
# Epoch: 0015 Avg. cost = 0.028 Train Acc. = 0.99674547
# Epoch: 0015 Avg. cost = 0.028 Train Acc. = 0.9967091
# Epoch: 0015 Avg. cost = 0.028 Train Acc. = 0.9967091
# Epoch: 0015 Avg. cost = 0.028 Train Acc. = 0.99665457
# Epoch: 0015 Avg. cost = 0.028 Train Acc. = 0.99667275
# Epoch: 0015 Avg. cost = 0.028 Train Acc. = 0.9966182
# Epoch: 0015 Avg. cost = 0.028 Train Acc. = 0.9967091
# Epoch: 0015 Avg. cost = 0.028 Train Acc. = 0.99665457
# Epoch: 0015 Avg. cost = 0.028 Train Acc. = 0.99665457
# Epoch: 0015 Avg. cost = 0.028 Train Acc. = 0.9966
# Epoch: 0015 Avg. cost = 0.028 Train Acc. = 0.9965636
# Epoch: 0015 Avg. cost = 0.029 Train Acc. = 0.9966
# Epoch: 0015 Avg. cost = 0.029 Train Acc. = 0.99665457
# Epoch: 0015 Avg. cost = 0.029 Train Acc. = 0.9966909
# Epoch: 0015 Avg. cost = 0.029 Train Acc. = 0.9968182
# Epoch: 0015 Avg. cost = 0.029 Train Acc. = 0.99694544
# Epoch: 0015 Avg. cost = 0.029 Train Acc. = 0.99703634
# Epoch: 0015 Avg. cost = 0.029 Train Acc. = 0.997
# Epoch: 0015 Avg. cost = 0.029 Train Acc. = 0.99701816
# Epoch: 0015 Avg. cost = 0.030 Train Acc. = 0.99707276
# Epoch: 0015 Avg. cost = 0.030 Train Acc. = 0.99709094
# Epoch: 0015 Avg. cost = 0.030 Train Acc. = 0.99709094
# Epoch: 0015 Avg. cost = 0.030 Train Acc. = 0.99703634
# Epoch: 0015 Avg. cost = 0.030 Train Acc. = 0.9970545
# Epoch: 0015 Avg. cost = 0.030 Train Acc. = 0.99701816
# Epoch: 0015 Avg. cost = 0.030 Train Acc. = 0.9969818
# Epoch: 0015 Avg. cost = 0.030 Train Acc. = 0.99694544
# Epoch: 0015 Avg. cost = 0.030 Train Acc. = 0.9969818
# Epoch: 0015 Avg. cost = 0.030 Train Acc. = 0.99703634
# Epoch: 0015 Avg. cost = 0.030 Train Acc. = 0.997
# Epoch: 0015 Avg. cost = 0.030 Train Acc. = 0.99701816
# Epoch: 0015 Avg. cost = 0.031 Train Acc. = 0.9969818
# Epoch: 0015 Avg. cost = 0.031 Train Acc. = 0.99701816
# Epoch: 0015 Avg. cost = 0.031 Train Acc. = 0.9969818
# Epoch: 0015 Avg. cost = 0.031 Train Acc. = 0.9969818
# Epoch: 0015 Avg. cost = 0.031 Train Acc. = 0.9969636
# Epoch: 0015 Avg. cost = 0.031 Train Acc. = 0.99701816
# Epoch: 0015 Avg. cost = 0.031 Train Acc. = 0.99694544
# Epoch: 0015 Avg. cost = 0.032 Train Acc. = 0.9970545
# Epoch: 0015 Avg. cost = 0.032 Train Acc. = 0.99707276
# Epoch: 0015 Avg. cost = 0.032 Train Acc. = 0.9970545
# Epoch: 0015 Avg. cost = 0.032 Train Acc. = 0.9971091
# Epoch: 0015 Avg. cost = 0.032 Train Acc. = 0.99716365
# Epoch: 0015 Avg. cost = 0.032 Train Acc. = 0.9972
# Epoch: 0015 Avg. cost = 0.032 Train Acc. = 0.99718183
# Epoch: 0015 Avg. cost = 0.032 Train Acc. = 0.99718183
# Epoch: 0015 Avg. cost = 0.032 Train Acc. = 0.9972364
# Epoch: 0015 Avg. cost = 0.032 Train Acc. = 0.9972182
# Epoch: 0015 Avg. cost = 0.032 Train Acc. = 0.99725455
# Epoch: 0015 Avg. cost = 0.032 Train Acc. = 0.99727273
# Epoch: 0015 Avg. cost = 0.033 Train Acc. = 0.99725455
# Epoch: 0015 Avg. cost = 0.033 Train Acc. = 0.99732727
# Epoch: 0015 Avg. cost = 0.033 Train Acc. = 0.9974
# Epoch: 0015 Avg. cost = 0.033 Train Acc. = 0.9973818
# Epoch: 0015 Avg. cost = 0.033 Train Acc. = 0.99732727
# Epoch: 0015 Avg. cost = 0.033 Train Acc. = 0.9973091
# Epoch: 0015 Avg. cost = 0.033 Train Acc. = 0.9973636
# Epoch: 0015 Avg. cost = 0.033 Train Acc. = 0.99734545
# Epoch: 0015 Avg. cost = 0.033 Train Acc. = 0.99734545
# Epoch: 0015 Avg. cost = 0.033 Train Acc. = 0.9973636
# Epoch: 0015 Avg. cost = 0.034 Train Acc. = 0.99725455
# Epoch: 0015 Avg. cost = 0.034 Train Acc. = 0.99725455
# Epoch: 0015 Avg. cost = 0.034 Train Acc. = 0.99718183
# Epoch: 0015 Avg. cost = 0.034 Train Acc. = 0.9972364
# Epoch: 0015 Avg. cost = 0.034 Train Acc. = 0.99716365
# Epoch: 0015 Avg. cost = 0.034 Train Acc. = 0.9971455
# Epoch: 0015 Avg. cost = 0.034 Train Acc. = 0.99716365
# Epoch: 0015 Avg. cost = 0.034 Train Acc. = 0.9971273
# Epoch: 0015 Avg. cost = 0.034 Train Acc. = 0.9971273
# Epoch: 0015 Avg. cost = 0.034 Train Acc. = 0.9971273
# Epoch: 0015 Avg. cost = 0.034 Train Acc. = 0.99707276
# Epoch: 0015 Avg. cost = 0.034 Train Acc. = 0.9969818
# Epoch: 0015 Avg. cost = 0.035 Train Acc. = 0.99685454
# Epoch: 0015 Avg. cost = 0.035 Train Acc. = 0.9968182
# Epoch: 0015 Avg. cost = 0.035 Train Acc. = 0.99674547
# Epoch: 0015 Avg. cost = 0.035 Train Acc. = 0.9967273
# Epoch: 0015 Avg. cost = 0.035 Train Acc. = 0.9968
# Epoch: 0015 Avg. cost = 0.035 Train Acc. = 0.9968909
# Epoch: 0015 Avg. cost = 0.035 Train Acc. = 0.99685454
# Epoch: 0015 Avg. cost = 0.035 Train Acc. = 0.9969091
# Epoch: 0015 Avg. cost = 0.036 Train Acc. = 0.99703634
# Epoch: 0015 Avg. cost = 0.036 Train Acc. = 0.99709094
# Epoch: 0015 Avg. cost = 0.036 Train Acc. = 0.99703634
# Epoch: 0015 Avg. cost = 0.036 Train Acc. = 0.99709094
# Epoch: 0015 Avg. cost = 0.036 Train Acc. = 0.9970545
# Epoch: 0015 Avg. cost = 0.036 Train Acc. = 0.99709094
# Epoch: 0015 Avg. cost = 0.036 Train Acc. = 0.9970545
# Epoch: 0015 Avg. cost = 0.036 Train Acc. = 0.99701816
# Epoch: 0015 Avg. cost = 0.036 Train Acc. = 0.99703634
# Epoch: 0015 Avg. cost = 0.036 Train Acc. = 0.99703634
# Epoch: 0015 Avg. cost = 0.036 Train Acc. = 0.99703634
# Epoch: 0015 Avg. cost = 0.036 Train Acc. = 0.99709094
# Epoch: 0015 Avg. cost = 0.036 Train Acc. = 0.997
# Epoch: 0015 Avg. cost = 0.036 Train Acc. = 0.99701816
# Epoch: 0015 Avg. cost = 0.036 Train Acc. = 0.99709094
# Epoch: 0015 Avg. cost = 0.037 Train Acc. = 0.9971091
# Epoch: 0015 Avg. cost = 0.037 Train Acc. = 0.9970545
# Epoch: 0015 Avg. cost = 0.037 Train Acc. = 0.9970545
# Epoch: 0015 Avg. cost = 0.037 Train Acc. = 0.99703634
# Epoch: 0015 Avg. cost = 0.037 Train Acc. = 0.9969091
# Epoch: 0015 Avg. cost = 0.037 Train Acc. = 0.9967818
# Epoch: 0015 Avg. cost = 0.037 Train Acc. = 0.9966182
# Epoch: 0015 Avg. cost = 0.037 Train Acc. = 0.9966182
# Epoch: 0015 Avg. cost = 0.037 Train Acc. = 0.99652725
# Epoch: 0015 Avg. cost = 0.037 Train Acc. = 0.9964909
# Epoch: 0015 Avg. cost = 0.037 Train Acc. = 0.9964182
# Epoch: 0015 Avg. cost = 0.038 Train Acc. = 0.99643636
# Epoch: 0015 Avg. cost = 0.038 Train Acc. = 0.9964727
# Epoch: 0015 Avg. cost = 0.038 Train Acc. = 0.99654543
# Epoch: 0015 Avg. cost = 0.038 Train Acc. = 0.9966364
# Epoch: 0015 Avg. cost = 0.038 Train Acc. = 0.9966182
# Epoch: 0015 Avg. cost = 0.038 Train Acc. = 0.99683636
# Epoch: 0015 Avg. cost = 0.038 Train Acc. = 0.99683636
# Epoch: 0015 Avg. cost = 0.039 Train Acc. = 0.9969636
# Epoch: 0015 Avg. cost = 0.039 Train Acc. = 0.997
# Epoch: 0015 Avg. cost = 0.039 Train Acc. = 0.997
# Epoch: 0015 Avg. cost = 0.039 Train Acc. = 0.9969818
# Epoch: 0015 Avg. cost = 0.039 Train Acc. = 0.9969636
# Epoch: 0015 Avg. cost = 0.039 Train Acc. = 0.9969091
# Epoch: 0015 Avg. cost = 0.039 Train Acc. = 0.9969636
# Epoch: 0015 Avg. cost = 0.039 Train Acc. = 0.9969091
# Epoch: 0015 Avg. cost = 0.039 Train Acc. = 0.99694544
# Epoch: 0015 Avg. cost = 0.039 Train Acc. = 0.9969091
# Epoch: 0015 Avg. cost = 0.039 Train Acc. = 0.9968
# Epoch: 0015 Avg. cost = 0.040 Train Acc. = 0.9968
# Epoch: 0015 Avg. cost = 0.040 Train Acc. = 0.9968909
# Epoch: 0015 Avg. cost = 0.040 Train Acc. = 0.9969636
# Epoch: 0015 Avg. cost = 0.040 Train Acc. = 0.99701816
# Epoch: 0015 Avg. cost = 0.040 Train Acc. = 0.9968909
# Epoch: 0015 Avg. cost = 0.040 Train Acc. = 0.99683636
# Epoch: 0015 Avg. cost = 0.040 Train Acc. = 0.99685454
# Epoch: 0015 Avg. cost = 0.040 Train Acc. = 0.9967273
# Epoch: 0015 Avg. cost = 0.040 Train Acc. = 0.99676365
# Epoch: 0015 Avg. cost = 0.040 Train Acc. = 0.9967091
# Epoch: 0015 Avg. cost = 0.040 Train Acc. = 0.9966182
# Epoch: 0015 Avg. cost = 0.041 Train Acc. = 0.99654543
# Epoch: 0015 Avg. cost = 0.041 Train Acc. = 0.9964727
# Epoch: 0015 Avg. cost = 0.041 Train Acc. = 0.9965091
# Epoch: 0015 Avg. cost = 0.041 Train Acc. = 0.9965091
# Epoch: 0015 Avg. cost = 0.041 Train Acc. = 0.99654543
# Epoch: 0015 Avg. cost = 0.041 Train Acc. = 0.9966182
# Epoch: 0015 Avg. cost = 0.041 Train Acc. = 0.99665457
# Epoch: 0015 Avg. cost = 0.041 Train Acc. = 0.9966909
# Epoch: 0015 Avg. cost = 0.041 Train Acc. = 0.9967273
# Epoch: 0015 Avg. cost = 0.041 Train Acc. = 0.9968
# Epoch: 0015 Avg. cost = 0.041 Train Acc. = 0.99683636
# Epoch: 0015 Avg. cost = 0.042 Train Acc. = 0.9969091
# Epoch: 0015 Avg. cost = 0.042 Train Acc. = 0.9969636
# Epoch: 0015 Avg. cost = 0.042 Train Acc. = 0.9969818
# Epoch: 0015 Avg. cost = 0.042 Train Acc. = 0.99701816
# Epoch: 0015 Avg. cost = 0.042 Train Acc. = 0.99709094
# Epoch: 0015 Avg. cost = 0.042 Train Acc. = 0.9971455
# Epoch: 0015 Avg. cost = 0.042 Train Acc. = 0.9971455
# Epoch: 0015 Avg. cost = 0.042 Train Acc. = 0.9970545
# Epoch: 0015 Avg. cost = 0.042 Train Acc. = 0.9969636
# Epoch: 0015 Avg. cost = 0.042 Train Acc. = 0.99692726
# Epoch: 0015 Avg. cost = 0.042 Train Acc. = 0.9969636
# Epoch: 0015 Avg. cost = 0.043 Train Acc. = 0.9969091
# Epoch: 0015 Avg. cost = 0.043 Train Acc. = 0.9969091
# Epoch: 0015 Avg. cost = 0.043 Train Acc. = 0.9968909
# Epoch: 0015 Avg. cost = 0.043 Train Acc. = 0.99701816
# Epoch: 0015 Avg. cost = 0.043 Train Acc. = 0.9970545
# Epoch: 0015 Avg. cost = 0.043 Train Acc. = 0.99707276
# Epoch: 0015 Avg. cost = 0.043 Train Acc. = 0.9970545
# Epoch: 0015 Avg. cost = 0.043 Train Acc. = 0.9971273
# Epoch: 0015 Avg. cost = 0.043 Train Acc. = 0.9971273
# Epoch: 0015 Avg. cost = 0.043 Train Acc. = 0.99709094
# Epoch: 0015 Avg. cost = 0.043 Train Acc. = 0.9970545
# Epoch: 0015 Avg. cost = 0.043 Train Acc. = 0.99709094
# Epoch: 0015 Avg. cost = 0.044 Train Acc. = 0.99701816
# Epoch: 0015 Avg. cost = 0.044 Train Acc. = 0.99703634
# Epoch: 0015 Avg. cost = 0.044 Train Acc. = 0.9971273
# Epoch: 0015 Avg. cost = 0.044 Train Acc. = 0.9971273
# Epoch: 0015 Avg. cost = 0.044 Train Acc. = 0.9970545
# Epoch: 0015 Avg. cost = 0.044 Train Acc. = 0.99709094
# Epoch: 0015 Avg. cost = 0.044 Train Acc. = 0.99707276
# Epoch: 0015 Avg. cost = 0.044 Train Acc. = 0.99707276
# Epoch: 0015 Avg. cost = 0.045 Train Acc. = 0.99707276
# Epoch: 0015 Avg. cost = 0.045 Train Acc. = 0.997
# Epoch: 0015 Avg. cost = 0.045 Train Acc. = 0.9969636
# Epoch: 0015 Avg. cost = 0.045 Train Acc. = 0.99692726
# Epoch: 0015 Avg. cost = 0.045 Train Acc. = 0.9969091
# Epoch: 0015 Avg. cost = 0.045 Train Acc. = 0.9969818
# Epoch: 0015 Avg. cost = 0.045 Train Acc. = 0.9969818
# Epoch: 0015 Avg. cost = 0.045 Train Acc. = 0.99701816
# Epoch: 0015 Avg. cost = 0.045 Train Acc. = 0.9970545
# Epoch: 0015 Avg. cost = 0.045 Train Acc. = 0.9970545
# Epoch: 0015 Avg. cost = 0.045 Train Acc. = 0.9970545
# Epoch: 0015 Avg. cost = 0.046 Train Acc. = 0.9971273
# Epoch: 0015 Avg. cost = 0.046 Train Acc. = 0.9972
# Epoch: 0015 Avg. cost = 0.046 Train Acc. = 0.9971455
# Epoch: 0015 Avg. cost = 0.046 Train Acc. = 0.99716365
# Epoch: 0015 Avg. cost = 0.046 Train Acc. = 0.99716365
# Epoch: 0015 Avg. cost = 0.046 Train Acc. = 0.99718183
# Epoch: 0015 Avg. cost = 0.046 Train Acc. = 0.99709094
# Epoch: 0015 Avg. cost = 0.046 Train Acc. = 0.99709094
# Epoch: 0015 Avg. cost = 0.046 Train Acc. = 0.9971091
# Epoch: 0015 Avg. cost = 0.046 Train Acc. = 0.9971273
# Epoch: 0015 Avg. cost = 0.047 Train Acc. = 0.9971455
# Epoch: 0015 Avg. cost = 0.047 Train Acc. = 0.99716365
# Epoch: 0015 Avg. cost = 0.047 Train Acc. = 0.99727273
# Epoch: 0015 Avg. cost = 0.047 Train Acc. = 0.99727273
# Epoch: 0015 Avg. cost = 0.047 Train Acc. = 0.9972
# Epoch: 0015 Avg. cost = 0.047 Train Acc. = 0.99716365
# Epoch: 0015 Avg. cost = 0.047 Train Acc. = 0.9971273
# Epoch: 0015 Avg. cost = 0.047 Train Acc. = 0.9971091
# Epoch: 0015 Avg. cost = 0.047 Train Acc. = 0.9971091
# Epoch: 0015 Avg. cost = 0.047 Train Acc. = 0.99707276
# Epoch: 0015 Avg. cost = 0.047 Train Acc. = 0.9970545
# Epoch: 0015 Avg. cost = 0.047 Train Acc. = 0.9969818
# Epoch: 0015 Avg. cost = 0.048 Train Acc. = 0.9969818
# Epoch: 0015 Avg. cost = 0.048 Train Acc. = 0.99694544
# Epoch: 0015 Avg. cost = 0.048 Train Acc. = 0.9969091
# Epoch: 0015 Avg. cost = 0.048 Train Acc. = 0.9969818
# Epoch: 0015 Avg. cost = 0.048 Train Acc. = 0.9969818
# Epoch: 0015 Avg. cost = 0.048 Train Acc. = 0.99701816
# Epoch: 0015 Avg. cost = 0.048 Train Acc. = 0.99701816
# Epoch: 0015 Avg. cost = 0.048 Train Acc. = 0.9969636
# Epoch: 0015 Avg. cost = 0.048 Train Acc. = 0.99694544
# Epoch: 0015 Avg. cost = 0.048 Train Acc. = 0.9968727
# Epoch: 0015 Avg. cost = 0.048 Train Acc. = 0.9967818
# Epoch: 0015 Avg. cost = 0.048 Train Acc. = 0.9968182
# Epoch: 0015 Avg. cost = 0.048 Train Acc. = 0.99683636
# Epoch: 0015 Avg. cost = 0.048 Train Acc. = 0.9968727
# Epoch: 0015 Avg. cost = 0.048 Train Acc. = 0.9968909
# Epoch: 0015 Avg. cost = 0.049 Train Acc. = 0.9969091
# Epoch: 0015 Avg. cost = 0.049 Train Acc. = 0.9969091
# Epoch: 0015 Avg. cost = 0.049 Train Acc. = 0.9969091
# Epoch: 0015 Avg. cost = 0.049 Train Acc. = 0.9969091
# Epoch: 0015 Avg. cost = 0.049 Train Acc. = 0.9968727
# Epoch: 0015 Avg. cost = 0.049 Train Acc. = 0.99692726
# Epoch: 0015 Avg. cost = 0.049 Train Acc. = 0.9969818
# Epoch: 0015 Avg. cost = 0.050 Train Acc. = 0.9970545
# Epoch: 0015 Avg. cost = 0.050 Train Acc. = 0.9970545
# Epoch: 0015 Avg. cost = 0.050 Train Acc. = 0.9970545
# Epoch: 0015 Avg. cost = 0.050 Train Acc. = 0.99709094
# Training Done!
# Test Acc. =  0.9853
