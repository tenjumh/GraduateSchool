# %%
# session 생성시 tf.Session()대신 tf.Session(config=config)로 대체 바랍니다!

import tensorflow as tf
import os
'''
os.environ["CUDA_VISIBLE_DEVICES"]='0'
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
'''
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("./mnist/data/", one_hot=True)

X = tf.placeholder(tf.float32, [None, 784])
Y = tf.placeholder(tf.float32, [None, 10])
# Out:
# WARNING:tensorflow:From <ipython-input-1-4ec01238e7e9>:11: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /etc/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /etc/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ./mnist/data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /etc/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ./mnist/data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /etc/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting ./mnist/data/t10k-images-idx3-ubyte.gz
# Extracting ./mnist/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /etc/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
# setup layers
# dropout
keep_prob = tf.placeholder(tf.float32)
epsilon = 1e-3

#  Init_Weight : He
W1_BN = tf.get_variable("W1_BN", shape=[784, 2048], initializer=tf.contrib.layers.variance_scaling_initializer())
L1_BN = tf.matmul(X, W1_BN)
batch_mean1, batch_var1 = tf.nn.moments(L1_BN,[0])
scale1 = tf.Variable(tf.ones([2048]))
beta1 = tf.Variable(tf.zeros([2048]))
BN1 = tf.nn.batch_normalization(L1_BN, batch_mean1, batch_var1, beta1, scale1, epsilon)
L1_BN = tf.nn.relu(BN1)
L1_BN = tf.nn.dropout(L1_BN, keep_prob)

W2_BN = tf.get_variable("W2_BN", shape=[2048, 2048], initializer=tf.contrib.layers.variance_scaling_initializer())
L2_BN = tf.matmul(L1_BN, W2_BN)
batch_mean2, batch_var2 = tf.nn.moments(L2_BN,[0])
scale2 = tf.Variable(tf.ones([1024]))
beta2 = tf.Variable(tf.zeros([1024]))
BN2 = tf.nn.batch_normalization(L2_BN, batch_mean2, batch_var2, beta2, scale2, epsilon)
L2_BN = tf.nn.relu(BN2)
L2_BN = tf.nn.dropout(L2_BN, keep_prob)

W3_BN = tf.get_variable("W3_BN", shape=[2048, 1024], initializer=tf.contrib.layers.variance_scaling_initializer())
L3_BN = tf.matmul(L2_BN, W3_BN)
batch_mean3, batch_var3 = tf.nn.moments(L3_BN,[0])
scale3 = tf.Variable(tf.ones([512]))
beta3 = tf.Variable(tf.zeros([512]))
BN3 = tf.nn.batch_normalization(L3_BN, batch_mean3, batch_var3, beta3, scale3, epsilon)
L3_BN = tf.nn.relu(BN3)
L3_BN = tf.nn.dropout(L3_BN, keep_prob)

W4_BN = tf.get_variable("W4_BN", shape=[1024, 1024], initializer=tf.contrib.layers.variance_scaling_initializer())
L4_BN = tf.matmul(L3_BN, W4_BN)
batch_mean4, batch_var4 = tf.nn.moments(L4_BN,[0])
scale4 = tf.Variable(tf.ones([256]))
beta4 = tf.Variable(tf.zeros([256]))
BN4 = tf.nn.batch_normalization(L4_BN, batch_mean4, batch_var4, beta4, scale4, epsilon)
L4_BN = tf.nn.relu(BN4)
L4_BN = tf.nn.dropout(L4_BN, keep_prob)

W5_BN = tf.get_variable("W5_BN", shape=[1024, 512], initializer=tf.contrib.layers.variance_scaling_initializer())
L5_BN = tf.matmul(L4_BN, W5_BN)
batch_mean5, batch_var5 = tf.nn.moments(L5_BN,[0])
scale5 = tf.Variable(tf.ones([256]))
beta5 = tf.Variable(tf.zeros([256]))
BN5 = tf.nn.batch_normalization(L5_BN, batch_mean5, batch_var5, beta5, scale5, epsilon)
L5_BN = tf.nn.relu(BN5)
L5_BN = tf.nn.dropout(L5_BN, keep_prob)

W6_BN = tf.get_variable("W6_BN", shape=[512, 512], initializer=tf.contrib.layers.variance_scaling_initializer())
L6_BN = tf.matmul(L5_BN, W6_BN)
batch_mean6, batch_var6 = tf.nn.moments(L6_BN,[0])
scale6 = tf.Variable(tf.ones([256]))
beta6 = tf.Variable(tf.zeros([256]))
BN6 = tf.nn.batch_normalization(L6_BN, batch_mean6, batch_var6, beta6, scale6, epsilon)
L6_BN = tf.nn.relu(BN6)
L6_BN = tf.nn.dropout(L6_BN, keep_prob)

W7_BN = tf.get_variable("W7_BN", shape=[512, 256], initializer=tf.contrib.layers.variance_scaling_initializer())
L7_BN = tf.matmul(L6_BN, W7_BN)
batch_mean7, batch_var7 = tf.nn.moments(L7_BN,[0])
scale7 = tf.Variable(tf.ones([256]))
beta7 = tf.Variable(tf.zeros([256]))
BN7 = tf.nn.batch_normalization(L7_BN, batch_mean7, batch_var7, beta7, scale7, epsilon)
L7_BN = tf.nn.relu(BN7)
L7_BN = tf.nn.dropout(L7_BN, keep_prob)

W8_BN = tf.get_variable("W8_BN", shape=[256, 10], initializer=tf.contrib.layers.variance_scaling_initializer())
L8_BN = tf.matmul(L7_BN, W8_BN)
batch_mean8, batch_var8 = tf.nn.moments(L8_BN,[0])
scale8 = tf.Variable(tf.ones([10]))
beta8 = tf.Variable(tf.zeros([10]))
BN8 = tf.nn.batch_normalization(L8_BN, batch_mean8, batch_var8, beta8, scale8, epsilon)
model = tf.nn.softmax(BN8)

#cost function and optimizer
cost = tf.reduce_mean(-tf.reduce_sum(Y * tf.log(tf.clip_by_value(model, 1e-10,1.0)), [1]))
optimizer = tf.train.AdamOptimizer(0.001).minimize(cost)

init = tf.global_variables_initializer()
sess = tf.Session(config=config)
sess.run(init)

#set up for minibatch
batch_size=100
total_batch= int(mnist.train.num_examples/batch_size) 

#set up for accuracy
is_correct = tf.equal(tf.argmax(model,1), tf.argmax(Y,1))
accuracy = tf.reduce_mean(tf.cast(is_correct, tf.float32))

#training
for epoch in range(30):
    total_cost = 0
    
    for i in range(total_batch):
        batch_xs, batch_ys = mnist.train.next_batch(batch_size)
        
        _, cost_val = sess.run([optimizer, cost], feed_dict={X: batch_xs, Y: batch_ys, keep_prob: 0.5})
        total_cost += cost_val
        
    print('Epoch:', '%04d' % (epoch + 1), 'Avg. cost =', '{:.3f}'.format(total_cost / total_batch), 'Train Acc. =', sess.run(accuracy, feed_dict={X: mnist.train.images, Y: mnist.train.labels, keep_prob: 1.0}))

#print("Training Done")
#print("Test Acc.=", sess.run(accuracy, feed_dict={X: mnist.test.images, Y: mnist.test.labels}))
        
print('Training Done!')
print('Test Acc. = ', sess.run(accuracy, feed_dict={X: mnist.test.images, Y: mnist.test.labels, keep_prob: 1.0}))
# Out:
# Epoch: 0001 Avg. cost = 0.006 Train Acc. = 0.25045455
# Epoch: 0001 Avg. cost = 0.011 Train Acc. = 0.39485455
# Epoch: 0001 Avg. cost = 0.016 Train Acc. = 0.48112726
# Epoch: 0001 Avg. cost = 0.021 Train Acc. = 0.5367454
# Epoch: 0001 Avg. cost = 0.026 Train Acc. = 0.58236367
# Epoch: 0001 Avg. cost = 0.030 Train Acc. = 0.6186182
# Epoch: 0001 Avg. cost = 0.034 Train Acc. = 0.64649093
# Epoch: 0001 Avg. cost = 0.039 Train Acc. = 0.6664909
# Epoch: 0001 Avg. cost = 0.042 Train Acc. = 0.68374544
# Epoch: 0001 Avg. cost = 0.046 Train Acc. = 0.6976727
# Epoch: 0001 Avg. cost = 0.049 Train Acc. = 0.70910907
# Epoch: 0001 Avg. cost = 0.053 Train Acc. = 0.71721816
# Epoch: 0001 Avg. cost = 0.056 Train Acc. = 0.7217818
# Epoch: 0001 Avg. cost = 0.059 Train Acc. = 0.7278909
# Epoch: 0001 Avg. cost = 0.062 Train Acc. = 0.7339454
# Epoch: 0001 Avg. cost = 0.065 Train Acc. = 0.7394364
# Epoch: 0001 Avg. cost = 0.068 Train Acc. = 0.7472
# Epoch: 0001 Avg. cost = 0.071 Train Acc. = 0.75365454
# Epoch: 0001 Avg. cost = 0.074 Train Acc. = 0.76067275
# Epoch: 0001 Avg. cost = 0.076 Train Acc. = 0.76872724
# Epoch: 0001 Avg. cost = 0.078 Train Acc. = 0.7753636
# Epoch: 0001 Avg. cost = 0.081 Train Acc. = 0.7816727
# Epoch: 0001 Avg. cost = 0.083 Train Acc. = 0.7888182
# Epoch: 0001 Avg. cost = 0.086 Train Acc. = 0.7951273
# Epoch: 0001 Avg. cost = 0.088 Train Acc. = 0.8000909
# Epoch: 0001 Avg. cost = 0.090 Train Acc. = 0.8057455
# Epoch: 0001 Avg. cost = 0.092 Train Acc. = 0.8125273
# Epoch: 0001 Avg. cost = 0.094 Train Acc. = 0.82074547
# Epoch: 0001 Avg. cost = 0.096 Train Acc. = 0.82723635
# Epoch: 0001 Avg. cost = 0.098 Train Acc. = 0.8324182
# Epoch: 0001 Avg. cost = 0.100 Train Acc. = 0.8378364
# Epoch: 0001 Avg. cost = 0.102 Train Acc. = 0.84214544
# Epoch: 0001 Avg. cost = 0.104 Train Acc. = 0.8458
# Epoch: 0001 Avg. cost = 0.106 Train Acc. = 0.84892726
# Epoch: 0001 Avg. cost = 0.107 Train Acc. = 0.8509273
# Epoch: 0001 Avg. cost = 0.109 Train Acc. = 0.85252726
# Epoch: 0001 Avg. cost = 0.110 Train Acc. = 0.85345453
# Epoch: 0001 Avg. cost = 0.112 Train Acc. = 0.85523635
# Epoch: 0001 Avg. cost = 0.114 Train Acc. = 0.8569273
# Epoch: 0001 Avg. cost = 0.115 Train Acc. = 0.85905457
# Epoch: 0001 Avg. cost = 0.117 Train Acc. = 0.86074543
# Epoch: 0001 Avg. cost = 0.118 Train Acc. = 0.86252725
# Epoch: 0001 Avg. cost = 0.119 Train Acc. = 0.8638727
# Epoch: 0001 Avg. cost = 0.121 Train Acc. = 0.86563635
# Epoch: 0001 Avg. cost = 0.123 Train Acc. = 0.8671091
# Epoch: 0001 Avg. cost = 0.124 Train Acc. = 0.86849093
# Epoch: 0001 Avg. cost = 0.126 Train Acc. = 0.8694
# Epoch: 0001 Avg. cost = 0.127 Train Acc. = 0.87076366
# Epoch: 0001 Avg. cost = 0.128 Train Acc. = 0.8721273
# Epoch: 0001 Avg. cost = 0.130 Train Acc. = 0.87305456
# Epoch: 0001 Avg. cost = 0.131 Train Acc. = 0.8739273
# Epoch: 0001 Avg. cost = 0.132 Train Acc. = 0.8747454
# Epoch: 0001 Avg. cost = 0.133 Train Acc. = 0.87612724
# Epoch: 0001 Avg. cost = 0.135 Train Acc. = 0.87765455
# Epoch: 0001 Avg. cost = 0.136 Train Acc. = 0.8792727
# Epoch: 0001 Avg. cost = 0.137 Train Acc. = 0.88118184
# Epoch: 0001 Avg. cost = 0.138 Train Acc. = 0.88232726
# Epoch: 0001 Avg. cost = 0.140 Train Acc. = 0.8836
# Epoch: 0001 Avg. cost = 0.141 Train Acc. = 0.88423634
# Epoch: 0001 Avg. cost = 0.142 Train Acc. = 0.8855818
# Epoch: 0001 Avg. cost = 0.143 Train Acc. = 0.8862182
# Epoch: 0001 Avg. cost = 0.144 Train Acc. = 0.8872909
# Epoch: 0001 Avg. cost = 0.145 Train Acc. = 0.88805455
# Epoch: 0001 Avg. cost = 0.147 Train Acc. = 0.8889091
# Epoch: 0001 Avg. cost = 0.148 Train Acc. = 0.8898182
# Epoch: 0001 Avg. cost = 0.149 Train Acc. = 0.89045453
# Epoch: 0001 Avg. cost = 0.150 Train Acc. = 0.8912909
# Epoch: 0001 Avg. cost = 0.151 Train Acc. = 0.89225453
# Epoch: 0001 Avg. cost = 0.152 Train Acc. = 0.8932545
# Epoch: 0001 Avg. cost = 0.153 Train Acc. = 0.89403635
# Epoch: 0001 Avg. cost = 0.154 Train Acc. = 0.8951273
# Epoch: 0001 Avg. cost = 0.155 Train Acc. = 0.8959091
# Epoch: 0001 Avg. cost = 0.156 Train Acc. = 0.89698184
# Epoch: 0001 Avg. cost = 0.157 Train Acc. = 0.8979818
# Epoch: 0001 Avg. cost = 0.158 Train Acc. = 0.89863634
# Epoch: 0001 Avg. cost = 0.159 Train Acc. = 0.8994
# Epoch: 0001 Avg. cost = 0.160 Train Acc. = 0.89994544
# Epoch: 0001 Avg. cost = 0.162 Train Acc. = 0.9008545
# Epoch: 0001 Avg. cost = 0.163 Train Acc. = 0.90183634
# Epoch: 0001 Avg. cost = 0.164 Train Acc. = 0.9026909
# Epoch: 0001 Avg. cost = 0.165 Train Acc. = 0.9038
# Epoch: 0001 Avg. cost = 0.166 Train Acc. = 0.9050909
# Epoch: 0001 Avg. cost = 0.167 Train Acc. = 0.9059273
# Epoch: 0001 Avg. cost = 0.168 Train Acc. = 0.9068909
# Epoch: 0001 Avg. cost = 0.169 Train Acc. = 0.9077273
# Epoch: 0001 Avg. cost = 0.170 Train Acc. = 0.9080909
# Epoch: 0001 Avg. cost = 0.171 Train Acc. = 0.9088
# Epoch: 0001 Avg. cost = 0.172 Train Acc. = 0.9094545
# Epoch: 0001 Avg. cost = 0.173 Train Acc. = 0.90956366
# Epoch: 0001 Avg. cost = 0.175 Train Acc. = 0.9098909
# Epoch: 0001 Avg. cost = 0.176 Train Acc. = 0.91041815
# Epoch: 0001 Avg. cost = 0.176 Train Acc. = 0.91096365
# Epoch: 0001 Avg. cost = 0.177 Train Acc. = 0.9117454
# Epoch: 0001 Avg. cost = 0.178 Train Acc. = 0.9121636
# Epoch: 0001 Avg. cost = 0.179 Train Acc. = 0.9128
# Epoch: 0001 Avg. cost = 0.180 Train Acc. = 0.91312724
# Epoch: 0001 Avg. cost = 0.181 Train Acc. = 0.91376364
# Epoch: 0001 Avg. cost = 0.182 Train Acc. = 0.9141273
# Epoch: 0001 Avg. cost = 0.182 Train Acc. = 0.9142727
# Epoch: 0001 Avg. cost = 0.183 Train Acc. = 0.9149455
# Epoch: 0001 Avg. cost = 0.183 Train Acc. = 0.9153818
# Epoch: 0001 Avg. cost = 0.184 Train Acc. = 0.9157091
# Epoch: 0001 Avg. cost = 0.185 Train Acc. = 0.91623634
# Epoch: 0001 Avg. cost = 0.186 Train Acc. = 0.91647273
# Epoch: 0001 Avg. cost = 0.186 Train Acc. = 0.9168182
# Epoch: 0001 Avg. cost = 0.187 Train Acc. = 0.9171818
# Epoch: 0001 Avg. cost = 0.188 Train Acc. = 0.91754544
# Epoch: 0001 Avg. cost = 0.189 Train Acc. = 0.9181273
# Epoch: 0001 Avg. cost = 0.190 Train Acc. = 0.9184727
# Epoch: 0001 Avg. cost = 0.191 Train Acc. = 0.9187091
# Epoch: 0001 Avg. cost = 0.191 Train Acc. = 0.9188182
# Epoch: 0001 Avg. cost = 0.192 Train Acc. = 0.91914546
# Epoch: 0001 Avg. cost = 0.193 Train Acc. = 0.91972727
# Epoch: 0001 Avg. cost = 0.194 Train Acc. = 0.9198
# Epoch: 0001 Avg. cost = 0.195 Train Acc. = 0.9206
# Epoch: 0001 Avg. cost = 0.196 Train Acc. = 0.92114544
# Epoch: 0001 Avg. cost = 0.197 Train Acc. = 0.9218364
# Epoch: 0001 Avg. cost = 0.197 Train Acc. = 0.92236364
# Epoch: 0001 Avg. cost = 0.198 Train Acc. = 0.9228
# Epoch: 0001 Avg. cost = 0.199 Train Acc. = 0.9231455
# Epoch: 0001 Avg. cost = 0.200 Train Acc. = 0.9236182
# Epoch: 0001 Avg. cost = 0.200 Train Acc. = 0.924
# Epoch: 0001 Avg. cost = 0.201 Train Acc. = 0.9243636
# Epoch: 0001 Avg. cost = 0.202 Train Acc. = 0.9247636
# Epoch: 0001 Avg. cost = 0.203 Train Acc. = 0.9253455
# Epoch: 0001 Avg. cost = 0.204 Train Acc. = 0.9255818
# Epoch: 0001 Avg. cost = 0.205 Train Acc. = 0.92603636
# Epoch: 0001 Avg. cost = 0.206 Train Acc. = 0.9266
# Epoch: 0001 Avg. cost = 0.207 Train Acc. = 0.9271455
# Epoch: 0001 Avg. cost = 0.208 Train Acc. = 0.9273273
# Epoch: 0001 Avg. cost = 0.209 Train Acc. = 0.92765456
# Epoch: 0001 Avg. cost = 0.209 Train Acc. = 0.92776364
# Epoch: 0001 Avg. cost = 0.210 Train Acc. = 0.92794544
# Epoch: 0001 Avg. cost = 0.211 Train Acc. = 0.92823637
# Epoch: 0001 Avg. cost = 0.212 Train Acc. = 0.9283091
# Epoch: 0001 Avg. cost = 0.212 Train Acc. = 0.9284727
# Epoch: 0001 Avg. cost = 0.213 Train Acc. = 0.9287091
# Epoch: 0001 Avg. cost = 0.213 Train Acc. = 0.9288
# Epoch: 0001 Avg. cost = 0.214 Train Acc. = 0.9288
# Epoch: 0001 Avg. cost = 0.215 Train Acc. = 0.92898184
# Epoch: 0001 Avg. cost = 0.216 Train Acc. = 0.9292
# Epoch: 0001 Avg. cost = 0.216 Train Acc. = 0.92932725
# Epoch: 0001 Avg. cost = 0.217 Train Acc. = 0.92965454
# Epoch: 0001 Avg. cost = 0.218 Train Acc. = 0.92994547
# Epoch: 0001 Avg. cost = 0.219 Train Acc. = 0.93023634
# Epoch: 0001 Avg. cost = 0.219 Train Acc. = 0.9308182
# Epoch: 0001 Avg. cost = 0.220 Train Acc. = 0.93072724
# Epoch: 0001 Avg. cost = 0.221 Train Acc. = 0.9309818
# Epoch: 0001 Avg. cost = 0.222 Train Acc. = 0.93125457
# Epoch: 0001 Avg. cost = 0.222 Train Acc. = 0.9314
# Epoch: 0001 Avg. cost = 0.223 Train Acc. = 0.9316
# Epoch: 0001 Avg. cost = 0.224 Train Acc. = 0.93174547
# Epoch: 0001 Avg. cost = 0.225 Train Acc. = 0.93209094
# Epoch: 0001 Avg. cost = 0.225 Train Acc. = 0.9322
# Epoch: 0001 Avg. cost = 0.226 Train Acc. = 0.9323818
# Epoch: 0001 Avg. cost = 0.226 Train Acc. = 0.9325455
# Epoch: 0001 Avg. cost = 0.227 Train Acc. = 0.93274546
# Epoch: 0001 Avg. cost = 0.227 Train Acc. = 0.93283635
# Epoch: 0001 Avg. cost = 0.228 Train Acc. = 0.9331818
# Epoch: 0001 Avg. cost = 0.229 Train Acc. = 0.9332909
# Epoch: 0001 Avg. cost = 0.230 Train Acc. = 0.9336727
# Epoch: 0001 Avg. cost = 0.230 Train Acc. = 0.9340909
# Epoch: 0001 Avg. cost = 0.231 Train Acc. = 0.9343455
# Epoch: 0001 Avg. cost = 0.231 Train Acc. = 0.93445456
# Epoch: 0001 Avg. cost = 0.232 Train Acc. = 0.9345273
# Epoch: 0001 Avg. cost = 0.233 Train Acc. = 0.9347636
# Epoch: 0001 Avg. cost = 0.233 Train Acc. = 0.9352
# Epoch: 0001 Avg. cost = 0.234 Train Acc. = 0.9356727
# Epoch: 0001 Avg. cost = 0.235 Train Acc. = 0.93543637
# Epoch: 0001 Avg. cost = 0.235 Train Acc. = 0.9358364
# Epoch: 0001 Avg. cost = 0.236 Train Acc. = 0.9362909
# Epoch: 0001 Avg. cost = 0.237 Train Acc. = 0.93627274
# Epoch: 0001 Avg. cost = 0.238 Train Acc. = 0.9363818
# Epoch: 0001 Avg. cost = 0.239 Train Acc. = 0.9367818
# Epoch: 0001 Avg. cost = 0.240 Train Acc. = 0.9366909
# Epoch: 0001 Avg. cost = 0.240 Train Acc. = 0.93725455
# Epoch: 0001 Avg. cost = 0.241 Train Acc. = 0.9374727
# Epoch: 0001 Avg. cost = 0.241 Train Acc. = 0.93774545
# Epoch: 0001 Avg. cost = 0.242 Train Acc. = 0.9378909
# Epoch: 0001 Avg. cost = 0.242 Train Acc. = 0.93796366
# Epoch: 0001 Avg. cost = 0.243 Train Acc. = 0.9380182
# Epoch: 0001 Avg. cost = 0.244 Train Acc. = 0.9382182
# Epoch: 0001 Avg. cost = 0.245 Train Acc. = 0.93816364
# Epoch: 0001 Avg. cost = 0.246 Train Acc. = 0.9383091
# Epoch: 0001 Avg. cost = 0.246 Train Acc. = 0.93856364
# Epoch: 0001 Avg. cost = 0.247 Train Acc. = 0.93834543
# Epoch: 0001 Avg. cost = 0.247 Train Acc. = 0.9385818
# Epoch: 0001 Avg. cost = 0.248 Train Acc. = 0.9385818
# Epoch: 0001 Avg. cost = 0.248 Train Acc. = 0.93847275
# Epoch: 0001 Avg. cost = 0.249 Train Acc. = 0.93856364
# Epoch: 0001 Avg. cost = 0.250 Train Acc. = 0.93872726
# Epoch: 0001 Avg. cost = 0.250 Train Acc. = 0.9385818
# Epoch: 0001 Avg. cost = 0.251 Train Acc. = 0.9387091
# Epoch: 0001 Avg. cost = 0.253 Train Acc. = 0.93923634
# Epoch: 0001 Avg. cost = 0.253 Train Acc. = 0.9393091
# Epoch: 0001 Avg. cost = 0.253 Train Acc. = 0.93963635
# Epoch: 0001 Avg. cost = 0.254 Train Acc. = 0.93963635
# Epoch: 0001 Avg. cost = 0.255 Train Acc. = 0.93985456
# Epoch: 0001 Avg. cost = 0.255 Train Acc. = 0.9402364
# Epoch: 0001 Avg. cost = 0.256 Train Acc. = 0.9407455
# Epoch: 0001 Avg. cost = 0.256 Train Acc. = 0.9410727
# Epoch: 0001 Avg. cost = 0.257 Train Acc. = 0.9414182
# Epoch: 0001 Avg. cost = 0.257 Train Acc. = 0.94174546
# Epoch: 0001 Avg. cost = 0.258 Train Acc. = 0.9420364
# Epoch: 0001 Avg. cost = 0.259 Train Acc. = 0.94214547
# Epoch: 0001 Avg. cost = 0.260 Train Acc. = 0.9423818
# Epoch: 0001 Avg. cost = 0.260 Train Acc. = 0.9426364
# Epoch: 0001 Avg. cost = 0.261 Train Acc. = 0.94283634
# Epoch: 0001 Avg. cost = 0.261 Train Acc. = 0.94316363
# Epoch: 0001 Avg. cost = 0.262 Train Acc. = 0.9434182
# Epoch: 0001 Avg. cost = 0.263 Train Acc. = 0.9438909
# Epoch: 0001 Avg. cost = 0.264 Train Acc. = 0.94365454
# Epoch: 0001 Avg. cost = 0.264 Train Acc. = 0.94387275
# Epoch: 0001 Avg. cost = 0.265 Train Acc. = 0.9438546
# Epoch: 0001 Avg. cost = 0.265 Train Acc. = 0.94372725
# Epoch: 0001 Avg. cost = 0.266 Train Acc. = 0.9435273
# Epoch: 0001 Avg. cost = 0.267 Train Acc. = 0.94365454
# Epoch: 0001 Avg. cost = 0.267 Train Acc. = 0.94365454
# Epoch: 0001 Avg. cost = 0.268 Train Acc. = 0.9436727
# Epoch: 0001 Avg. cost = 0.269 Train Acc. = 0.94414544
# Epoch: 0001 Avg. cost = 0.269 Train Acc. = 0.9440727
# Epoch: 0001 Avg. cost = 0.270 Train Acc. = 0.9443091
# Epoch: 0001 Avg. cost = 0.271 Train Acc. = 0.9445818
# Epoch: 0001 Avg. cost = 0.271 Train Acc. = 0.94461817
# Epoch: 0001 Avg. cost = 0.271 Train Acc. = 0.9448364
# Epoch: 0001 Avg. cost = 0.272 Train Acc. = 0.94452727
# Epoch: 0001 Avg. cost = 0.273 Train Acc. = 0.94438183
# Epoch: 0001 Avg. cost = 0.273 Train Acc. = 0.9443091
# Epoch: 0001 Avg. cost = 0.274 Train Acc. = 0.94438183
# Epoch: 0001 Avg. cost = 0.275 Train Acc. = 0.9445091
# Epoch: 0001 Avg. cost = 0.275 Train Acc. = 0.9446909
# Epoch: 0001 Avg. cost = 0.276 Train Acc. = 0.9449273
# Epoch: 0001 Avg. cost = 0.277 Train Acc. = 0.9452909
# Epoch: 0001 Avg. cost = 0.277 Train Acc. = 0.94569093
# Epoch: 0001 Avg. cost = 0.278 Train Acc. = 0.9457818
# Epoch: 0001 Avg. cost = 0.279 Train Acc. = 0.9458182
# Epoch: 0001 Avg. cost = 0.279 Train Acc. = 0.9460727
# Epoch: 0001 Avg. cost = 0.280 Train Acc. = 0.94625455
# Epoch: 0001 Avg. cost = 0.280 Train Acc. = 0.9464727
# Epoch: 0001 Avg. cost = 0.281 Train Acc. = 0.94665456
# Epoch: 0001 Avg. cost = 0.282 Train Acc. = 0.94683635
# Epoch: 0001 Avg. cost = 0.282 Train Acc. = 0.9472
# Epoch: 0001 Avg. cost = 0.282 Train Acc. = 0.9473636
# Epoch: 0001 Avg. cost = 0.283 Train Acc. = 0.94725454
# Epoch: 0001 Avg. cost = 0.283 Train Acc. = 0.94749093
# Epoch: 0001 Avg. cost = 0.284 Train Acc. = 0.9477818
# Epoch: 0001 Avg. cost = 0.284 Train Acc. = 0.9477636
# Epoch: 0001 Avg. cost = 0.285 Train Acc. = 0.9481091
# Epoch: 0001 Avg. cost = 0.285 Train Acc. = 0.94838184
# Epoch: 0001 Avg. cost = 0.286 Train Acc. = 0.94865453
# Epoch: 0001 Avg. cost = 0.286 Train Acc. = 0.94854546
# Epoch: 0001 Avg. cost = 0.287 Train Acc. = 0.94878185
# Epoch: 0001 Avg. cost = 0.288 Train Acc. = 0.9490182
# Epoch: 0001 Avg. cost = 0.288 Train Acc. = 0.9494909
# Epoch: 0001 Avg. cost = 0.289 Train Acc. = 0.94969094
# Epoch: 0001 Avg. cost = 0.290 Train Acc. = 0.95025456
# Epoch: 0001 Avg. cost = 0.290 Train Acc. = 0.9506909
# Epoch: 0001 Avg. cost = 0.291 Train Acc. = 0.95092726
# Epoch: 0001 Avg. cost = 0.292 Train Acc. = 0.95074546
# Epoch: 0001 Avg. cost = 0.293 Train Acc. = 0.95065457
# Epoch: 0001 Avg. cost = 0.293 Train Acc. = 0.95045453
# Epoch: 0001 Avg. cost = 0.293 Train Acc. = 0.95025456
# Epoch: 0001 Avg. cost = 0.295 Train Acc. = 0.9504
# Epoch: 0001 Avg. cost = 0.296 Train Acc. = 0.9505636
# Epoch: 0001 Avg. cost = 0.296 Train Acc. = 0.95054543
# Epoch: 0001 Avg. cost = 0.297 Train Acc. = 0.9508909
# Epoch: 0001 Avg. cost = 0.297 Train Acc. = 0.9513818
# Epoch: 0001 Avg. cost = 0.298 Train Acc. = 0.9513636
# Epoch: 0001 Avg. cost = 0.299 Train Acc. = 0.95132726
# Epoch: 0001 Avg. cost = 0.299 Train Acc. = 0.9513818
# Epoch: 0001 Avg. cost = 0.300 Train Acc. = 0.95174545
# Epoch: 0001 Avg. cost = 0.300 Train Acc. = 0.9518
# Epoch: 0001 Avg. cost = 0.300 Train Acc. = 0.95176363
# Epoch: 0001 Avg. cost = 0.301 Train Acc. = 0.95183635
# Epoch: 0001 Avg. cost = 0.302 Train Acc. = 0.95165455
# Epoch: 0001 Avg. cost = 0.303 Train Acc. = 0.9518909
# Epoch: 0001 Avg. cost = 0.303 Train Acc. = 0.9521818
# Epoch: 0001 Avg. cost = 0.304 Train Acc. = 0.9521818
# Epoch: 0001 Avg. cost = 0.304 Train Acc. = 0.9525091
# Epoch: 0001 Avg. cost = 0.305 Train Acc. = 0.9524182
# Epoch: 0001 Avg. cost = 0.305 Train Acc. = 0.9524182
# Epoch: 0001 Avg. cost = 0.306 Train Acc. = 0.9526727
# Epoch: 0001 Avg. cost = 0.306 Train Acc. = 0.95287275
# Epoch: 0001 Avg. cost = 0.307 Train Acc. = 0.9530909
# Epoch: 0001 Avg. cost = 0.307 Train Acc. = 0.9532545
# Epoch: 0001 Avg. cost = 0.308 Train Acc. = 0.9534909
# Epoch: 0001 Avg. cost = 0.309 Train Acc. = 0.9536545
# Epoch: 0001 Avg. cost = 0.309 Train Acc. = 0.95396364
# Epoch: 0001 Avg. cost = 0.310 Train Acc. = 0.9539091
# Epoch: 0001 Avg. cost = 0.310 Train Acc. = 0.9537454
# Epoch: 0001 Avg. cost = 0.311 Train Acc. = 0.9536727
# Epoch: 0001 Avg. cost = 0.312 Train Acc. = 0.9538364
# Epoch: 0001 Avg. cost = 0.313 Train Acc. = 0.95405453
# Epoch: 0001 Avg. cost = 0.313 Train Acc. = 0.95405453
# Epoch: 0001 Avg. cost = 0.314 Train Acc. = 0.9541818
# Epoch: 0001 Avg. cost = 0.314 Train Acc. = 0.954
# Epoch: 0001 Avg. cost = 0.315 Train Acc. = 0.9541091
# Epoch: 0001 Avg. cost = 0.315 Train Acc. = 0.95414543
# Epoch: 0001 Avg. cost = 0.316 Train Acc. = 0.9539091
# Epoch: 0001 Avg. cost = 0.316 Train Acc. = 0.95372725
# Epoch: 0001 Avg. cost = 0.317 Train Acc. = 0.9537454
# Epoch: 0001 Avg. cost = 0.318 Train Acc. = 0.9536909
# Epoch: 0001 Avg. cost = 0.318 Train Acc. = 0.9538364
# Epoch: 0001 Avg. cost = 0.318 Train Acc. = 0.95363635
# Epoch: 0001 Avg. cost = 0.319 Train Acc. = 0.9531818
# Epoch: 0001 Avg. cost = 0.319 Train Acc. = 0.9534182
# Epoch: 0001 Avg. cost = 0.320 Train Acc. = 0.95361817
# Epoch: 0001 Avg. cost = 0.320 Train Acc. = 0.954
# Epoch: 0001 Avg. cost = 0.321 Train Acc. = 0.9544
# Epoch: 0001 Avg. cost = 0.321 Train Acc. = 0.9543273
# Epoch: 0001 Avg. cost = 0.322 Train Acc. = 0.9544
# Epoch: 0001 Avg. cost = 0.322 Train Acc. = 0.95454544
# Epoch: 0001 Avg. cost = 0.323 Train Acc. = 0.95434546
# Epoch: 0001 Avg. cost = 0.323 Train Acc. = 0.95425457
# Epoch: 0001 Avg. cost = 0.324 Train Acc. = 0.95414543
# Epoch: 0001 Avg. cost = 0.324 Train Acc. = 0.9538364
# Epoch: 0001 Avg. cost = 0.324 Train Acc. = 0.9536727
# Epoch: 0001 Avg. cost = 0.325 Train Acc. = 0.9536545
# Epoch: 0001 Avg. cost = 0.326 Train Acc. = 0.95363635
# Epoch: 0001 Avg. cost = 0.326 Train Acc. = 0.95396364
# Epoch: 0001 Avg. cost = 0.327 Train Acc. = 0.9540909
# Epoch: 0001 Avg. cost = 0.327 Train Acc. = 0.9539818
# Epoch: 0001 Avg. cost = 0.328 Train Acc. = 0.9544
# Epoch: 0001 Avg. cost = 0.328 Train Acc. = 0.9544909
# Epoch: 0001 Avg. cost = 0.329 Train Acc. = 0.95476365
# Epoch: 0001 Avg. cost = 0.329 Train Acc. = 0.95461816
# Epoch: 0001 Avg. cost = 0.330 Train Acc. = 0.9550727
# Epoch: 0001 Avg. cost = 0.330 Train Acc. = 0.9551091
# Epoch: 0001 Avg. cost = 0.331 Train Acc. = 0.9551273
# Epoch: 0001 Avg. cost = 0.331 Train Acc. = 0.95516366
# Epoch: 0001 Avg. cost = 0.332 Train Acc. = 0.9554545
# Epoch: 0001 Avg. cost = 0.332 Train Acc. = 0.9556909
# Epoch: 0001 Avg. cost = 0.333 Train Acc. = 0.9554727
# Epoch: 0001 Avg. cost = 0.333 Train Acc. = 0.95556366
# Epoch: 0001 Avg. cost = 0.334 Train Acc. = 0.9555454
# Epoch: 0001 Avg. cost = 0.334 Train Acc. = 0.95552725
# Epoch: 0001 Avg. cost = 0.335 Train Acc. = 0.95550907
# Epoch: 0001 Avg. cost = 0.335 Train Acc. = 0.9554909
# Epoch: 0001 Avg. cost = 0.336 Train Acc. = 0.95552725
# Epoch: 0001 Avg. cost = 0.336 Train Acc. = 0.95567274
# Epoch: 0001 Avg. cost = 0.337 Train Acc. = 0.95583636
# Epoch: 0001 Avg. cost = 0.337 Train Acc. = 0.9559818
# Epoch: 0001 Avg. cost = 0.338 Train Acc. = 0.9562
# Epoch: 0001 Avg. cost = 0.339 Train Acc. = 0.9562909
# Epoch: 0001 Avg. cost = 0.339 Train Acc. = 0.9565273
# Epoch: 0001 Avg. cost = 0.340 Train Acc. = 0.9564546
# Epoch: 0001 Avg. cost = 0.341 Train Acc. = 0.9567636
# Epoch: 0001 Avg. cost = 0.341 Train Acc. = 0.9566182
# Epoch: 0001 Avg. cost = 0.341 Train Acc. = 0.9563636
# Epoch: 0001 Avg. cost = 0.342 Train Acc. = 0.95643634
# Epoch: 0001 Avg. cost = 0.342 Train Acc. = 0.9561818
# Epoch: 0001 Avg. cost = 0.343 Train Acc. = 0.9558
# Epoch: 0001 Avg. cost = 0.344 Train Acc. = 0.956
# Epoch: 0001 Avg. cost = 0.344 Train Acc. = 0.95550907
# Epoch: 0001 Avg. cost = 0.345 Train Acc. = 0.95558184
# Epoch: 0001 Avg. cost = 0.345 Train Acc. = 0.95534545
# Epoch: 0001 Avg. cost = 0.346 Train Acc. = 0.9552
# Epoch: 0001 Avg. cost = 0.346 Train Acc. = 0.95536363
# Epoch: 0001 Avg. cost = 0.346 Train Acc. = 0.95536363
# Epoch: 0001 Avg. cost = 0.347 Train Acc. = 0.9549818
# Epoch: 0001 Avg. cost = 0.348 Train Acc. = 0.95516366
# Epoch: 0001 Avg. cost = 0.349 Train Acc. = 0.9552
# Epoch: 0001 Avg. cost = 0.349 Train Acc. = 0.95525455
# Epoch: 0001 Avg. cost = 0.350 Train Acc. = 0.9555454
# Epoch: 0001 Avg. cost = 0.350 Train Acc. = 0.9557273
# Epoch: 0001 Avg. cost = 0.351 Train Acc. = 0.9559091
# Epoch: 0001 Avg. cost = 0.351 Train Acc. = 0.9561818
# Epoch: 0001 Avg. cost = 0.352 Train Acc. = 0.9565091
# Epoch: 0001 Avg. cost = 0.353 Train Acc. = 0.9567091
# Epoch: 0001 Avg. cost = 0.353 Train Acc. = 0.9571273
# Epoch: 0001 Avg. cost = 0.354 Train Acc. = 0.95705456
# Epoch: 0001 Avg. cost = 0.354 Train Acc. = 0.9571818
# Epoch: 0001 Avg. cost = 0.355 Train Acc. = 0.9573454
# Epoch: 0001 Avg. cost = 0.355 Train Acc. = 0.9574182
# Epoch: 0001 Avg. cost = 0.356 Train Acc. = 0.9570364
# Epoch: 0001 Avg. cost = 0.356 Train Acc. = 0.95681816
# Epoch: 0001 Avg. cost = 0.357 Train Acc. = 0.95663637
# Epoch: 0001 Avg. cost = 0.357 Train Acc. = 0.9568
# Epoch: 0001 Avg. cost = 0.358 Train Acc. = 0.9569273
# Epoch: 0001 Avg. cost = 0.358 Train Acc. = 0.9568545
# Epoch: 0001 Avg. cost = 0.358 Train Acc. = 0.9565455
# Epoch: 0001 Avg. cost = 0.359 Train Acc. = 0.95672727
# Epoch: 0001 Avg. cost = 0.359 Train Acc. = 0.95663637
# Epoch: 0001 Avg. cost = 0.360 Train Acc. = 0.9564
# Epoch: 0001 Avg. cost = 0.360 Train Acc. = 0.9565091
# Epoch: 0001 Avg. cost = 0.361 Train Acc. = 0.9566727
# Epoch: 0001 Avg. cost = 0.361 Train Acc. = 0.9570909
# Epoch: 0001 Avg. cost = 0.362 Train Acc. = 0.9572909
# Epoch: 0001 Avg. cost = 0.362 Train Acc. = 0.95736367
# Epoch: 0001 Avg. cost = 0.363 Train Acc. = 0.9575818
# Epoch: 0001 Avg. cost = 0.363 Train Acc. = 0.9576
# Epoch: 0001 Avg. cost = 0.364 Train Acc. = 0.9577091
# Epoch: 0001 Avg. cost = 0.364 Train Acc. = 0.95772725
# Epoch: 0001 Avg. cost = 0.365 Train Acc. = 0.95796365
# Epoch: 0001 Avg. cost = 0.365 Train Acc. = 0.9580909
# Epoch: 0001 Avg. cost = 0.365 Train Acc. = 0.95821816
# Epoch: 0001 Avg. cost = 0.366 Train Acc. = 0.9581091
# Epoch: 0001 Avg. cost = 0.366 Train Acc. = 0.9584
# Epoch: 0001 Avg. cost = 0.367 Train Acc. = 0.9584
# Epoch: 0001 Avg. cost = 0.367 Train Acc. = 0.95870906
# Epoch: 0001 Avg. cost = 0.367 Train Acc. = 0.9586
# Epoch: 0001 Avg. cost = 0.368 Train Acc. = 0.95861816
# Epoch: 0001 Avg. cost = 0.368 Train Acc. = 0.9584182
# Epoch: 0001 Avg. cost = 0.369 Train Acc. = 0.95843637
# Epoch: 0001 Avg. cost = 0.369 Train Acc. = 0.9584
# Epoch: 0001 Avg. cost = 0.370 Train Acc. = 0.95827276
# Epoch: 0001 Avg. cost = 0.371 Train Acc. = 0.9587273
# Epoch: 0001 Avg. cost = 0.372 Train Acc. = 0.95870906
# Epoch: 0001 Avg. cost = 0.372 Train Acc. = 0.9587455
# Epoch: 0001 Avg. cost = 0.372 Train Acc. = 0.9585818
# Epoch: 0001 Avg. cost = 0.373 Train Acc. = 0.9585636
# Epoch: 0001 Avg. cost = 0.374 Train Acc. = 0.9588364
# Epoch: 0001 Avg. cost = 0.374 Train Acc. = 0.95885456
# Epoch: 0001 Avg. cost = 0.375 Train Acc. = 0.95910907
# Epoch: 0001 Avg. cost = 0.375 Train Acc. = 0.9593091
# Epoch: 0001 Avg. cost = 0.376 Train Acc. = 0.9594727
# Epoch: 0001 Avg. cost = 0.376 Train Acc. = 0.95954543
# Epoch: 0001 Avg. cost = 0.377 Train Acc. = 0.9594727
# Epoch: 0001 Avg. cost = 0.377 Train Acc. = 0.9592364
# Epoch: 0001 Avg. cost = 0.377 Train Acc. = 0.95916367
# Epoch: 0001 Avg. cost = 0.378 Train Acc. = 0.9592
# Epoch: 0001 Avg. cost = 0.378 Train Acc. = 0.95916367
# Epoch: 0001 Avg. cost = 0.379 Train Acc. = 0.95903635
# Epoch: 0001 Avg. cost = 0.379 Train Acc. = 0.9588909
# Epoch: 0001 Avg. cost = 0.380 Train Acc. = 0.95912725
# Epoch: 0001 Avg. cost = 0.381 Train Acc. = 0.95912725
# Epoch: 0001 Avg. cost = 0.381 Train Acc. = 0.9591454
# Epoch: 0001 Avg. cost = 0.382 Train Acc. = 0.95916367
# Epoch: 0001 Avg. cost = 0.382 Train Acc. = 0.95910907
# Epoch: 0001 Avg. cost = 0.382 Train Acc. = 0.95936364
# Epoch: 0001 Avg. cost = 0.383 Train Acc. = 0.95952725
# Epoch: 0001 Avg. cost = 0.383 Train Acc. = 0.9596
# Epoch: 0001 Avg. cost = 0.384 Train Acc. = 0.95967275
# Epoch: 0001 Avg. cost = 0.384 Train Acc. = 0.9596364
# Epoch: 0001 Avg. cost = 0.384 Train Acc. = 0.95974547
# Epoch: 0001 Avg. cost = 0.385 Train Acc. = 0.9598727
# Epoch: 0001 Avg. cost = 0.385 Train Acc. = 0.9598
# Epoch: 0001 Avg. cost = 0.386 Train Acc. = 0.95967275
# Epoch: 0001 Avg. cost = 0.386 Train Acc. = 0.95983636
# Epoch: 0001 Avg. cost = 0.386 Train Acc. = 0.9596909
# Epoch: 0001 Avg. cost = 0.387 Train Acc. = 0.95985454
# Epoch: 0001 Avg. cost = 0.388 Train Acc. = 0.95994544
# Epoch: 0001 Avg. cost = 0.388 Train Acc. = 0.9602364
# Epoch: 0001 Avg. cost = 0.388 Train Acc. = 0.96043634
# Epoch: 0001 Avg. cost = 0.389 Train Acc. = 0.96074545
# Epoch: 0001 Avg. cost = 0.390 Train Acc. = 0.9608
# Epoch: 0001 Avg. cost = 0.390 Train Acc. = 0.96092725
# Epoch: 0001 Avg. cost = 0.391 Train Acc. = 0.9610909
# Epoch: 0001 Avg. cost = 0.391 Train Acc. = 0.96116364
# Epoch: 0001 Avg. cost = 0.391 Train Acc. = 0.96154547
# Epoch: 0001 Avg. cost = 0.391 Train Acc. = 0.9619455
# Epoch: 0001 Avg. cost = 0.392 Train Acc. = 0.9619091
# Epoch: 0001 Avg. cost = 0.392 Train Acc. = 0.9617091
# Epoch: 0001 Avg. cost = 0.393 Train Acc. = 0.96196365
# Epoch: 0001 Avg. cost = 0.393 Train Acc. = 0.96198183
# Epoch: 0001 Avg. cost = 0.394 Train Acc. = 0.96212727
# Epoch: 0001 Avg. cost = 0.394 Train Acc. = 0.96223634
# Epoch: 0001 Avg. cost = 0.395 Train Acc. = 0.9623273
# Epoch: 0001 Avg. cost = 0.396 Train Acc. = 0.9624364
# Epoch: 0001 Avg. cost = 0.396 Train Acc. = 0.9624364
# Epoch: 0001 Avg. cost = 0.397 Train Acc. = 0.9624364
# Epoch: 0001 Avg. cost = 0.397 Train Acc. = 0.96263635
# Epoch: 0001 Avg. cost = 0.398 Train Acc. = 0.9626
# Epoch: 0001 Avg. cost = 0.398 Train Acc. = 0.9626182
# Epoch: 0001 Avg. cost = 0.398 Train Acc. = 0.9624909
# Epoch: 0001 Avg. cost = 0.399 Train Acc. = 0.96230906
# Epoch: 0001 Avg. cost = 0.399 Train Acc. = 0.9622
# Epoch: 0001 Avg. cost = 0.400 Train Acc. = 0.9623273
# Epoch: 0001 Avg. cost = 0.400 Train Acc. = 0.9625273
# Epoch: 0001 Avg. cost = 0.401 Train Acc. = 0.9625273
# Epoch: 0001 Avg. cost = 0.401 Train Acc. = 0.9625273
# Epoch: 0001 Avg. cost = 0.402 Train Acc. = 0.96247274
# Epoch: 0001 Avg. cost = 0.402 Train Acc. = 0.9626182
# Epoch: 0001 Avg. cost = 0.403 Train Acc. = 0.96285456
# Epoch: 0001 Avg. cost = 0.403 Train Acc. = 0.9629091
# Epoch: 0001 Avg. cost = 0.404 Train Acc. = 0.96303636
# Epoch: 0001 Avg. cost = 0.404 Train Acc. = 0.96336365
# Epoch: 0001 Avg. cost = 0.405 Train Acc. = 0.96314543
# Epoch: 0001 Avg. cost = 0.405 Train Acc. = 0.9634182
# Epoch: 0001 Avg. cost = 0.405 Train Acc. = 0.9633818
# Epoch: 0001 Avg. cost = 0.405 Train Acc. = 0.96343637
# Epoch: 0001 Avg. cost = 0.406 Train Acc. = 0.9632546
# Epoch: 0001 Avg. cost = 0.406 Train Acc. = 0.9632
# Epoch: 0001 Avg. cost = 0.407 Train Acc. = 0.96327275
# Epoch: 0001 Avg. cost = 0.407 Train Acc. = 0.9633091
# Epoch: 0001 Avg. cost = 0.408 Train Acc. = 0.9633273
# Epoch: 0001 Avg. cost = 0.408 Train Acc. = 0.96336365
# Epoch: 0001 Avg. cost = 0.408 Train Acc. = 0.963
# Epoch: 0001 Avg. cost = 0.409 Train Acc. = 0.9630182
# Epoch: 0001 Avg. cost = 0.409 Train Acc. = 0.96312726
# Epoch: 0001 Avg. cost = 0.410 Train Acc. = 0.96305454
# Epoch: 0001 Avg. cost = 0.411 Train Acc. = 0.9632364
# Epoch: 0001 Avg. cost = 0.411 Train Acc. = 0.96343637
# Epoch: 0001 Avg. cost = 0.411 Train Acc. = 0.96363634
# Epoch: 0001 Avg. cost = 0.412 Train Acc. = 0.9638
# Epoch: 0001 Avg. cost = 0.412 Train Acc. = 0.96403635
# Epoch: 0001 Avg. cost = 0.413 Train Acc. = 0.96427274
# Epoch: 0001 Avg. cost = 0.413 Train Acc. = 0.9642909
# Epoch: 0001 Avg. cost = 0.413 Train Acc. = 0.96465456
# Epoch: 0001 Avg. cost = 0.414 Train Acc. = 0.96483636
# Epoch: 0001 Avg. cost = 0.414 Train Acc. = 0.96445453
# Epoch: 0001 Avg. cost = 0.415 Train Acc. = 0.9644909
# Epoch: 0001 Avg. cost = 0.415 Train Acc. = 0.9646364
# Epoch: 0001 Avg. cost = 0.416 Train Acc. = 0.9645454
# Epoch: 0001 Avg. cost = 0.416 Train Acc. = 0.9643273
# Epoch: 0001 Avg. cost = 0.417 Train Acc. = 0.96416366
# Epoch: 0001 Avg. cost = 0.417 Train Acc. = 0.9643091
# Epoch: 0001 Avg. cost = 0.418 Train Acc. = 0.9641455
# Epoch: 0001 Avg. cost = 0.418 Train Acc. = 0.96436363
# Epoch: 0001 Avg. cost = 0.419 Train Acc. = 0.9644
# Epoch: 0001 Avg. cost = 0.419 Train Acc. = 0.9643273
# Epoch: 0001 Avg. cost = 0.419 Train Acc. = 0.9643091
# Epoch: 0001 Avg. cost = 0.420 Train Acc. = 0.96425456
# Epoch: 0001 Avg. cost = 0.420 Train Acc. = 0.9643273
# Epoch: 0001 Avg. cost = 0.421 Train Acc. = 0.96434546
# Epoch: 0001 Avg. cost = 0.421 Train Acc. = 0.9642364
# Epoch: 0001 Avg. cost = 0.422 Train Acc. = 0.9639636
# Epoch: 0001 Avg. cost = 0.422 Train Acc. = 0.96378183
# Epoch: 0001 Avg. cost = 0.422 Train Acc. = 0.9634909
# Epoch: 0001 Avg. cost = 0.423 Train Acc. = 0.96334547
# Epoch: 0001 Avg. cost = 0.423 Train Acc. = 0.96334547
# Epoch: 0001 Avg. cost = 0.424 Train Acc. = 0.9631818
# Epoch: 0001 Avg. cost = 0.424 Train Acc. = 0.9630727
# Epoch: 0001 Avg. cost = 0.425 Train Acc. = 0.96345454
# Epoch: 0001 Avg. cost = 0.425 Train Acc. = 0.96361816
# Epoch: 0001 Avg. cost = 0.425 Train Acc. = 0.9635818
# Epoch: 0001 Avg. cost = 0.426 Train Acc. = 0.9638909
# Epoch: 0001 Avg. cost = 0.426 Train Acc. = 0.9640909
# Epoch: 0001 Avg. cost = 0.427 Train Acc. = 0.9646182
# Epoch: 0001 Avg. cost = 0.427 Train Acc. = 0.9648909
# Epoch: 0001 Avg. cost = 0.428 Train Acc. = 0.9650364
# Epoch: 0001 Avg. cost = 0.428 Train Acc. = 0.96507275
# Epoch: 0001 Avg. cost = 0.429 Train Acc. = 0.9652
# Epoch: 0001 Avg. cost = 0.429 Train Acc. = 0.96556365
# Epoch: 0001 Avg. cost = 0.430 Train Acc. = 0.96567273
# Epoch: 0001 Avg. cost = 0.430 Train Acc. = 0.9657818
# Epoch: 0001 Avg. cost = 0.430 Train Acc. = 0.96574545
# Epoch: 0001 Avg. cost = 0.431 Train Acc. = 0.96581817
# Epoch: 0001 Avg. cost = 0.431 Train Acc. = 0.9658909
# Epoch: 0001 Avg. cost = 0.431 Train Acc. = 0.96572727
# Epoch: 0001 Avg. cost = 0.432 Train Acc. = 0.9656364
# Epoch: 0001 Avg. cost = 0.432 Train Acc. = 0.9658
# Epoch: 0001 Avg. cost = 0.433 Train Acc. = 0.9654727
# Epoch: 0001 Avg. cost = 0.434 Train Acc. = 0.9652727
# Epoch: 0001 Avg. cost = 0.434 Train Acc. = 0.9655091
# Epoch: 0001 Avg. cost = 0.435 Train Acc. = 0.9654
# Epoch: 0001 Avg. cost = 0.435 Train Acc. = 0.9654
# Epoch: 0001 Avg. cost = 0.435 Train Acc. = 0.96558183
# Epoch: 0001 Avg. cost = 0.436 Train Acc. = 0.96543634
# Epoch: 0001 Avg. cost = 0.436 Train Acc. = 0.9654727
# Epoch: 0002 Avg. cost = 0.000 Train Acc. = 0.9650546
# Epoch: 0002 Avg. cost = 0.001 Train Acc. = 0.96514547
# Epoch: 0002 Avg. cost = 0.001 Train Acc. = 0.9652909
# Epoch: 0002 Avg. cost = 0.001 Train Acc. = 0.9651818
# Epoch: 0002 Avg. cost = 0.002 Train Acc. = 0.9651091
# Epoch: 0002 Avg. cost = 0.002 Train Acc. = 0.9649636
# Epoch: 0002 Avg. cost = 0.003 Train Acc. = 0.96458185
# Epoch: 0002 Avg. cost = 0.004 Train Acc. = 0.9646182
# Epoch: 0002 Avg. cost = 0.004 Train Acc. = 0.9645636
# Epoch: 0002 Avg. cost = 0.004 Train Acc. = 0.9645454
# Epoch: 0002 Avg. cost = 0.005 Train Acc. = 0.96450907
# Epoch: 0002 Avg. cost = 0.005 Train Acc. = 0.965
# Epoch: 0002 Avg. cost = 0.006 Train Acc. = 0.96492726
# Epoch: 0002 Avg. cost = 0.006 Train Acc. = 0.9654727
# Epoch: 0002 Avg. cost = 0.007 Train Acc. = 0.9656909
# Epoch: 0002 Avg. cost = 0.007 Train Acc. = 0.96583635
# Epoch: 0002 Avg. cost = 0.007 Train Acc. = 0.96583635
# Epoch: 0002 Avg. cost = 0.008 Train Acc. = 0.96592724
# Epoch: 0002 Avg. cost = 0.008 Train Acc. = 0.96605456
# Epoch: 0002 Avg. cost = 0.009 Train Acc. = 0.9661091
# Epoch: 0002 Avg. cost = 0.009 Train Acc. = 0.9661091
# Epoch: 0002 Avg. cost = 0.010 Train Acc. = 0.9664909
# Epoch: 0002 Avg. cost = 0.010 Train Acc. = 0.96665454
# Epoch: 0002 Avg. cost = 0.011 Train Acc. = 0.9670727
# Epoch: 0002 Avg. cost = 0.011 Train Acc. = 0.9673091
# Epoch: 0002 Avg. cost = 0.011 Train Acc. = 0.96738183
# Epoch: 0002 Avg. cost = 0.012 Train Acc. = 0.96761817
# Epoch: 0002 Avg. cost = 0.012 Train Acc. = 0.96770906
# Epoch: 0002 Avg. cost = 0.012 Train Acc. = 0.9676727
# Epoch: 0002 Avg. cost = 0.013 Train Acc. = 0.9678364
# Epoch: 0002 Avg. cost = 0.014 Train Acc. = 0.9675818
# Epoch: 0002 Avg. cost = 0.014 Train Acc. = 0.9675636
# Epoch: 0002 Avg. cost = 0.014 Train Acc. = 0.96787274
# Epoch: 0002 Avg. cost = 0.015 Train Acc. = 0.9676727
# Epoch: 0002 Avg. cost = 0.015 Train Acc. = 0.9678182
# Epoch: 0002 Avg. cost = 0.015 Train Acc. = 0.96763635
# Epoch: 0002 Avg. cost = 0.015 Train Acc. = 0.9675636
# Epoch: 0002 Avg. cost = 0.016 Train Acc. = 0.9673091
# Epoch: 0002 Avg. cost = 0.016 Train Acc. = 0.9674182
# Epoch: 0002 Avg. cost = 0.016 Train Acc. = 0.96747273
# Epoch: 0002 Avg. cost = 0.017 Train Acc. = 0.9675818
# Epoch: 0002 Avg. cost = 0.017 Train Acc. = 0.9677455
# Epoch: 0002 Avg. cost = 0.018 Train Acc. = 0.96761817
# Epoch: 0002 Avg. cost = 0.018 Train Acc. = 0.96754545
# Epoch: 0002 Avg. cost = 0.018 Train Acc. = 0.9675273
# Epoch: 0002 Avg. cost = 0.019 Train Acc. = 0.9673455
# Epoch: 0002 Avg. cost = 0.019 Train Acc. = 0.96747273
# Epoch: 0002 Avg. cost = 0.019 Train Acc. = 0.9674
# Epoch: 0002 Avg. cost = 0.020 Train Acc. = 0.9676
# Epoch: 0002 Avg. cost = 0.020 Train Acc. = 0.9678909
# Epoch: 0002 Avg. cost = 0.021 Train Acc. = 0.9681818
# Epoch: 0002 Avg. cost = 0.021 Train Acc. = 0.96803635
# Epoch: 0002 Avg. cost = 0.021 Train Acc. = 0.9679818
# Epoch: 0002 Avg. cost = 0.022 Train Acc. = 0.96814543
# Epoch: 0002 Avg. cost = 0.022 Train Acc. = 0.9683091
# Epoch: 0002 Avg. cost = 0.023 Train Acc. = 0.96843636
# Epoch: 0002 Avg. cost = 0.023 Train Acc. = 0.9684727
# Epoch: 0002 Avg. cost = 0.024 Train Acc. = 0.96825457
# Epoch: 0002 Avg. cost = 0.024 Train Acc. = 0.9683818
# Epoch: 0002 Avg. cost = 0.024 Train Acc. = 0.9682909
# Epoch: 0002 Avg. cost = 0.025 Train Acc. = 0.96836364
# Epoch: 0002 Avg. cost = 0.025 Train Acc. = 0.9683273
# Epoch: 0002 Avg. cost = 0.025 Train Acc. = 0.96852726
# Epoch: 0002 Avg. cost = 0.026 Train Acc. = 0.9685091
# Epoch: 0002 Avg. cost = 0.026 Train Acc. = 0.9687273
# Epoch: 0002 Avg. cost = 0.027 Train Acc. = 0.9687818
# Epoch: 0002 Avg. cost = 0.027 Train Acc. = 0.96883637
# Epoch: 0002 Avg. cost = 0.027 Train Acc. = 0.96867275
# Epoch: 0002 Avg. cost = 0.028 Train Acc. = 0.96892726
# Epoch: 0002 Avg. cost = 0.028 Train Acc. = 0.96885455
# Epoch: 0002 Avg. cost = 0.028 Train Acc. = 0.96903634
# Epoch: 0002 Avg. cost = 0.029 Train Acc. = 0.9691091
# Epoch: 0002 Avg. cost = 0.029 Train Acc. = 0.96909094
# Epoch: 0002 Avg. cost = 0.029 Train Acc. = 0.969
# Epoch: 0002 Avg. cost = 0.030 Train Acc. = 0.9692364
# Epoch: 0002 Avg. cost = 0.030 Train Acc. = 0.96936363
# Epoch: 0002 Avg. cost = 0.030 Train Acc. = 0.96950907
# Epoch: 0002 Avg. cost = 0.031 Train Acc. = 0.9694909
# Epoch: 0002 Avg. cost = 0.031 Train Acc. = 0.96941817
# Epoch: 0002 Avg. cost = 0.031 Train Acc. = 0.96958184
# Epoch: 0002 Avg. cost = 0.032 Train Acc. = 0.9692364
# Epoch: 0002 Avg. cost = 0.032 Train Acc. = 0.9691273
# Epoch: 0002 Avg. cost = 0.033 Train Acc. = 0.9692
# Epoch: 0002 Avg. cost = 0.033 Train Acc. = 0.9692364
# Epoch: 0002 Avg. cost = 0.034 Train Acc. = 0.9693273
# Epoch: 0002 Avg. cost = 0.035 Train Acc. = 0.96934545
# Epoch: 0002 Avg. cost = 0.035 Train Acc. = 0.9693273
# Epoch: 0002 Avg. cost = 0.035 Train Acc. = 0.9693818
# Epoch: 0002 Avg. cost = 0.036 Train Acc. = 0.9694
# Epoch: 0002 Avg. cost = 0.036 Train Acc. = 0.96936363
# Epoch: 0002 Avg. cost = 0.036 Train Acc. = 0.9693818
# Epoch: 0002 Avg. cost = 0.037 Train Acc. = 0.9694545
# Epoch: 0002 Avg. cost = 0.037 Train Acc. = 0.9693091
# Epoch: 0002 Avg. cost = 0.037 Train Acc. = 0.9692909
# Epoch: 0002 Avg. cost = 0.038 Train Acc. = 0.9690727
# Epoch: 0002 Avg. cost = 0.038 Train Acc. = 0.9690727
# Epoch: 0002 Avg. cost = 0.038 Train Acc. = 0.9689818
# Epoch: 0002 Avg. cost = 0.039 Train Acc. = 0.96909094
# Epoch: 0002 Avg. cost = 0.039 Train Acc. = 0.96869093
# Epoch: 0002 Avg. cost = 0.040 Train Acc. = 0.96883637
# Epoch: 0002 Avg. cost = 0.040 Train Acc. = 0.9687273
# Epoch: 0002 Avg. cost = 0.040 Train Acc. = 0.96843636
# Epoch: 0002 Avg. cost = 0.041 Train Acc. = 0.9682
# Epoch: 0002 Avg. cost = 0.041 Train Acc. = 0.9683818
# Epoch: 0002 Avg. cost = 0.041 Train Acc. = 0.9682909
# Epoch: 0002 Avg. cost = 0.042 Train Acc. = 0.9683818
# Epoch: 0002 Avg. cost = 0.042 Train Acc. = 0.9683818
# Epoch: 0002 Avg. cost = 0.042 Train Acc. = 0.9685636
# Epoch: 0002 Avg. cost = 0.043 Train Acc. = 0.9685091
# Epoch: 0002 Avg. cost = 0.043 Train Acc. = 0.96827275
# Epoch: 0002 Avg. cost = 0.043 Train Acc. = 0.9680182
# Epoch: 0002 Avg. cost = 0.044 Train Acc. = 0.968
# Epoch: 0002 Avg. cost = 0.044 Train Acc. = 0.9679273
# Epoch: 0002 Avg. cost = 0.045 Train Acc. = 0.96796364
# Epoch: 0002 Avg. cost = 0.045 Train Acc. = 0.9679091
# Epoch: 0002 Avg. cost = 0.045 Train Acc. = 0.96805453
# Epoch: 0002 Avg. cost = 0.046 Train Acc. = 0.96852726
# Epoch: 0002 Avg. cost = 0.046 Train Acc. = 0.96883637
# Epoch: 0002 Avg. cost = 0.047 Train Acc. = 0.9692
# Epoch: 0002 Avg. cost = 0.047 Train Acc. = 0.9693818
# Epoch: 0002 Avg. cost = 0.047 Train Acc. = 0.9694
# Epoch: 0002 Avg. cost = 0.048 Train Acc. = 0.9694545
# Epoch: 0002 Avg. cost = 0.048 Train Acc. = 0.96965456
# Epoch: 0002 Avg. cost = 0.048 Train Acc. = 0.9694545
# Epoch: 0002 Avg. cost = 0.049 Train Acc. = 0.9694909
# Epoch: 0002 Avg. cost = 0.049 Train Acc. = 0.9696182
# Epoch: 0002 Avg. cost = 0.050 Train Acc. = 0.96950907
# Epoch: 0002 Avg. cost = 0.050 Train Acc. = 0.9696
# Epoch: 0002 Avg. cost = 0.050 Train Acc. = 0.96958184
# Epoch: 0002 Avg. cost = 0.051 Train Acc. = 0.9695455
# Epoch: 0002 Avg. cost = 0.051 Train Acc. = 0.96941817
# Epoch: 0002 Avg. cost = 0.051 Train Acc. = 0.96956366
# Epoch: 0002 Avg. cost = 0.052 Train Acc. = 0.9697091
# Epoch: 0002 Avg. cost = 0.052 Train Acc. = 0.96976364
# Epoch: 0002 Avg. cost = 0.053 Train Acc. = 0.9694545
# Epoch: 0002 Avg. cost = 0.053 Train Acc. = 0.9694
# Epoch: 0002 Avg. cost = 0.053 Train Acc. = 0.96934545
# Epoch: 0002 Avg. cost = 0.054 Train Acc. = 0.9696909
# Epoch: 0002 Avg. cost = 0.054 Train Acc. = 0.9701273
# Epoch: 0002 Avg. cost = 0.054 Train Acc. = 0.9703636
# Epoch: 0002 Avg. cost = 0.055 Train Acc. = 0.9704
# Epoch: 0002 Avg. cost = 0.055 Train Acc. = 0.97041816
# Epoch: 0002 Avg. cost = 0.055 Train Acc. = 0.9703091
# Epoch: 0002 Avg. cost = 0.056 Train Acc. = 0.97023636
# Epoch: 0002 Avg. cost = 0.056 Train Acc. = 0.9704546
# Epoch: 0002 Avg. cost = 0.056 Train Acc. = 0.97041816
# Epoch: 0002 Avg. cost = 0.056 Train Acc. = 0.9705273
# Epoch: 0002 Avg. cost = 0.057 Train Acc. = 0.9702909
# Epoch: 0002 Avg. cost = 0.057 Train Acc. = 0.97023636
# Epoch: 0002 Avg. cost = 0.057 Train Acc. = 0.9700909
# Epoch: 0002 Avg. cost = 0.058 Train Acc. = 0.96994543
# Epoch: 0002 Avg. cost = 0.058 Train Acc. = 0.9700182
# Epoch: 0002 Avg. cost = 0.058 Train Acc. = 0.9701273
# Epoch: 0002 Avg. cost = 0.059 Train Acc. = 0.9701091
# Epoch: 0002 Avg. cost = 0.059 Train Acc. = 0.9699091
# Epoch: 0002 Avg. cost = 0.060 Train Acc. = 0.97
# Epoch: 0002 Avg. cost = 0.060 Train Acc. = 0.9696
# Epoch: 0002 Avg. cost = 0.060 Train Acc. = 0.96967274
# Epoch: 0002 Avg. cost = 0.060 Train Acc. = 0.96958184
# Epoch: 0002 Avg. cost = 0.061 Train Acc. = 0.9694909
# Epoch: 0002 Avg. cost = 0.061 Train Acc. = 0.96985453
# Epoch: 0002 Avg. cost = 0.062 Train Acc. = 0.9701091
# Epoch: 0002 Avg. cost = 0.062 Train Acc. = 0.9703818
# Epoch: 0002 Avg. cost = 0.063 Train Acc. = 0.97049093
# Epoch: 0002 Avg. cost = 0.063 Train Acc. = 0.9703636
# Epoch: 0002 Avg. cost = 0.063 Train Acc. = 0.9704
# Epoch: 0002 Avg. cost = 0.063 Train Acc. = 0.9702909
# Epoch: 0002 Avg. cost = 0.064 Train Acc. = 0.97023636
# Epoch: 0002 Avg. cost = 0.064 Train Acc. = 0.9703091
# Epoch: 0002 Avg. cost = 0.064 Train Acc. = 0.97025454
# Epoch: 0002 Avg. cost = 0.065 Train Acc. = 0.9700182
# Epoch: 0002 Avg. cost = 0.065 Train Acc. = 0.9700909
# Epoch: 0002 Avg. cost = 0.066 Train Acc. = 0.9702182
# Epoch: 0002 Avg. cost = 0.066 Train Acc. = 0.97016364
# Epoch: 0002 Avg. cost = 0.067 Train Acc. = 0.9702
# Epoch: 0002 Avg. cost = 0.067 Train Acc. = 0.9703818
# Epoch: 0002 Avg. cost = 0.067 Train Acc. = 0.97041816
# Epoch: 0002 Avg. cost = 0.068 Train Acc. = 0.9702727
# Epoch: 0002 Avg. cost = 0.068 Train Acc. = 0.9703636
# Epoch: 0002 Avg. cost = 0.068 Train Acc. = 0.9704546
# Epoch: 0002 Avg. cost = 0.069 Train Acc. = 0.9705818
# Epoch: 0002 Avg. cost = 0.069 Train Acc. = 0.9707091
# Epoch: 0002 Avg. cost = 0.069 Train Acc. = 0.9709273
# Epoch: 0002 Avg. cost = 0.069 Train Acc. = 0.9708545
# Epoch: 0002 Avg. cost = 0.070 Train Acc. = 0.971
# Epoch: 0002 Avg. cost = 0.070 Train Acc. = 0.97098184
# Epoch: 0002 Avg. cost = 0.070 Train Acc. = 0.9710182
# Epoch: 0002 Avg. cost = 0.070 Train Acc. = 0.97098184
# Epoch: 0002 Avg. cost = 0.071 Train Acc. = 0.9709273
# Epoch: 0002 Avg. cost = 0.071 Train Acc. = 0.971
# Epoch: 0002 Avg. cost = 0.071 Train Acc. = 0.9711818
# Epoch: 0002 Avg. cost = 0.072 Train Acc. = 0.97138184
# Epoch: 0002 Avg. cost = 0.072 Train Acc. = 0.97156364
# Epoch: 0002 Avg. cost = 0.072 Train Acc. = 0.9719091
# Epoch: 0002 Avg. cost = 0.073 Train Acc. = 0.97212726
# Epoch: 0002 Avg. cost = 0.073 Train Acc. = 0.9723455
# Epoch: 0002 Avg. cost = 0.074 Train Acc. = 0.97223634
# Epoch: 0002 Avg. cost = 0.074 Train Acc. = 0.97227275
# Epoch: 0002 Avg. cost = 0.074 Train Acc. = 0.9723273
# Epoch: 0002 Avg. cost = 0.075 Train Acc. = 0.97243637
# Epoch: 0002 Avg. cost = 0.075 Train Acc. = 0.9725091
# Epoch: 0002 Avg. cost = 0.075 Train Acc. = 0.9725091
# Epoch: 0002 Avg. cost = 0.076 Train Acc. = 0.97254544
# Epoch: 0002 Avg. cost = 0.076 Train Acc. = 0.9728182
# Epoch: 0002 Avg. cost = 0.077 Train Acc. = 0.97263634
# Epoch: 0002 Avg. cost = 0.077 Train Acc. = 0.9725091
# Epoch: 0002 Avg. cost = 0.078 Train Acc. = 0.9724182
# Epoch: 0002 Avg. cost = 0.078 Train Acc. = 0.9723455
# Epoch: 0002 Avg. cost = 0.078 Train Acc. = 0.9721818
# Epoch: 0002 Avg. cost = 0.079 Train Acc. = 0.9720727
# Epoch: 0002 Avg. cost = 0.079 Train Acc. = 0.9717091
# Epoch: 0002 Avg. cost = 0.079 Train Acc. = 0.9716182
# Epoch: 0002 Avg. cost = 0.080 Train Acc. = 0.97156364
# Epoch: 0002 Avg. cost = 0.080 Train Acc. = 0.9715091
# Epoch: 0002 Avg. cost = 0.081 Train Acc. = 0.97147274
# Epoch: 0002 Avg. cost = 0.081 Train Acc. = 0.97116363
# Epoch: 0002 Avg. cost = 0.081 Train Acc. = 0.9711273
# Epoch: 0002 Avg. cost = 0.082 Train Acc. = 0.971
# Epoch: 0002 Avg. cost = 0.082 Train Acc. = 0.97121817
# Epoch: 0002 Avg. cost = 0.082 Train Acc. = 0.9712727
# Epoch: 0002 Avg. cost = 0.083 Train Acc. = 0.9715091
# Epoch: 0002 Avg. cost = 0.083 Train Acc. = 0.97165453
# Epoch: 0002 Avg. cost = 0.083 Train Acc. = 0.9714
# Epoch: 0002 Avg. cost = 0.083 Train Acc. = 0.9714182
# Epoch: 0002 Avg. cost = 0.084 Train Acc. = 0.97130907
# Epoch: 0002 Avg. cost = 0.084 Train Acc. = 0.97136366
# Epoch: 0002 Avg. cost = 0.085 Train Acc. = 0.9712909
# Epoch: 0002 Avg. cost = 0.085 Train Acc. = 0.97105455
# Epoch: 0002 Avg. cost = 0.085 Train Acc. = 0.9708909
# Epoch: 0002 Avg. cost = 0.086 Train Acc. = 0.9710364
# Epoch: 0002 Avg. cost = 0.086 Train Acc. = 0.9710909
# Epoch: 0002 Avg. cost = 0.087 Train Acc. = 0.9709091
# Epoch: 0002 Avg. cost = 0.087 Train Acc. = 0.9709091
# Epoch: 0002 Avg. cost = 0.087 Train Acc. = 0.9708
# Epoch: 0002 Avg. cost = 0.088 Train Acc. = 0.97107273
# Epoch: 0002 Avg. cost = 0.088 Train Acc. = 0.9712
# Epoch: 0002 Avg. cost = 0.088 Train Acc. = 0.9711818
# Epoch: 0002 Avg. cost = 0.089 Train Acc. = 0.9714364
# Epoch: 0002 Avg. cost = 0.089 Train Acc. = 0.97156364
# Epoch: 0002 Avg. cost = 0.090 Train Acc. = 0.9717636
# Epoch: 0002 Avg. cost = 0.090 Train Acc. = 0.9720909
# Epoch: 0002 Avg. cost = 0.090 Train Acc. = 0.9719818
# Epoch: 0002 Avg. cost = 0.091 Train Acc. = 0.97212726
# Epoch: 0002 Avg. cost = 0.091 Train Acc. = 0.9721091
# Epoch: 0002 Avg. cost = 0.091 Train Acc. = 0.97205454
# Epoch: 0002 Avg. cost = 0.091 Train Acc. = 0.9716909
# Epoch: 0002 Avg. cost = 0.092 Train Acc. = 0.9716182
# Epoch: 0002 Avg. cost = 0.092 Train Acc. = 0.97156364
# Epoch: 0002 Avg. cost = 0.092 Train Acc. = 0.9714909
# Epoch: 0002 Avg. cost = 0.093 Train Acc. = 0.9715818
# Epoch: 0002 Avg. cost = 0.093 Train Acc. = 0.9714909
# Epoch: 0002 Avg. cost = 0.093 Train Acc. = 0.9715273
# Epoch: 0002 Avg. cost = 0.094 Train Acc. = 0.97163635
# Epoch: 0002 Avg. cost = 0.094 Train Acc. = 0.9715818
# Epoch: 0002 Avg. cost = 0.094 Train Acc. = 0.9716
# Epoch: 0002 Avg. cost = 0.095 Train Acc. = 0.9716182
# Epoch: 0002 Avg. cost = 0.095 Train Acc. = 0.9718364
# Epoch: 0002 Avg. cost = 0.096 Train Acc. = 0.9718364
# Epoch: 0002 Avg. cost = 0.096 Train Acc. = 0.97163635
# Epoch: 0002 Avg. cost = 0.097 Train Acc. = 0.97165453
# Epoch: 0002 Avg. cost = 0.098 Train Acc. = 0.9716909
# Epoch: 0002 Avg. cost = 0.098 Train Acc. = 0.97172725
# Epoch: 0002 Avg. cost = 0.098 Train Acc. = 0.97187275
# Epoch: 0002 Avg. cost = 0.099 Train Acc. = 0.9717636
# Epoch: 0002 Avg. cost = 0.099 Train Acc. = 0.9715818
# Epoch: 0002 Avg. cost = 0.099 Train Acc. = 0.9714909
# Epoch: 0002 Avg. cost = 0.100 Train Acc. = 0.9716
# Epoch: 0002 Avg. cost = 0.100 Train Acc. = 0.9714909
# Epoch: 0002 Avg. cost = 0.101 Train Acc. = 0.9716182
# Epoch: 0002 Avg. cost = 0.101 Train Acc. = 0.9718182
# Epoch: 0002 Avg. cost = 0.102 Train Acc. = 0.972
# Epoch: 0002 Avg. cost = 0.102 Train Acc. = 0.9723455
# Epoch: 0002 Avg. cost = 0.103 Train Acc. = 0.97229093
# Epoch: 0002 Avg. cost = 0.103 Train Acc. = 0.97243637
# Epoch: 0002 Avg. cost = 0.103 Train Acc. = 0.97252727
# Epoch: 0002 Avg. cost = 0.104 Train Acc. = 0.9724182
# Epoch: 0002 Avg. cost = 0.104 Train Acc. = 0.9723273
# Epoch: 0002 Avg. cost = 0.105 Train Acc. = 0.97236365
# Epoch: 0002 Avg. cost = 0.105 Train Acc. = 0.97236365
# Epoch: 0002 Avg. cost = 0.105 Train Acc. = 0.97245455
# Epoch: 0002 Avg. cost = 0.106 Train Acc. = 0.9725818
# Epoch: 0002 Avg. cost = 0.106 Train Acc. = 0.97254544
# Epoch: 0002 Avg. cost = 0.106 Train Acc. = 0.97238183
# Epoch: 0002 Avg. cost = 0.107 Train Acc. = 0.97212726
# Epoch: 0002 Avg. cost = 0.107 Train Acc. = 0.97212726
# Epoch: 0002 Avg. cost = 0.108 Train Acc. = 0.9719818
# Epoch: 0002 Avg. cost = 0.108 Train Acc. = 0.97187275
# Epoch: 0002 Avg. cost = 0.109 Train Acc. = 0.97185457
# Epoch: 0002 Avg. cost = 0.109 Train Acc. = 0.9719091
# Epoch: 0002 Avg. cost = 0.110 Train Acc. = 0.9719818
# Epoch: 0002 Avg. cost = 0.110 Train Acc. = 0.97212726
# Epoch: 0002 Avg. cost = 0.111 Train Acc. = 0.97205454
# Epoch: 0002 Avg. cost = 0.111 Train Acc. = 0.97221816
# Epoch: 0002 Avg. cost = 0.111 Train Acc. = 0.9724
# Epoch: 0002 Avg. cost = 0.111 Train Acc. = 0.9725636
# Epoch: 0002 Avg. cost = 0.112 Train Acc. = 0.9725818
# Epoch: 0002 Avg. cost = 0.112 Train Acc. = 0.9726909
# Epoch: 0002 Avg. cost = 0.112 Train Acc. = 0.9727273
# Epoch: 0002 Avg. cost = 0.113 Train Acc. = 0.9728182
# Epoch: 0002 Avg. cost = 0.113 Train Acc. = 0.9729818
# Epoch: 0002 Avg. cost = 0.113 Train Acc. = 0.97276366
# Epoch: 0002 Avg. cost = 0.114 Train Acc. = 0.97285455
# Epoch: 0002 Avg. cost = 0.114 Train Acc. = 0.9727455
# Epoch: 0002 Avg. cost = 0.114 Train Acc. = 0.97276366
# Epoch: 0002 Avg. cost = 0.115 Train Acc. = 0.97252727
# Epoch: 0002 Avg. cost = 0.115 Train Acc. = 0.97245455
# Epoch: 0002 Avg. cost = 0.116 Train Acc. = 0.97238183
# Epoch: 0002 Avg. cost = 0.116 Train Acc. = 0.97229093
# Epoch: 0002 Avg. cost = 0.116 Train Acc. = 0.97223634
# Epoch: 0002 Avg. cost = 0.116 Train Acc. = 0.9720909
# Epoch: 0002 Avg. cost = 0.117 Train Acc. = 0.9718909
# Epoch: 0002 Avg. cost = 0.117 Train Acc. = 0.972
# Epoch: 0002 Avg. cost = 0.118 Train Acc. = 0.9720909
# Epoch: 0002 Avg. cost = 0.118 Train Acc. = 0.97221816
# Epoch: 0002 Avg. cost = 0.118 Train Acc. = 0.97229093
# Epoch: 0002 Avg. cost = 0.118 Train Acc. = 0.9724909
# Epoch: 0002 Avg. cost = 0.119 Train Acc. = 0.9724727
# Epoch: 0002 Avg. cost = 0.119 Train Acc. = 0.9726
# Epoch: 0002 Avg. cost = 0.119 Train Acc. = 0.9728364
# Epoch: 0002 Avg. cost = 0.120 Train Acc. = 0.97287273
# Epoch: 0002 Avg. cost = 0.120 Train Acc. = 0.9729273
# Epoch: 0002 Avg. cost = 0.120 Train Acc. = 0.9727273
# Epoch: 0002 Avg. cost = 0.121 Train Acc. = 0.97285455
# Epoch: 0002 Avg. cost = 0.121 Train Acc. = 0.97294545
# Epoch: 0002 Avg. cost = 0.121 Train Acc. = 0.97285455
# Epoch: 0002 Avg. cost = 0.121 Train Acc. = 0.97310907
# Epoch: 0002 Avg. cost = 0.121 Train Acc. = 0.97296363
# Epoch: 0002 Avg. cost = 0.122 Train Acc. = 0.97276366
# Epoch: 0002 Avg. cost = 0.122 Train Acc. = 0.97276366
# Epoch: 0002 Avg. cost = 0.122 Train Acc. = 0.9726909
# Epoch: 0002 Avg. cost = 0.123 Train Acc. = 0.97303635
# Epoch: 0002 Avg. cost = 0.123 Train Acc. = 0.97316366
# Epoch: 0002 Avg. cost = 0.124 Train Acc. = 0.97327274
# Epoch: 0002 Avg. cost = 0.124 Train Acc. = 0.9732
# Epoch: 0002 Avg. cost = 0.124 Train Acc. = 0.9729818
# Epoch: 0002 Avg. cost = 0.124 Train Acc. = 0.97287273
# Epoch: 0002 Avg. cost = 0.125 Train Acc. = 0.9726909
# Epoch: 0002 Avg. cost = 0.125 Train Acc. = 0.9726727
# Epoch: 0002 Avg. cost = 0.125 Train Acc. = 0.9725636
# Epoch: 0002 Avg. cost = 0.126 Train Acc. = 0.9726545
# Epoch: 0002 Avg. cost = 0.126 Train Acc. = 0.9728
# Epoch: 0002 Avg. cost = 0.127 Train Acc. = 0.9728
# Epoch: 0002 Avg. cost = 0.127 Train Acc. = 0.9729273
# Epoch: 0002 Avg. cost = 0.127 Train Acc. = 0.97287273
# Epoch: 0002 Avg. cost = 0.128 Train Acc. = 0.9728909
# Epoch: 0002 Avg. cost = 0.128 Train Acc. = 0.9728364
# Epoch: 0002 Avg. cost = 0.129 Train Acc. = 0.97303635
# Epoch: 0002 Avg. cost = 0.129 Train Acc. = 0.9732909
# Epoch: 0002 Avg. cost = 0.129 Train Acc. = 0.97327274
# Epoch: 0002 Avg. cost = 0.130 Train Acc. = 0.9732909
# Epoch: 0002 Avg. cost = 0.130 Train Acc. = 0.9733818
# Epoch: 0002 Avg. cost = 0.130 Train Acc. = 0.9733818
# Epoch: 0002 Avg. cost = 0.131 Train Acc. = 0.97345454
# Epoch: 0002 Avg. cost = 0.131 Train Acc. = 0.9734
# ...
# Epoch: 0030 Avg. cost = 0.012 Train Acc. = 0.99923635
# Epoch: 0030 Avg. cost = 0.012 Train Acc. = 0.99923635
# Epoch: 0030 Avg. cost = 0.012 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.012 Train Acc. = 0.9992727
# Epoch: 0030 Avg. cost = 0.012 Train Acc. = 0.9992727
# Epoch: 0030 Avg. cost = 0.012 Train Acc. = 0.99923635
# Epoch: 0030 Avg. cost = 0.012 Train Acc. = 0.9992727
# Epoch: 0030 Avg. cost = 0.012 Train Acc. = 0.9992727
# Epoch: 0030 Avg. cost = 0.012 Train Acc. = 0.9992727
# Epoch: 0030 Avg. cost = 0.012 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.012 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.012 Train Acc. = 0.99923635
# Epoch: 0030 Avg. cost = 0.012 Train Acc. = 0.99923635
# Epoch: 0030 Avg. cost = 0.012 Train Acc. = 0.99923635
# Epoch: 0030 Avg. cost = 0.012 Train Acc. = 0.99923635
# Epoch: 0030 Avg. cost = 0.012 Train Acc. = 0.99921817
# Epoch: 0030 Avg. cost = 0.012 Train Acc. = 0.99921817
# Epoch: 0030 Avg. cost = 0.012 Train Acc. = 0.9992
# Epoch: 0030 Avg. cost = 0.012 Train Acc. = 0.9992
# Epoch: 0030 Avg. cost = 0.012 Train Acc. = 0.99923635
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.99921817
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.99921817
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.99921817
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.9992
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.9991818
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.9992
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.9991636
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.99914545
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.99914545
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.99914545
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.9991818
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.99921817
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.9991636
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.99921817
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.9992
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.9992
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.9992
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.9992
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.9991818
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.99914545
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.99914545
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.9991636
# Epoch: 0030 Avg. cost = 0.013 Train Acc. = 0.9991636
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.9991636
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.9991636
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.99914545
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.99912727
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.9991091
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.9990909
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.99907273
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.999
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.99898183
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.99898183
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.99907273
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.9990909
# Epoch: 0030 Avg. cost = 0.014 Train Acc. = 0.9990909
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.9990909
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.9990909
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.99912727
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.9992
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.99921817
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.99923635
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.99923635
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.99923635
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.99921817
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.9992
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.9991636
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.9991818
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.9991636
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.99912727
# Epoch: 0030 Avg. cost = 0.015 Train Acc. = 0.9991091
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.9991091
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.9990182
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.9990182
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.9990182
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.99898183
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.999
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.999
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.999
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.9990364
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.99905455
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.99907273
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.99912727
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.9991636
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.9991818
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.99914545
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.9991818
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.99921817
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.99923635
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.99921817
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.9992
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.9991818
# Epoch: 0030 Avg. cost = 0.016 Train Acc. = 0.9991818
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.9991818
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.99914545
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.99914545
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.9990909
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.99905455
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.99907273
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.99907273
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.9990909
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.9991091
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.9990909
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.99912727
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.9991636
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.99914545
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.9992
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.9991818
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.9991636
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.9991091
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.99914545
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.99914545
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.99914545
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.9992
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.9992
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.9992
# Epoch: 0030 Avg. cost = 0.017 Train Acc. = 0.9992
# Epoch: 0030 Avg. cost = 0.018 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.018 Train Acc. = 0.9992909
# Epoch: 0030 Avg. cost = 0.018 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.018 Train Acc. = 0.9992909
# Epoch: 0030 Avg. cost = 0.018 Train Acc. = 0.9992727
# Epoch: 0030 Avg. cost = 0.018 Train Acc. = 0.99923635
# Epoch: 0030 Avg. cost = 0.018 Train Acc. = 0.99923635
# Epoch: 0030 Avg. cost = 0.018 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.018 Train Acc. = 0.9992727
# Epoch: 0030 Avg. cost = 0.018 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.018 Train Acc. = 0.9992727
# Epoch: 0030 Avg. cost = 0.018 Train Acc. = 0.99923635
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.9991636
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.9991091
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.99907273
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.99907273
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.9991091
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.99907273
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.99907273
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.99907273
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.99907273
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.9990364
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.99896365
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.9989273
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.9989091
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.99889094
# Epoch: 0030 Avg. cost = 0.019 Train Acc. = 0.99883634
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.9987818
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.99881816
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.99881816
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.9987636
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.9987636
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.9987818
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.99872726
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.9986909
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.9986727
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.9986909
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.9987091
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.9987818
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.99881816
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.9988545
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.99887276
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.99887276
# Epoch: 0030 Avg. cost = 0.020 Train Acc. = 0.9988545
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.9989091
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.99896365
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.9990364
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.9990909
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.9991091
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.99912727
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.9991636
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.9991818
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.99921817
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.9992727
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.99930906
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.9993273
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.9994
# Epoch: 0030 Avg. cost = 0.021 Train Acc. = 0.99938184
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.99938184
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.99938184
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.99938184
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.99938184
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.9993273
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.99930906
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.9992727
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.9992909
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.9992909
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.99930906
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.022 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.9993273
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.9994364
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.9994364
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.99938184
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.9993273
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.99923635
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.9992909
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.9992727
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.9992909
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.9992909
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.99930906
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.99930906
# Epoch: 0030 Avg. cost = 0.023 Train Acc. = 0.99923635
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.9992909
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.9992727
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.9992545
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.9992909
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.99930906
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.99930906
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.99930906
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.99930906
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.9994182
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.9994182
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.9994182
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.9994364
# Epoch: 0030 Avg. cost = 0.024 Train Acc. = 0.9994
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.9994
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.9994182
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.9994182
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.9994
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.99945456
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.9994364
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.9994364
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.99945456
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.9994364
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.9994364
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.9994364
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.9994364
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.9994182
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.9994364
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.9994909
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.99947274
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.99947274
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.99947274
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.99947274
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.99945456
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.99945456
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.99945456
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.99947274
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.99945456
# Epoch: 0030 Avg. cost = 0.025 Train Acc. = 0.99947274
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.99947274
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.99947274
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.9994182
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.9994182
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.9994182
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.9994182
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.99945456
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.99945456
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.99947274
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.9994909
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.99945456
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.9994364
# Epoch: 0030 Avg. cost = 0.026 Train Acc. = 0.9994364
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9994
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9994
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9993273
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.99936366
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9993455
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.99930906
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9993273
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9993273
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.99930906
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9992909
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9992727
# Epoch: 0030 Avg. cost = 0.027 Train Acc. = 0.9992909
# Epoch: 0030 Avg. cost = 0.028 Train Acc. = 0.99930906
# Training Done!
# Test Acc. =  0.9859
